# %% [markdown]
# Salem Ameen, PhD student at Salford University
#
# ###  Concrete Compressive Strength Data Set
#
# Bayesian Ridge Regression

# %% [markdown]
# # Import the Libraries

# %%
import numpy as np
import pandas
from numpy import *
import time
import sys
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import feature_selection
from sklearn.linear_model import BayesianRidge
from sklearn.learning_curve import learning_curve, validation_curve
from sklearn.cross_validation import cross_val_predict
from sklearn import metrics, grid_search, cross_validation
from IPython.display import set_matplotlib_formats
from bokeh.plotting import figure, show, output_notebook
from sklearn.grid_search import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import r2_score
from bokeh.layouts import gridplot
output_notebook()
set_matplotlib_formats('png', 'pdf')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (6, 6)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="695c4f00-976a-4269-8768-78df399ccf13">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Load data

# %% [markdown]
# In the previous file we have not change the data as there is no missing value or add any new parameters so it can be downloaded from the web directly.

# %% [markdown]
# ['Cement','BlastFurnace','Fly_Ash','Water','Superplasticizer','CoarseAggregate','Aggregate','day','Concrete']

# %%
names = ['Cement','BlastFurnace','Fly_Ash','Water','Superplasticizer','CoarseAggregate','Aggregate','day','Concrete']
feature_names = names
feature_cols = names

data = pd.read_excel('Concrete_Data.xls', sep='%s')

from sklearn import preprocessing

def number_encode_features(df):
    result = df.copy()
    encoders = {}
    for column in result.columns:
        if result.dtypes[column] == np.object:
            encoders[column] = preprocessing.LabelEncoder()
            result[column] = encoders[column].fit_transform(result[column])
    return result, encoders

data, _ = number_encode_features(data)

dataset = data.values
X = dataset[:,0:8]
Y = dataset[:,8]
print 'Number of examples',len(X)
# Out:
# Number of examples 1030

# %%
dataset.shape
# Out:
# (1030, 9)

# %%
# Make developement dataset for genrilization and final testing
from sklearn.cross_validation import train_test_split
# Extracting 20% testing data
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.20, random_state=0)
X = X_train
Y = y_train
new_data      = X_train
new_test_data = X_test
print 'Number of training examples',len(X_train)
print 'Number of validation examples',len(X_test)
# Out:
# Number of training examples 824
# Number of validation examples 206

# %% [markdown]
# Number of training data is very small so we need to use cross validation instead of spareate another validation data.

# %% [markdown]
# From the previous visulization the data has no missing value but has many outlier and some sparisty

# %% [markdown]
# # Ranking of the feature's importance to the target

# %%
# Using just correlation coefficient even in prevoius file we show them using data frame
for col in feature_cols:
    lm = BayesianRidge(fit_intercept=True)
    lm.fit(data[[col]], data['Concrete'])
    print col,'\t', lm.score(data[[col]], data['Concrete'])
# Out:
# Cement 	0.247835277377
# BlastFurnace 	0.0181281273861
# Fly_Ash 	0.0111028033348
# Water 	0.0838665178229
# Superplasticizer 	0.134025608207
# CoarseAggregate 	0.0271685166316
# Aggregate 	0.0279404960062
# day 	0.108153232577
# Concrete 	1.0

# %%
# Randing the important features to the target
model = feature_selection.SelectKBest(score_func=feature_selection.f_regression,k=4)
results = model.fit(data[feature_cols], data['Concrete'])
k=0
print 'Feature Name      Score         Pvalue'
for feat in feature_cols:
    print feat,'\t\t',results.scores_[k],'\t',results.pvalues_[k]
    k=k+1
# Out:
# Feature Name      Score         Pvalue
# Cement 		338.725793692 	1.32345794884e-65
# BlastFurnace 		19.0325717427 	1.41457498978e-05
# Fly_Ash 		11.6269492436 	0.000675283559617
# Water 		94.1187973071 	2.3660726996e-21
# Superplasticizer 		159.109321731 	5.07908923638e-34
# CoarseAggregate 		28.7447095672 	1.01959722248e-07
# Aggregate 		29.5829376115 	6.69468148289e-08
# day 		124.673209261 	2.10314421454e-27
# Concrete 		-2.31485020847e+18 	1.0

# %% [markdown]
# # Set the parameters for cross validation

# %%
num_folds = 10
num_instances = len(X)
seed = 7
kfold = cross_validation.KFold(n=num_instances, n_folds=num_folds, random_state=seed)

# %% [markdown]
#  # Set the parameters for bias-variance dilemma

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %% [markdown]
# # Preprocessing the data and save both the model and preprocessed data

# %%
# According to the nature of the data spasity and there is outliter RobustScaler class is recomandit 
# but when I tried both of them the result seems is same
from sklearn.preprocessing import StandardScaler
scaler = preprocessing.StandardScaler().fit(X_train)

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test) # use same transform for testing data
X = X_train

# %%
# save transformed data
np.save('./data/X_train', X_train)
np.save('./data/y_train', y_train)
np.save('./data/X_test', X_test)
np.save('./data/y_test', y_test)

# %%
# save the model scaler to the desk
from sklearn.externals import joblib
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl', 'scaler.pkl_01.npy', 'scaler.pkl_02.npy', 'scaler.pkl_03.npy']

# %%
# Test the model if it is work
scalerTest = joblib.load('scaler.pkl')
new_data_scaled = scalerTest.transform(new_test_data)
print " =================================================================>>>>> done"
print new_data_scaled
# Out:
#  =================================================================>>>>> done
# [[ 2.10991518 -0.88106119 -0.84617062 ...,  1.97132825 -1.97556016
#   -0.69267849]
#  [-1.49852146  1.2030767  -0.84617062 ..., -0.17456898  0.33209718
#   -0.62793264]
#  [ 0.79619183  1.26087498 -0.84617062 ..., -0.34824772 -0.21429096
#    0.7317303 ]
#  ...,
#  [-1.01146856 -0.31384476  1.84556404 ...,  0.4429554   0.25069398
#   -0.51462739]
#  [-0.16567549  0.37690132  0.48783031 ..., -0.98764276 -0.495502   -0.2880169 ]
#  [-0.28041116 -0.88106119  0.63813809 ..., -0.19180821  1.08532344
#   -0.69267849]]

# %% [markdown]
# # 1. BayesianRidge Regression

# %% [markdown]
# The Least Absolute Shrinkage and Selection Operator (or BayesianRidge for short) is a modification of linear regression, like BayesianRidge regression, where the loss function is modified to minimize the complexity of the model measured as the sum absolute value of the coefficient values (also called the l1-norm).

# %% [markdown]
# ## Validation curve

# %% [markdown]
# choosing multiple hyperparameters of an estimator

# %%
from sklearn.linear_model import BayesianRidge
estimator = BayesianRidge()
estimator.get_params().keys()
# Out:
# ['normalize',
#  'n_iter',
#  'verbose',
#  'lambda_1',
#  'lambda_2',
#  'fit_intercept',
#  'alpha_2',
#  'tol',
#  'alpha_1',
#  'copy_X',
#  'compute_score']

# %%
# For parametr alpha
#param_range = np.logspace(-10.0, 10.0)
#param_range = np.logspace(-7, 7, 3)
param_range = np.linspace(0,1000,100)

train_scores, test_scores = validation_curve(
    BayesianRidge(), X, Y, param_name="alpha_1", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with BayesianRidge")
plt.xlabel("lambda_2")
plt.ylabel("Score")
plt.ylim(0.4, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# It turns out changing alpha_1, alpha_2, lambda_1 and lambda_2 does not change the performance so in next step the search will find the best cominations between them.

# %% [markdown]
# ## Grid search and/or Random search to determine best compination of parameters

# %%
# Utility function to report optimal parameters
from operator import itemgetter
def report(grid_scores, n_top=5):
    params = None
    top_scores = sorted(grid_scores, key=itemgetter(1), reverse=True)[:n_top]
    for i, score in enumerate(top_scores):
        print("Parameters with rank: {0}".format(i + 1))
        print("Mean validation score: {0:.4f} (std: {1:.4f})".format(
              score.mean_validation_score, np.std(score.cv_validation_scores)))
        print("Parameters: {0}".format(score.parameters))
        print("")
        
        if params == None:
            params = score.parameters
    
    return params

# The most common value for the max number of features to look at in each split is sqrt(# of features)
sqrtfeat = np.sqrt(X.shape[1]) 
# Simple grid test (162 combinations)
grid_test1 = { "alpha_1"      : [-1.0,0, 0.000001, 1.0],
                "alpha_2"      : [-1.0,0,0.000001, 1.0],
               "lambda_1"      : [-1.0,0,0.000001, 1.0],
               "lambda_2"      : [-1.0,0,0.000001, 1.0]}

# Large randomized test using max_depth to control tree size (5000 possible combinations)
random_test1 = { "alpha_1"          : np.linspace(0,1.0,100),
                  "alpha_2"      : np.linspace(0,1.0,100),
                  "lambda_1"      : np.linspace(0,1.0,100),
                  "lambda_2"      : np.linspace(0,1.0,100)}


forest = BayesianRidge()

print "Hyperparameter optimization using GridSearchCV..."
grid_search = GridSearchCV(forest, grid_test1, n_jobs=-1, cv=num_folds)
grid_search.fit(X, Y)
best_params_from_grid_search = report(grid_search.grid_scores_)
print '+++++++++++++++++++++++++++++++++++++++++++++++'
print "Hyperparameter optimization using RandomizedSearchCV"
grid_search = RandomizedSearchCV(forest, random_test1, n_jobs=-1, cv=num_folds, n_iter=5)
grid_search.fit(X, Y)
best_params_from_rand_search1 = report(grid_search.grid_scores_)
# Out:
# Hyperparameter optimization using GridSearchCV...
# Parameters with rank: 1
# Mean validation score: 0.5956 (std: 0.0536)
# Parameters: {'alpha_2': -1.0, 'lambda_1': -1.0, 'lambda_2': 1.0, 'alpha_1': 1.0}
#
# Parameters with rank: 2
# Mean validation score: 0.5956 (std: 0.0536)
# Parameters: {'alpha_2': 0, 'lambda_1': -1.0, 'lambda_2': 1.0, 'alpha_1': 1.0}
#
# Parameters with rank: 3
# Mean validation score: 0.5956 (std: 0.0536)
# Parameters: {'alpha_2': 1e-06, 'lambda_1': -1.0, 'lambda_2': 1.0, 'alpha_1': 1.0}
#
# Parameters with rank: 4
# Mean validation score: 0.5956 (std: 0.0536)
# Parameters: {'alpha_2': 1.0, 'lambda_1': -1.0, 'lambda_2': 1.0, 'alpha_1': 1.0}
#
# Parameters with rank: 5
# Mean validation score: 0.5956 (std: 0.0536)
# Parameters: {'alpha_2': -1.0, 'lambda_1': -1.0, 'lambda_2': 1.0, 'alpha_1': 1e-06}
#
# +++++++++++++++++++++++++++++++++++++++++++++++
# Hyperparameter optimization using RandomizedSearchCV
# Parameters with rank: 1
# Mean validation score: 0.5956 (std: 0.0534)
# Parameters: {'alpha_2': 0.42424242424242425, 'lambda_1': 0.010101010101010102, 'lambda_2': 0.53535353535353536, 'alpha_1': 0.60606060606060608}
#
# Parameters with rank: 2
# Mean validation score: 0.5955 (std: 0.0533)
# Parameters: {'alpha_2': 0.30303030303030304, 'lambda_1': 0.50505050505050508, 'lambda_2': 0.39393939393939398, 'alpha_1': 0.33333333333333337}
#
# Parameters with rank: 3
# Mean validation score: 0.5955 (std: 0.0533)
# Parameters: {'alpha_2': 0.98989898989898994, 'lambda_1': 0.58585858585858586, 'lambda_2': 0.89898989898989912, 'alpha_1': 0.80808080808080818}
#
# Parameters with rank: 4
# Mean validation score: 0.5955 (std: 0.0532)
# Parameters: {'alpha_2': 0.47474747474747481, 'lambda_1': 0.81818181818181823, 'lambda_2': 0.5252525252525253, 'alpha_1': 0.8282828282828284}
#
# Parameters with rank: 5
# Mean validation score: 0.5955 (std: 0.0532)
# Parameters: {'alpha_2': 0.37373737373737376, 'lambda_1': 0.83838383838383845, 'lambda_2': 0.91919191919191923, 'alpha_1': 0.56565656565656575}

# %% [markdown]
# Best parameters Parameters: Parameters: {'alpha_2': 1.0, 'lambda_1': 1.0, 'lambda_2': -1.0, 'alpha_1': -1.0}

# %% [markdown]
# ## Learning Curve

# %% [markdown]
# In essence, what we’re doing it training the exact same model with increasingly large fractions of our total training data, and plotting the error of the training and test sets at each step.

# %%
from sklearn.linear_model import BayesianRidge
model = BayesianRidge(lambda_1 = 1.0, lambda_2 = -1.0, alpha_1 = -1.0, alpha_2=-1.0)
title = "Learning Curves (BayesianRidge Refression)"
cv = cross_validation.ShuffleSplit(X.shape[0], n_iter=100,
                                   test_size=0.2, random_state=0)
plot_learning_curve(model, title, X, Y, ylim=(0.2, 1.01), cv=cv, n_jobs=-1)
plt.show()

# %%
# More data from learning curve to show the process of building the model
train_sizes, train_scores, valid_scores = learning_curve(
     model, X, Y, train_sizes=[50, 80, 110], cv=cv, n_jobs=4)

print 'train_sizes = ', train_sizes

print ' training scores'
print ' 50 training sizees'
print train_scores[0].mean(),'±',train_scores[0].std()
print ' 80 training sizees'
print train_scores[1].mean(),'±',train_scores[1].std()
print ' 110 training sizees'
print train_scores[2].mean(),'±',train_scores[2].std()

print '\n validation scores'
print ' 50 validation scores'
print valid_scores[0].mean(),'±',valid_scores[0].std()
print ' 80 validation scores'
print valid_scores[1].mean(),'±',valid_scores[1].std()
print ' 110 validation scores'
print valid_scores[2].mean(),'±',valid_scores[2].std()
# Out:
# train_sizes =  [ 50  80 110]
#  training scores
#  50 training sizees
# 0.64506640504 ± 0.125918379967
#  80 training sizees
# 0.631945723657 ± 0.0716173522419
#  110 training sizees
# 0.629583984968 ± 0.0569485943536
#
#  validation scores
#  50 validation scores
# 0.435176912842 ± 0.190999282469
#  80 validation scores
# 0.528548341178 ± 0.067975604428
#  110 validation scores
# 0.547526780127 ± 0.0734571946407

# %% [markdown]
# ## Cross validation

# %%
scoring = 'mean_squared_error'
results = cross_validation.cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
print 'Scoring according to mean_squared_error'
print results
print '\n Mean      Standard deviation'
print("%.2f      %.2f" % (results.mean(), results.std()))
## Fit the model
model.fit(X,Y)
print '\n print intercept and coefficients'
print model.intercept_
print model.coef_
# pair the feature names with the coefficients
print '\n(feature, coefficients)'
print zip(feature_cols, model.coef_)
# Linear qu. of the model

print ("\n Predicted Target = %.2f +(%.2f)X1 +(%.2f)X2 +(%.2f)X3 +(%.2f)X4+(%.2f)X4 "
       % (model.intercept_, model.coef_[0], model.coef_[1],model.coef_[2],model.coef_[3],
       model.coef_[4]))
print ("\n Predicted Target = %.2f +(%.2f)%s +(%.2f)%s +(%.2f)%s +(%.2f)%s+(%.2f)%s"
       % (model.intercept_, model.coef_[0], feature_cols[0], model.coef_[1], feature_cols[1],
          model.coef_[2], feature_cols[2],model.coef_[3], feature_cols[3],
       model.coef_[4], feature_cols[4]))
# Out:
# Scoring according to mean_squared_error
# [ -98.54089378 -105.87782184  -93.15366544 -130.87784283 -142.63813086
#   -92.06575432 -126.95659489  -97.4352927  -129.69141361 -112.72250847]
#
#  Mean      Standard deviation
# -113.00      17.34
#
#  print intercept and coefficients
# 36.100692614
# [ 11.73343157   8.86330933   5.22514508  -3.60483651   1.87980797
#    1.22700318   1.16778004   7.05808971]
#
# (feature, coefficients)
# [('Cement', 11.733431568922661), ('BlastFurnace', 8.8633093348060825), ('Fly_Ash', 5.2251450793512646), ('Water', -3.6048365149359256), ('Superplasticizer', 1.8798079746627572), ('CoarseAggregate', 1.2270031818879517), ('Aggregate', 1.167780037747896), ('day', 7.0580897104029923)]
#
#  Predicted Target = 36.10 +(11.73)X1 +(8.86)X2 +(5.23)X3 +(-3.60)X4+(1.88)X4
#
#  Predicted Target = 36.10 +(11.73)Cement +(8.86)BlastFurnace +(5.23)Fly_Ash +(-3.60)Water+(1.88)Superplasticizer

# %% [markdown]
# To be more precise these valrible is not the input feature as descripe on the dataset, those varibles in scaled virsion on the orginal onces. So, to be more correct I should assign to them another varibles but for easy to unserstand I kept them as they were.

# %% [markdown]
# ## Coefficients Of Determination {Calculating R^2}
#
# R^2, Close to one is better

# %%
predicted = cross_val_predict(model, X, Y, cv=kfold)
r_squared = r2_score(Y, predicted, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# R-squared =  0.599782140541

# %% [markdown]
# ## Residual Plot

# %%
predicted = cross_val_predict(model, X, Y, cv=kfold)
fig, ax = plt.subplots()
ax.scatter(Y, predicted)
ax.plot([Y.min(), Y.max()], [Y.min(), Y.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()

# %%
# Plotining using bokeh
#TOOLS = [BoxSelectTool(), HoverTool()]
#TOOLS = 'hover,box_zoom,box_select,crosshair,resize,reset,BayesianRidge_select,pan,save,poly_select,tap,wheel_zoom,undo'
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,lasso_select,pan,save,poly_select,tap,wheel_zoom,undo'
p = figure(plot_width=500, plot_height=500, tools=TOOLS)
p.scatter(Y, predicted,x="jjj", marker="o", color="#80B1D3", line_width=3)
p.title.align = "center"
p.xaxis.axis_label = "Measured"
p.xaxis.axis_label_text_color = "#aa6666"
#p.xaxis.axis_label_standoff = 30
p.xaxis.major_tick_line_color = "firebrick"
p.xaxis.major_tick_line_width = 3
p.xaxis.minor_tick_line_color = "orange"
p.yaxis.axis_label = "Predicted"
p.yaxis.axis_label_text_font_style = "italic"
p.yaxis.axis_label_text_color = "#aa6666"
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
#p.line([Y.min(), Y.max()], [Y.min(), Y.max()], line_dash="4 4", line_width=2, color='red')

# create a new plot with the toolbar below
# line_dash="4 4", line_width=2, color='red'
p.line([Y.min(), Y.max()], [Y.min(), Y.max()], line_dash="4 4", line_width=2, line_color="black")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="8a5ea40e-58df-4a90-92cc-2c855f030710"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#8a5ea40e-58df-4a90-92cc-2c855f030710").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8a5ea40e-58df-4a90-92cc-2c855f030710");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8a5ea40e-58df-4a90-92cc-2c855f030710' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"74f0a719-d811-45f9-9286-d3b0606ca429":{"roots":{"references":[{"attributes":{},"id":"48b46677-b1ee-428f-80de-6f989e6c1ebb","type":"ToolEvents"},{"attributes":{"axis_label":"Measured","axis_label_text_color":{"value":"#aa6666"},"formatter":{"id":"c719ef30-627b-444d-8ed6-45be632880e1","type":"BasicTickFormatter"},"major_tick_line_color":{"value":"firebrick"},"major_tick_line_width":{"value":3},"minor_tick_line_color":{"value":"orange"},"plot":{"id":"7bf31a2e-8cc7-4039-87c1-3289407ecb09","subtype":"Figure","type":"Plot"},"ticker":{"id":"438b6507-3c89-42a7-bf7d-529d30239cd8","type":"BasicTicker"}},"id":"69084a9e-ddee-42d1-bf6b-e426815667ec","type":"LinearAxis"},{"attributes":{"data_source":{"id":"2b106af5-3379-4691-8d64-74dc2b3adb14","type":"ColumnDataSource"},"glyph":{"id":"9f1ec049-c0ac-4b67-97fb-9031a4fd5be0","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"fea56b51-416c-40b9-abc1-ae89d6c461cd","type":"Circle"},"selection_glyph":null},"id":"20abae27-41ca-48bd-b055-05ece38ca2a1","type":"GlyphRenderer"},{"attributes":{"axis_label":"Predicted","axis_label_text_color":{"value":"#aa6666"},"formatter":{"id":"383d669a-0a52-4987-ae52-98c2b02409a4","type":"BasicTickFormatter"},"plot":{"id":"7bf31a2e-8cc7-4039-87c1-3289407ecb09","subtype":"Figure","type":"Plot"},"ticker":{"id":"0eae7366-7df4-4775-b7e2-14b17368d817","type":"BasicTicker"}},"id":"8b396b74-748a-4d55-bd81-eac5260448b9","type":"LinearAxis"},{"attributes":{"fill_color":{"value":"#80B1D3"},"line_color":{"value":"#80B1D3"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"9f1ec049-c0ac-4b67-97fb-9031a4fd5be0","type":"Circle"},{"attributes":{"line_dash":[4,4],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"62ee27a8-2452-4708-b87c-159066636088","type":"Line"},{"attributes":{"plot":{"id":"7bf31a2e-8cc7-4039-87c1-3289407ecb09","subtype":"Figure","type":"Plot"}},"id":"49ba3fc4-fde9-47d2-92bd-77ebefc0d223","type":"PanTool"},{"attributes":{"plot":{"id":"7bf31a2e-8cc7-4039-87c1-3289407ecb09","subtype":"Figure","type":"Plot"}},"id":"9ba114e1-0ed0-417f-8b77-15a27b381c0e","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"22168c05-1a92-4025-aeb6-f2f6a59fabbb","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"093a77f5-1e41-4bf7-9ae8-a3d698f5f6e7","type":"PolyAnnotation"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[43.892042159999995,38.21075992,33.419591196,13.12072828,47.22221124,22.31833812,12.47262084,28.937997196,47.029847436000004,26.322814728,30.439675923999996,12.63809508,20.77391188,43.798273423999994,66.10006412,15.361525279999999,40.865242519999995,45.939785879999995,33.75674496,43.58177796,23.524231644,42.69924868,14.143910664,48.401215199999996,34.569637164,35.85964676,59.09498796,24.49708228,37.721921436,15.520104759999999,32.401235144,33.05347944,49.249270679999995,71.69860924,54.896079119999996,50.45930106,51.863763672,28.6822016,26.77235308,17.236210524,36.83870268,40.2309246,47.714497103999996,11.36256448,9.99050724,40.925226931999994,40.563252031999994,31.715896,39.417342919999996,18.12632404,18.28490352,9.86640156,41.2996124,34.55653712,53.95839176,82.5992248,54.598914963999995,44.61185510399999,39.28978986,63.528318639999995,39.1622368,39.321505756,20.416073836,44.395359639999995,56.33708396,38.500339839999995,32.245413568000004,42.229026048,46.247292176,33.68779736,44.209201119999996,33.72916592,64.90037588,33.192064116000005,12.45193656,44.1402535 ...

# %%
plt.scatter(predicted, (predicted - Y), c='r', s=30)
plt.title("Residual plot on the training data")
plt.xlabel("Predicted")
plt.ylabel("Residuals")

# %%
# Plotining using bokeh
#TOOLS = 'hover,box_zoom,box_select,crosshair,resize,reset,BayesianRidge_select,pan,save,poly_select,tap,wheel_zoom,undo'
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,lasso_select,pan,save,poly_select,tap,wheel_zoom,undo'
p = figure(plot_width=500, plot_height=500, title="Residual plot on the training data", tools=TOOLS)
p.scatter(predicted, (predicted - Y),x="jjj", marker="o", color="#80B1D3", line_width=3)
p.title.align = "center"
p.xaxis.axis_label = "Predicted"
p.xaxis.axis_label_text_color = "#aa6666"
#p.xaxis.axis_label_standoff = 30
p.xaxis.major_tick_line_color = "firebrick"
p.xaxis.major_tick_line_width = 3
p.xaxis.minor_tick_line_color = "orange"
p.yaxis.axis_label = "Residuals"
p.yaxis.axis_label_text_font_style = "italic"
p.yaxis.axis_label_text_color = "#aa6666"
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
#p.line([2,38], [0, 0], line_dash="4 4", line_width=2, color='red')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="82cd6ae1-a9f9-48d6-8c27-bc285ef56182"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#82cd6ae1-a9f9-48d6-8c27-bc285ef56182").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("82cd6ae1-a9f9-48d6-8c27-bc285ef56182");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '82cd6ae1-a9f9-48d6-8c27-bc285ef56182' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d8d013cf-5d70-4f40-9816-a51dabbb4db2":{"roots":{"references":[{"attributes":{"plot":{"id":"d13328dc-de0f-4ef1-b96e-ff2d7a7f2f18","subtype":"Figure","type":"Plot"}},"id":"dbbf285a-3ccf-4beb-9cad-7336705cb96d","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"df6e733c-6a38-490a-a6bf-5f8c6510b26c","type":"Circle"},{"attributes":{"plot":{"id":"d13328dc-de0f-4ef1-b96e-ff2d7a7f2f18","subtype":"Figure","type":"Plot"}},"id":"ce101ff8-fbed-4eda-a14e-145d94d694c9","type":"UndoTool"},{"attributes":{"plot":{"id":"d13328dc-de0f-4ef1-b96e-ff2d7a7f2f18","subtype":"Figure","type":"Plot"},"ticker":{"id":"17039ed0-a55c-43f3-823e-1b342e90e47b","type":"BasicTicker"}},"id":"0a6387d5-f84d-4888-9b30-4c670f103159","type":"Grid"},{"attributes":{},"id":"5922175f-7044-420e-8d09-05dc05d77b64","type":"BasicTicker"},{"attributes":{"plot":{"id":"d13328dc-de0f-4ef1-b96e-ff2d7a7f2f18","subtype":"Figure","type":"Plot"}},"id":"cf700f1e-8861-41c7-91d9-269b4d68c1b5","type":"SaveTool"},{"attributes":{"overlay":{"id":"6781bdc9-2a23-41e7-b081-7871bdd3cafc","type":"BoxAnnotation"},"plot":{"id":"d13328dc-de0f-4ef1-b96e-ff2d7a7f2f18","subtype":"Figure","type":"Plot"}},"id":"56cb4212-74ac-41e2-8e46-ef484adf13fe","type":"BoxZoomTool"},{"attributes":{"axis_label":"Residuals","axis_label_text_color":{"value":"#aa6666"},"formatter":{"id":"baa46305-6ee4-43c2-aad5-2c90fe70e9f7","type":"BasicTickFormatter"},"plot":{"id":"d13328dc-de0f-4ef1-b96e-ff2d7a7f2f18","subtype":"Figure","type":"Plot"},"ticker":{"id":"5922175f-7044-420e-8d09-05dc05d77b64","type":"BasicTicker"}},"id":"8c69c3ae-08f9-49b3-914d-ee1bb2220353","type":"LinearAxis"},{"attributes":{"overlay":{"id":"93da11b6-68f2-4c5d-96ea-02e48199a5ab","type":"PolyAnnotation"},"plot":{"id":"d13328dc-de0f-4ef1-b96e-ff2d7a7f2f18","subtype":"Figure","type":"Plot"}},"id":"67bfdbe7-75eb-43f7-8e47-a07c0bd544df","type":"PolySelectTool"},{"attributes":{"callback":null},"id":"667000cf-895b-473f-9a53-d096071a3ad1","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"56cb4212-74ac-41e2-8e46-ef484adf13fe","type":"BoxZoomTool"},{"id":"c53047d0-c563-4e1e-8da3-afb9c472a504","type":"BoxSelectTool"},{"id":"ab41f0cf-e6de-4298-bbd8-c6b24d742b5e","type":"CrosshairTool"},{"id":"2a1754e1-2158-4728-b9c7-9dd26097e6c6","type":"ResizeTool"},{"id":"38c4334a-4ed2-4205-a4fd-25c6cf2ef085","type":"ResetTool"},{"id":"927bdcbc-22bd-4f79-b426-2303fe8652f7","type":"LassoSelectTool"},{"id":"dbbf285a-3ccf-4beb-9cad-7336705cb96d","type":"PanTool"},{"id":"cf700f1e-8861-41c7-91d9-269b4d68c1b5","type":"SaveTool"},{"id":"67bfdbe7-75eb-43f7-8e47-a07c0bd544df","type":"PolySelectTool"},{"id":"201760aa-cc2b-4803-92f5-35f467b2e724","type":"TapTool"},{"id":"31aedf83-6659-47f0-9df7-73899f3b13e0","type":"WheelZoomTool"},{"id":"ce101ff8-fbed-4eda-a14e-145d94d694c9","type":"UndoTool"}]},"id":"586c9472-7ce1-4052-b4fd-0c8a54ad8a05","type":"Toolbar"},{"attributes":{"plot":{"id":"d13328dc-de0f-4ef1-b96e-ff2d7a7f2f18","subtype":"Figure","type":"Plot"}},"id":"31aedf83-6659-47f0-9df7-73899f3b13e0","type":"WheelZoomTool"},{"attributes":{"fill_color":{"value":"#80B1D3"},"line_color":{"value":"#80B1D3"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"5cc530bd-979d-4005-8690-3811980501fc","type":"Circle"},{"attributes":{"plot":{"id":"d13328dc-de0f-4ef1-b96e-ff2d7a7f2f18","subtype":"Figure","type":"Plot"}},"id":"38c4334a-4ed2-4205-a4fd-25c6cf2ef085","type":"ResetTool"},{"attributes":{"align":"center","plot":null,"text":"Residual plot on the training data"},"id":"5850b467-1b96-42bb-8f85-53f218aa765e","type":"Title"},{"attributes":{},"id":"baa46305-6ee4-43c2-aad5-2c90fe70e9f7","type":"BasicTickFormatter"},{"attributes":{"callback":null,"overlay":{"id":"db0ea44f-c9a6-40e9-999b-1cd9f76938f1","type":"PolyAnnotation"}, ...

# %% [markdown]
# ## Pipeline

# %% [markdown]
# The best to deliver the model by pipeline the operation then at deployment can be done in one model.

# %% [markdown]
#   I used two ways to check the pipeline so any one can be fine

# %%
# Use Pipeline
# ANOVA 
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, f_regression
anova_filter = SelectKBest(f_regression, k=8)
LR = BayesianRidge(lambda_1 = 1.0, lambda_2 = -1.0, alpha_1 = -1.0, alpha_2=-1.0)
anova_LinReg = Pipeline([('scaler_Input',scaler), ('anova', anova_filter), ('LinReg', LR)])
# You can set the parameters using the names issued
# For instance, fit using a k of 10 in the SelectKBest
anova_LinReg.set_params(anova__k=8).fit(new_data, Y)
prediction = anova_LinReg.predict(new_data)
print anova_LinReg.score(new_data, Y)                        
# getting the selected features chosen by anova_filter
results = cross_validation.cross_val_score(anova_LinReg, new_data, Y, cv=kfold, scoring=scoring)
print 'Scoring according to mean_squared_error'
print results
print '\n Mean      Standard deviation'
print("%.2f      %.2f" % (results.mean(), results.std()))
print anova_LinReg.named_steps['anova'].get_support()
r_squared = r2_score(Y, prediction, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# 0.608788633249
# Scoring according to mean_squared_error
# [ -98.55007813 -105.87789329  -93.15450484 -130.87963641 -142.65049938
#   -92.06916312 -126.95824     -97.43954675 -129.69391608 -112.72315145]
#
#  Mean      Standard deviation
# -113.00      17.34
# [ True  True  True  True  True  True  True  True]
# R-squared =  0.608788633249

# %%
# Using make_pipeline
from sklearn.pipeline import make_pipeline

# ANOVA SVM-C
# 1) anova filter, take 3 best ranked features
anova_filter = SelectKBest(f_regression, k=8)
anova_BayesianRidge = make_pipeline(scaler, anova_filter, LR)
anova_BayesianRidge.fit(new_data, Y)
prediction = anova_BayesianRidge.predict(new_data)
r_squared = r2_score(Y, prediction, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# R-squared =  0.608788633249

# %% [markdown]
# ### Save the Pipeline model for developement

# %%
# save the model scaler to the desk
from sklearn.externals import joblib
joblib.dump(anova_BayesianRidge, 'anova_BayesianRidge.pkl')
# Out:
# ['anova_BayesianRidge.pkl',
#  'anova_BayesianRidge.pkl_01.npy',
#  'anova_BayesianRidge.pkl_02.npy',
#  'anova_BayesianRidge.pkl_03.npy',
#  'anova_BayesianRidge.pkl_04.npy',
#  'anova_BayesianRidge.pkl_05.npy',
#  'anova_BayesianRidge.pkl_06.npy']

# %%
# Test the model if it is work
anova_BayesianRidgeTest = joblib.load('anova_BayesianRidge.pkl')
NewPred = anova_BayesianRidgeTest.predict(new_data)
print " =================================================================>>>>> done"
r_squared = r2_score(Y, NewPred, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
#  =================================================================>>>>> done
# R-squared =  0.608788633249

# %%
# test on single data point, randomly choose point number 55
print 'Point of training data before normalization\n',new_data[55]
print '\nThe read target of the data = ', Y[55]
NewPred = anova_BayesianRidgeTest.predict([new_data[55]])
print '\nThe Predicted target of the data = ', NewPred
# Out:
# Point of training data before normalization
# [ 389.9  189.     0.   145.9   22.   944.7  755.8   91. ]
#
# The read target of the data =  82.5992248
#
# The Predicted target of the data =  [ 70.66569219]

# %% [markdown]
# ## Conclusion
