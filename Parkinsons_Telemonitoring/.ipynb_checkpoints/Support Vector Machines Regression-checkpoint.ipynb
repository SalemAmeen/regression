# %% [markdown]
# Salem Ameen, PhD student at Salford University
#
# ### Parkinsons Telemonitoring Data Set
#
# Support Vector Machines Regression

# %% [markdown]
# # Import the Libraries

# %%
import numpy as np
import pandas
from numpy import *
import time
import sys
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import feature_selection
from sklearn.svm import SVR
from sklearn.learning_curve import learning_curve, validation_curve
from sklearn.cross_validation import cross_val_predict
from sklearn import metrics, grid_search, cross_validation
from IPython.display import set_matplotlib_formats
from bokeh.plotting import figure, show, output_notebook
from sklearn.grid_search import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import r2_score
from bokeh.layouts import gridplot
output_notebook()
set_matplotlib_formats('png', 'pdf')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (6, 6)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="bd006a69-a145-42db-ba1f-7569251353a0">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Load data

# %% [markdown]
# In the previous file we have not change the data as there is no missing value or add any new parameters so it can be downloaded from the web directly.

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/parkinsons/telemonitoring/parkinsons_updrs.data'
data = pd.read_csv(url)
M_UPDRS = data['motor_UPDRS']
data = data.drop('motor_UPDRS', 1)
data = data.drop('total_UPDRS', 1)
from sklearn import preprocessing
dataset = data.values
X = dataset[:,0:20].astype(float)
Y = M_UPDRS.values
MEDV = M_UPDRS
feature_cols = list(data.columns.values)
print 'Number of examples',len(X)
# Out:
# Number of examples 5875

# %%
# Make developement dataset for genrilization and final testing
from sklearn.cross_validation import train_test_split
# Extracting 20% testing data
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.20, random_state=0)
X = X_train
Y = y_train
new_data      = X_train
new_test_data = X_test
print 'Number of training examples',len(X_train)
print 'Number of validation examples',len(X_test)
# Out:
# Number of training examples 4700
# Number of validation examples 1175

# %% [markdown]
# # Set the parameters for cross validation

# %%
num_folds = 10
num_instances = len(X)
seed = 7
kfold = cross_validation.KFold(n=num_instances, n_folds=num_folds, random_state=seed)

# %% [markdown]
#  # Set the parameters for bias-variance dilemma

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %% [markdown]
# # Preprocessing the data and save both the model and preprocessed data

# %%
# According to the nature of the data spasity and there is outliter RobustScaler class is recomandit 
# but when I tried both of them the result seems is same
from sklearn.preprocessing import StandardScaler
scaler = preprocessing.StandardScaler().fit(X_train)

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test) # use same transform for testing data
X = X_train

# %%
# save transformed data
np.save('./data/X_train', X_train)
np.save('./data/y_train', y_train)
np.save('./data/X_test', X_test)
np.save('./data/y_test', y_test)

# %%
# save the model scaler to the desk
from sklearn.externals import joblib
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl', 'scaler.pkl_01.npy', 'scaler.pkl_02.npy', 'scaler.pkl_03.npy']

# %%
# Test the model if it is work
scalerTest = joblib.load('scaler.pkl')
new_data_scaled = scalerTest.transform(new_test_data)
print " =================================================================>>>>> done"
print new_data_scaled
# Out:
#  =================================================================>>>>> done
# [[ 1.56638181  0.35745305  1.45347266 ...,  0.10654841  0.65433521
#    0.34236736]
#  [ 1.08416036  0.69933936 -0.68800744 ...,  1.03217561  1.35448669
#    2.09798914]
#  [ 0.11971746 -0.66820588  1.45347266 ..., -0.37688437  0.55760283
#   -0.48973219]
#  ...,
#  [ 1.56638181  0.35745305  1.45347266 ...,  1.28447486 -0.04104284
#    0.85186293]
#  [-1.24657665 -0.21235747 -0.68800744 ...,  0.08110981 -0.87695661
#    0.46320715]
#  [ 0.11971746 -0.66820588  1.45347266 ...,  0.38418689  0.68227388
#    0.30398295]]

# %% [markdown]
# # 1. SVR Regression

# %% [markdown]
# Support Vector Machines (SVM) were developed for binary classification. The technique has been extended for the prediction real-valued problems called Support Vector Regression (SVR). Like the classification example, SVR is built upon the LIBSVM library.

# %% [markdown]
# ## Validation curve

# %% [markdown]
# choosing multiple hyperparameters of an estimator

# %%
from sklearn.svm import SVR
estimator = SVR()
estimator.get_params().keys()
# Out:
# ['kernel',
#  'C',
#  'verbose',
#  'degree',
#  'epsilon',
#  'shrinking',
#  'max_iter',
#  'tol',
#  'cache_size',
#  'coef0',
#  'gamma']

# %%
# For parametr alpha
#param_range = np.logspace(-10.0, 10.0)
#param_range = np.linspace(1,50,100)
param_range = np.arange(1,50) # generate integer numbers

train_scores, test_scores = validation_curve(
    SVR(), X, Y, param_name="C", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with SVR")
plt.xlabel("C")
plt.ylabel("Score")
plt.ylim(0.4, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# more that 5 is the best of C

# %%
# For parametr alpha
#param_range = np.logspace(-10.0, 10.0)
#param_range = np.linspace(1,50,100)
param_range = np.arange(0,10) # generate integer numbers

train_scores, test_scores = validation_curve(
    SVR(), X, Y, param_name="epsilon", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with SVR")
plt.xlabel("epsilon")
plt.ylabel("Score")
plt.ylim(0.4, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# epsilon less than  1 is the best (default=0.1)

# %% [markdown]
# ## Grid search and/or Random search to determine best compination of parameters

# %%
# Utility function to report optimal parameters
from operator import itemgetter
def report(grid_scores, n_top=5):
    params = None
    top_scores = sorted(grid_scores, key=itemgetter(1), reverse=True)[:n_top]
    for i, score in enumerate(top_scores):
        print("Parameters with rank: {0}".format(i + 1))
        print("Mean validation score: {0:.4f} (std: {1:.4f})".format(
              score.mean_validation_score, np.std(score.cv_validation_scores)))
        print("Parameters: {0}".format(score.parameters))
        print("")
        
        if params == None:
            params = score.parameters
    
    return params

# The most common value for the max number of features to look at in each split is sqrt(# of features)
sqrtfeat = np.sqrt(X.shape[1]) 
grid_test1 = { "C"      : np.linspace(1,50,100) ,
                "kernel"      : [ "linear", "rbf", "poly", "sigmoid"]}

# Large randomized test using max_depth to control tree size (5000 possible combinations)
random_test1 = { "C"      : [1,5,10],
                "kernel"      : [ "linear", "rbf", "poly", "sigmoid"]}


forest = SVR()

print "Hyperparameter optimization using GridSearchCV..."
grid_search = GridSearchCV(forest, grid_test1, n_jobs=-1, cv=num_folds)
grid_search.fit(X, Y)
best_params_from_grid_search = report(grid_search.grid_scores_)
print '+++++++++++++++++++++++++++++++++++++++++++++++'
print "Hyperparameter optimization using RandomizedSearchCV"
grid_search = RandomizedSearchCV(forest, random_test1, n_jobs=-1, cv=num_folds, n_iter=5)
grid_search.fit(X, Y)
best_params_from_rand_search1 = report(grid_search.grid_scores_)
# Out:
# Hyperparameter optimization using GridSearchCV...
# Parameters with rank: 1
# Mean validation score: 0.8056 (std: 0.0196)
# Parameters: {'kernel': 'rbf', 'C': 50.0}
#
# Parameters with rank: 2
# Mean validation score: 0.8053 (std: 0.0196)
# Parameters: {'kernel': 'rbf', 'C': 49.505050505050505}
#
# Parameters with rank: 3
# Mean validation score: 0.8050 (std: 0.0196)
# Parameters: {'kernel': 'rbf', 'C': 49.01010101010101}
#
# Parameters with rank: 4
# Mean validation score: 0.8047 (std: 0.0196)
# Parameters: {'kernel': 'rbf', 'C': 48.515151515151516}
#
# Parameters with rank: 5
# Mean validation score: 0.8043 (std: 0.0196)
# Parameters: {'kernel': 'rbf', 'C': 48.020202020202021}
#
# +++++++++++++++++++++++++++++++++++++++++++++++
# Hyperparameter optimization using RandomizedSearchCV
# Parameters with rank: 1
# Mean validation score: 0.4925 (std: 0.0180)
# Parameters: {'kernel': 'rbf', 'C': 1}
#
# Parameters with rank: 2
# Mean validation score: 0.1892 (std: 0.0255)
# Parameters: {'kernel': 'linear', 'C': 5}
#
# Parameters with rank: 3
# Mean validation score: 0.1891 (std: 0.0255)
# Parameters: {'kernel': 'linear', 'C': 10}
#
# Parameters with rank: 4
# Mean validation score: -0.0050 (std: 0.0064)
# Parameters: {'kernel': 'sigmoid', 'C': 1}
#
# Parameters with rank: 5
# Mean validation score: -0.0050 (std: 0.0064)
# Parameters: {'kernel': 'sigmoid', 'C': 5}

# %% [markdown]
# Parameters: {'kernel': 'rbf', 'C': 50.0}

# %%
# Value of gamma on rbf
#param_range = np.logspace(-10.0, 10.0)
param_range = np.linspace(0,10,100)
#param_range = np.arange(0,10) # generate integer numbers

train_scores, test_scores = validation_curve(
    SVR(kernel="rbf", C=50), X, Y, param_name="gamma", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with SVR")
plt.xlabel("gamma")
plt.ylabel("Score")
plt.ylim(0.4, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %%
# Utility function to report optimal parameters
from operator import itemgetter
def report(grid_scores, n_top=5):
    params = None
    top_scores = sorted(grid_scores, key=itemgetter(1), reverse=True)[:n_top]
    for i, score in enumerate(top_scores):
        print("Parameters with rank: {0}".format(i + 1))
        print("Mean validation score: {0:.4f} (std: {1:.4f})".format(
              score.mean_validation_score, np.std(score.cv_validation_scores)))
        print("Parameters: {0}".format(score.parameters))
        print("")
        
        if params == None:
            params = score.parameters
    
    return params

# The most common value for the max number of features to look at in each split is sqrt(# of features)
sqrtfeat = np.sqrt(X.shape[1]) 
grid_test1 = { "C"        : np.linspace(1,20,10),
             "gamma"      : np.linspace(0,20,10)}

# Large randomized test using max_depth to control tree size (5000 possible combinations)
random_test1 = { "C"         : [1,5,10,50],
                "gamma"      : [0,1,2]}


forest = SVR()

print "Hyperparameter optimization using GridSearchCV..."
grid_search = GridSearchCV(forest, grid_test1, n_jobs=-1, cv=num_folds)
grid_search.fit(X, Y)
best_params_from_grid_search = report(grid_search.grid_scores_)
print '+++++++++++++++++++++++++++++++++++++++++++++++'
print "Hyperparameter optimization using RandomizedSearchCV"
grid_search = RandomizedSearchCV(forest, random_test1, n_jobs=-1, cv=num_folds, n_iter=5)
grid_search.fit(X, Y)
best_params_from_rand_search1 = report(grid_search.grid_scores_)
# Out:
# Hyperparameter optimization using GridSearchCV...
# Parameters with rank: 1
# Mean validation score: 0.7712 (std: 0.0183)
# Parameters: {'C': 20.0, 'gamma': 0.0}
#
# Parameters with rank: 2
# Mean validation score: 0.7657 (std: 0.0185)
# Parameters: {'C': 17.888888888888889, 'gamma': 0.0}
#
# Parameters with rank: 3
# Mean validation score: 0.7594 (std: 0.0184)
# Parameters: {'C': 15.777777777777779, 'gamma': 0.0}
#
# Parameters with rank: 4
# Mean validation score: 0.7519 (std: 0.0185)
# Parameters: {'C': 13.666666666666668, 'gamma': 0.0}
#
# Parameters with rank: 5
# Mean validation score: 0.7430 (std: 0.0182)
# Parameters: {'C': 11.555555555555555, 'gamma': 0.0}
#
# +++++++++++++++++++++++++++++++++++++++++++++++
# Hyperparameter optimization using RandomizedSearchCV
# Parameters with rank: 1
# Mean validation score: 0.7976 (std: 0.0196)
# Parameters: {'C': 50, 'gamma': 1}
#
# Parameters with rank: 2
# Mean validation score: 0.7964 (std: 0.0178)
# Parameters: {'C': 10, 'gamma': 1}
#
# Parameters with rank: 3
# Mean validation score: 0.7680 (std: 0.0176)
# Parameters: {'C': 5, 'gamma': 1}
#
# Parameters with rank: 4
# Mean validation score: 0.5950 (std: 0.0229)
# Parameters: {'C': 10, 'gamma': 2}
#
# Parameters with rank: 5
# Mean validation score: 0.2173 (std: 0.0118)
# Parameters: {'C': 1, 'gamma': 2}

# %% [markdown]
# ## Learning Curve

# %% [markdown]
# In essence, what we’re doing it training the exact same model with increasingly large fractions of our total training data, and plotting the error of the training and test sets at each step.

# %%
from sklearn.svm import SVR
model = SVR(kernel = "linear", C = 5.0 )
title = "Learning Curves (SVR Refression)"
cv = cross_validation.ShuffleSplit(X.shape[0], n_iter=100,
                                   test_size=0.2, random_state=0)
plot_learning_curve(model, title, X, Y, ylim=(0.2, 1.01), cv=cv, n_jobs=-1)
plt.show()

# %%
# More data from learning curve to show the process of building the model
train_sizes, train_scores, valid_scores = learning_curve(
     model, X, Y, train_sizes=[50, 80, 110], cv=cv, n_jobs=4)

print 'train_sizes = ', train_sizes

print ' training scores'
print ' 50 training sizees'
print train_scores[0].mean(),'±',train_scores[0].std()
print ' 80 training sizees'
print train_scores[1].mean(),'±',train_scores[1].std()
print ' 110 training sizees'
print train_scores[2].mean(),'±',train_scores[2].std()

print '\n validation scores'
print ' 50 validation scores'
print valid_scores[0].mean(),'±',valid_scores[0].std()
print ' 80 validation scores'
print valid_scores[1].mean(),'±',valid_scores[1].std()
print ' 110 validation scores'
print valid_scores[2].mean(),'±',valid_scores[2].std()
# Out:
# train_sizes =  [ 50  80 110]
#  training scores
#  50 training sizees
# 0.325788597447 ± 0.120138567359
#  80 training sizees
# 0.273716255912 ± 0.0918950671394
#  110 training sizees
# 0.269599069584 ± 0.0816001681067
#
#  validation scores
#  50 validation scores
# -0.335346515693 ± 0.321728611443
#  80 validation scores
# -0.190256208126 ± 0.251100165147
#  110 validation scores
# -0.0708405669757 ± 0.14285197726

# %% [markdown]
# ## Cross validation

# %%
scoring = 'mean_squared_error'
results = cross_validation.cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
print 'Scoring according to mean_squared_error'
print results
print '\n Mean      Standard deviation'
print("%.2f      %.2f" % (results.mean(), results.std()))
## Fit the model
model.fit(X,Y)
# Out:
# Scoring according to mean_squared_error
# [-49.21170771 -53.69013004 -49.90038651 -54.73696734 -53.48003215
#  -56.82197745 -54.5633996  -52.32751832 -59.0279052  -52.55252137]
#
#  Mean      Standard deviation
# -53.63      2.79
# SVR(C=5.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# ## Coefficients Of Determination {Calculating R^2}
#
# R^2, Close to one is better

# %%
predicted = cross_val_predict(model, X, Y, cv=kfold)
r_squared = r2_score(Y, predicted, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# R-squared =  0.190541372824

# %% [markdown]
# ## Residual Plot

# %%
predicted = cross_val_predict(model, X, Y, cv=kfold)
fig, ax = plt.subplots()
ax.scatter(Y, predicted)
ax.plot([Y.min(), Y.max()], [Y.min(), Y.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()

# %%
# Plotining using bokeh
#TOOLS = [BoxSelectTool(), HoverTool()]
#TOOLS = 'hover,box_zoom,box_select,crosshair,resize,reset,SVR_select,pan,save,poly_select,tap,wheel_zoom,undo'
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,lasso_select,pan,save,poly_select,tap,wheel_zoom,undo'
p = figure(plot_width=500, plot_height=500, tools=TOOLS)
p.scatter(Y, predicted,x="jjj", marker="o", color="#80B1D3", line_width=3)
p.title.align = "center"
p.xaxis.axis_label = "Measured"
p.xaxis.axis_label_text_color = "#aa6666"
#p.xaxis.axis_label_standoff = 30
p.xaxis.major_tick_line_color = "firebrick"
p.xaxis.major_tick_line_width = 3
p.xaxis.minor_tick_line_color = "orange"
p.yaxis.axis_label = "Predicted"
p.yaxis.axis_label_text_font_style = "italic"
p.yaxis.axis_label_text_color = "#aa6666"
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
#p.line([Y.min(), Y.max()], [Y.min(), Y.max()], line_dash="4 4", line_width=2, color='red')

# create a new plot with the toolbar below
# line_dash="4 4", line_width=2, color='red'
p.line([Y.min(), Y.max()], [Y.min(), Y.max()], line_dash="4 4", line_width=2, line_color="black")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="6db2a5ae-0ac5-488f-aa2e-d59ce28c2768"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#6db2a5ae-0ac5-488f-aa2e-d59ce28c2768").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6db2a5ae-0ac5-488f-aa2e-d59ce28c2768");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6db2a5ae-0ac5-488f-aa2e-d59ce28c2768' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"80da2734-56dc-4e6d-b361-e546c2541ba1":{"roots":{"references":[{"attributes":{"plot":{"id":"ef339620-9ca3-4744-89aa-ac77aad4ea9c","subtype":"Figure","type":"Plot"}},"id":"06c25689-6203-4b69-b1db-204685913c0f","type":"UndoTool"},{"attributes":{},"id":"ffb505b4-a5bf-44bc-9240-18b28b885e4d","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":
793,21.127873565586103,22.062486851257166,19.06127767771089,18.908757042855818,20.910920504090008,17.05334478501717,13.429214849334347,16.508219960680833,12.41331300647351,15.415332488484685,23.2025557197116,24.11966570905306,9.671788580831777,23.715690742721804,25.832454011098406,26.690900727936434,18.345199352500586,24.781601943010564,17.227925555812917,13.813901408177774,22.305271594486086,24.140306501839724,28.234230749973523,20.917761808359476,23.14899150756631,11.006788130483631,20.67819989296441,16.689330097923765,16.829545213443183,25.448568837016143,15.88446197193577,18.554487087785454,11.599296742761346,26.381259381881073,18.449651705661985,24.360049473949864,25.05795056644653,27.473854484736663,26.733498217964623,22.45445723877446,16.136131886356264,18.354405169123872,17.722249907443665,14.826253161557153,23.07637824922483,14.215333723352371,19.68521155971768,20.775237702746285,17.755904573597,17.517526658824366,18.357078249641813,15.884407241223556,25.35266750464601,17.79581367498686,25.005294020431815,14.960113633289012,21.92027184480091,24.14924999451686,21.148757493422252,20.177515991458506,24.95490385461491,17.08996956422444,28.541276605087845,30.95838012739248,20.44281509657266,13.741749792900848,19.87620248793938,21.74542923291283,21.524960204517626,18.111582237204434,27.720848646486015,12.78109560504273,18.163956141631143,23.565128540705324,17.984979670003778,16.98794237120098,20.8391874487026,15.0132854976377,23.448443250712984,17.566094826565365,17.963278034202308,23.261504615240685,24.103138263418924,25.590199336728098,19.404723566649526,20.80026883890621,18.630006266002027,19.60576764624178,12.932512927387759,22.35872693747764,27.632264436068183,29.2250069114497,24.49476374161753,21.3501135254 ...

# %% [markdown]
# ## Pipeline

# %% [markdown]
# The best to deliver the model by pipeline the operation then at deployment can be done in one model.

# %% [markdown]
#   I used two ways to check the pipeline so any one can be fine

# %%
# Use Pipeline
# ANOVA 
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, f_regression
anova_filter = SelectKBest(f_regression, k=13)
LR = SVR(kernel = "linear", C = 5.0 )
anova_LinReg = Pipeline([('scaler_Input',scaler), ('anova', anova_filter), ('LinReg', LR)])
# You can set the parameters using the names issued
# For instance, fit using a k of 10 in the SelectKBest
anova_LinReg.set_params(anova__k=13).fit(new_data, Y)
prediction = anova_LinReg.predict(new_data)
print anova_LinReg.score(new_data, Y)                        
# getting the selected features chosen by anova_filter
results = cross_validation.cross_val_score(anova_LinReg, new_data, Y, cv=kfold, scoring=scoring)
print 'Scoring according to mean_squared_error'
print results
print '\n Mean      Standard deviation'
print("%.2f      %.2f" % (results.mean(), results.std()))
print anova_LinReg.named_steps['anova'].get_support()
r_squared = r2_score(Y, prediction, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# 0.161701922174
# Scoring according to mean_squared_error
# [-50.68000572 -55.92566961 -53.26306189 -57.99873715 -56.53160663
#  -58.12791621 -55.25628667 -54.89200536 -61.82786188 -54.25386712]
#
#  Mean      Standard deviation
# -55.88      2.89
# [ True  True False False  True False False False False  True  True  True
#   True  True  True False  True  True  True  True]
# R-squared =  0.161701922174

# %%
# Using make_pipeline
from sklearn.pipeline import make_pipeline

# ANOVA SVM-C
# 1) anova filter, take 3 best ranked features
anova_filter = SelectKBest(f_regression, k=13)
anova_SVR = make_pipeline(scaler, anova_filter, LR)
anova_SVR.fit(new_data, Y)
prediction = anova_SVR.predict(new_data)
r_squared = r2_score(Y, prediction, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# R-squared =  0.161701922174

# %% [markdown]
# ### Save the Pipeline model for developement

# %%
# save the model scaler to the desk
from sklearn.externals import joblib
joblib.dump(anova_SVR, 'anova_SVR.pkl')
# Out:
# ['anova_SVR.pkl',
#  'anova_SVR.pkl_01.npy',
#  'anova_SVR.pkl_02.npy',
#  'anova_SVR.pkl_03.npy',
#  'anova_SVR.pkl_04.npy',
#  'anova_SVR.pkl_05.npy',
#  'anova_SVR.pkl_06.npy',
#  'anova_SVR.pkl_07.npy',
#  'anova_SVR.pkl_08.npy',
#  'anova_SVR.pkl_09.npy',
#  'anova_SVR.pkl_10.npy',
#  'anova_SVR.pkl_11.npy',
#  'anova_SVR.pkl_12.npy',
#  'anova_SVR.pkl_13.npy',
#  'anova_SVR.pkl_14.npy',
#  'anova_SVR.pkl_15.npy']

# %%
# Test the model if it is work
anova_SVRTest = joblib.load('anova_SVR.pkl')
NewPred = anova_SVRTest.predict(new_data)
print " =================================================================>>>>> done"
r_squared = r2_score(Y, NewPred, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
#  =================================================================>>>>> done
# R-squared =  0.161701922174

# %%
# test on single data point, randomly choose point number 55
print 'Point of training data before normalization\n',new_data[55]
print '\nThe read target of the data = ', Y[55]
NewPred = anova_SVRTest.predict([new_data[55]])
print '\nThe Predicted target of the data = ', NewPred
# Out:
# Point of training data before normalization
# [  2.60000000e+01   4.90000000e+01   0.00000000e+00   3.17820000e+01
#    1.18000000e-02   1.27000000e-04   7.05000000e-03   6.00000000e-03
#    2.11500000e-02   5.81300000e-02   5.27000000e-01   3.21500000e-02
#    3.45600000e-02   4.39900000e-02   9.64400000e-02   3.43700000e-02
#    1.74210000e+01   6.30040000e-01   7.72870000e-01   4.15090000e-01]
#
# The read target of the data =  25.706
#
# The Predicted target of the data =  [ 17.84431632]

# %% [markdown]
# ## Conclusion
