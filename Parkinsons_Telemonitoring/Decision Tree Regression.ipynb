# %% [markdown]
# Salem Ameen, PhD student at Salford University
#
# ### Parkinsons Telemonitoring Data Set
#
# Decision trees Regression

# %% [markdown]
# # Import the Libraries

# %%
import numpy as np
import pandas
from numpy import *
import time
import sys
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import feature_selection
from sklearn.tree import DecisionTreeRegressor
from sklearn.learning_curve import learning_curve, validation_curve
from sklearn.cross_validation import cross_val_predict
from sklearn import metrics, grid_search, cross_validation
from IPython.display import set_matplotlib_formats
from bokeh.plotting import figure, show, output_notebook
from sklearn.grid_search import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import r2_score
from bokeh.layouts import gridplot
output_notebook()
set_matplotlib_formats('png', 'pdf')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (6, 6)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9a182fdd-780c-4f7b-8b9d-4928fada0127">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Load data

# %% [markdown]
# In the previous file we have not change the data as there is no missing value or add any new parameters so it can be downloaded from the web directly.

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/parkinsons/telemonitoring/parkinsons_updrs.data'
data = pd.read_csv(url)
M_UPDRS = data['motor_UPDRS']
data = data.drop('motor_UPDRS', 1)
data = data.drop('total_UPDRS', 1)
from sklearn import preprocessing
dataset = data.values
X = dataset[:,0:20].astype(float)
Y = M_UPDRS.values
MEDV = M_UPDRS
feature_cols = list(data.columns.values)
print 'Number of examples',len(X)
# Out:
# Number of examples 5875

# %%
# Make developement dataset for genrilization and final testing
from sklearn.cross_validation import train_test_split
# Extracting 20% testing data
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.20, random_state=0)
X = X_train
Y = y_train
new_data      = X_train
new_test_data = X_test
print 'Number of training examples',len(X_train)
print 'Number of validation examples',len(X_test)
# Out:
# Number of training examples 4700
# Number of validation examples 1175

# %% [markdown]
# Number of training data is very small so we need to use cross validation instead of spareate another validation data.

# %% [markdown]
# From the previous visulization the data has no missing value but has many outlier and some sparisty

# %% [markdown]
# # Set the parameters for cross validation

# %%
num_folds = 10
num_instances = len(X)
seed = 7
kfold = cross_validation.KFold(n=num_instances, n_folds=num_folds, random_state=seed)

# %% [markdown]
#  # Set the parameters for bias-variance dilemma

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %% [markdown]
# # Preprocessing the data and save both the model and preprocessed data

# %%
# According to the nature of the data spasity and there is outliter RobustScaler class is recomandit 
# but when I tried both of them the result seems is same
from sklearn.preprocessing import StandardScaler
scaler = preprocessing.StandardScaler().fit(X_train)

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test) # use same transform for testing data
X = X_train

# %%
# save transformed data
np.save('./data/X_train', X_train)
np.save('./data/y_train', y_train)
np.save('./data/X_test', X_test)
np.save('./data/y_test', y_test)

# %%
# save the model scaler to the desk
from sklearn.externals import joblib
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl', 'scaler.pkl_01.npy', 'scaler.pkl_02.npy', 'scaler.pkl_03.npy']

# %%
# Test the model if it is work
scalerTest = joblib.load('scaler.pkl')
new_data_scaled = scalerTest.transform(new_test_data)
print " =================================================================>>>>> done"
print new_data_scaled
# Out:
#  =================================================================>>>>> done
# [[ 1.56638181  0.35745305  1.45347266 ...,  0.10654841  0.65433521
#    0.34236736]
#  [ 1.08416036  0.69933936 -0.68800744 ...,  1.03217561  1.35448669
#    2.09798914]
#  [ 0.11971746 -0.66820588  1.45347266 ..., -0.37688437  0.55760283
#   -0.48973219]
#  ...,
#  [ 1.56638181  0.35745305  1.45347266 ...,  1.28447486 -0.04104284
#    0.85186293]
#  [-1.24657665 -0.21235747 -0.68800744 ...,  0.08110981 -0.87695661
#    0.46320715]
#  [ 0.11971746 -0.66820588  1.45347266 ...,  0.38418689  0.68227388
#    0.30398295]]

# %% [markdown]
# # 1. DecisionTreeRegressor  with   Regression

# %% [markdown]
# Decision trees or the Classification and Regression Trees (CART as they are know) use the training data to select the best points to split the data in order to minimize a cost metric. The default cost metric for regression decision trees is the mean squared error, specified in the criterion parameter.

# %% [markdown]
# ## Validation curve

# %% [markdown]
# choosing multiple hyperparameters of an estimator

# %%
from sklearn.tree import DecisionTreeRegressor
estimator = DecisionTreeRegressor()
estimator.get_params().keys()
# Out:
# ['presort',
#  'splitter',
#  'max_leaf_nodes',
#  'min_samples_leaf',
#  'min_samples_split',
#  'min_weight_fraction_leaf',
#  'criterion',
#  'random_state',
#  'max_features',
#  'max_depth']

# %%
# For parametr alpha
#param_range = np.logspace(-10.0, 10.0)
#param_range = np.linspace(1,50,100)
param_range = np.arange(1,50) # generate integer numbers

train_scores, test_scores = validation_curve(
    DecisionTreeRegressor(), X, Y, param_name="max_depth", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with DecisionTreeRegressor")
plt.xlabel("max_depth")
plt.ylabel("Score")
plt.ylim(0.4, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# more that 5 is the best of number of K

# %%
# For parametr alpha
#param_range = np.logspace(-10.0, 10.0)
#param_range = np.linspace(1,50,100)
param_range = np.arange(1,10) # generate integer numbers

train_scores, test_scores = validation_curve(
    DecisionTreeRegressor(), X, Y, param_name="min_samples_split", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with DecisionTreeRegressor")
plt.xlabel("min_samples_split")
plt.ylabel("Score")
plt.ylim(0.4, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# min_samples_split =2 (The defualt) is the best

# %%
# For parametr alpha
#param_range = np.logspace(-10.0, 10.0)
#param_range = np.linspace(1,50,100)
param_range = np.arange(1,10) # generate integer numbers

train_scores, test_scores = validation_curve(
    DecisionTreeRegressor(), X, Y, param_name="min_samples_leaf", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with DecisionTreeRegressor")
plt.xlabel("min_samples_leaf")
plt.ylabel("Score")
plt.ylim(0.4, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# min_samples_leaf = 2 is the best

# %% [markdown]
# ## Grid search and/or Random search to determine best compination of parameters

# %%
# Utility function to report optimal parameters
from operator import itemgetter
def report(grid_scores, n_top=5):
    params = None
    top_scores = sorted(grid_scores, key=itemgetter(1), reverse=True)[:n_top]
    for i, score in enumerate(top_scores):
        print("Parameters with rank: {0}".format(i + 1))
        print("Mean validation score: {0:.4f} (std: {1:.4f})".format(
              score.mean_validation_score, np.std(score.cv_validation_scores)))
        print("Parameters: {0}".format(score.parameters))
        print("")
        
        if params == None:
            params = score.parameters
    
    return params

# The most common value for the max number of features to look at in each split is sqrt(# of features)
sqrtfeat = np.sqrt(X.shape[1]) 
grid_test1 = { "max_depth"      : np.arange(1,15),
             "min_samples_split"      : np.arange(1,4),
             "min_samples_leaf"    : np.arange(1,3)}

# Large randomized test using max_depth to control tree size (5000 possible combinations)
random_test1 = { "max_depth"      : [1,10],
                "min_samples_split"      : [ 1,2],
               "min_samples_leaf"   : [1,2]}


forest =  DecisionTreeRegressor()

print "Hyperparameter optimization using GridSearchCV..."
grid_search = GridSearchCV(forest, grid_test1, n_jobs=-1, cv=num_folds)
grid_search.fit(X, Y)
best_params_from_grid_search = report(grid_search.grid_scores_)
print '+++++++++++++++++++++++++++++++++++++++++++++++'
print "Hyperparameter optimization using RandomizedSearchCV"
grid_search = RandomizedSearchCV(forest, random_test1, n_jobs=-1, cv=num_folds, n_iter=5)
grid_search.fit(X, Y)
best_params_from_rand_search1 = report(grid_search.grid_scores_)
# Out:
# Hyperparameter optimization using GridSearchCV...
# Parameters with rank: 1
# Mean validation score: 0.9971 (std: 0.0012)
# Parameters: {'min_samples_split': 3, 'max_depth': 13, 'min_samples_leaf': 1}
#
# Parameters with rank: 2
# Mean validation score: 0.9971 (std: 0.0017)
# Parameters: {'min_samples_split': 2, 'max_depth': 14, 'min_samples_leaf': 1}
#
# Parameters with rank: 3
# Mean validation score: 0.9971 (std: 0.0014)
# Parameters: {'min_samples_split': 2, 'max_depth': 14, 'min_samples_leaf': 2}
#
# Parameters with rank: 4
# Mean validation score: 0.9971 (std: 0.0015)
# Parameters: {'min_samples_split': 3, 'max_depth': 14, 'min_samples_leaf': 1}
#
# Parameters with rank: 5
# Mean validation score: 0.9970 (std: 0.0015)
# Parameters: {'min_samples_split': 2, 'max_depth': 13, 'min_samples_leaf': 1}
#
# +++++++++++++++++++++++++++++++++++++++++++++++
# Hyperparameter optimization using RandomizedSearchCV
# Parameters with rank: 1
# Mean validation score: 0.9930 (std: 0.0013)
# Parameters: {'min_samples_split': 1, 'max_depth': 10, 'min_samples_leaf': 1}
#
# Parameters with rank: 2
# Mean validation score: 0.9928 (std: 0.0015)
# Parameters: {'min_samples_split': 2, 'max_depth': 10, 'min_samples_leaf': 2}
#
# Parameters with rank: 3
# Mean validation score: 0.1831 (std: 0.0280)
# Parameters: {'min_samples_split': 1, 'max_depth': 1, 'min_samples_leaf': 2}
#
# Parameters with rank: 4
# Mean validation score: 0.1831 (std: 0.0280)
# Parameters: {'min_samples_split': 2, 'max_depth': 1, 'min_samples_leaf': 2}
#
# Parameters with rank: 5
# Mean validation score: 0.1831 (std: 0.0280)
# Parameters: {'min_samples_split': 2, 'max_depth': 1, 'min_samples_leaf': 1}

# %% [markdown]
# Best 'min_samples_split': 3, 'max_depth': 7, 'min_samples_leaf': 1

# %% [markdown]
# ## Learning Curve

# %% [markdown]
# In essence, what we’re doing it training the exact same model with increasingly large fractions of our total training data, and plotting the error of the training and test sets at each step.

# %%
from sklearn.tree import DecisionTreeRegressor

model =  DecisionTreeRegressor(min_samples_split = 3, max_depth = 7, min_samples_leaf =1 )
title = "Learning Curves (  DecisionTreeRegressor Refression)"
cv = cross_validation.ShuffleSplit(X.shape[0], n_iter=100,
                                   test_size=0.2, random_state=0)
plot_learning_curve(model, title, X, Y, ylim=(0.2, 1.01), cv=cv, n_jobs=-1)
plt.show()

# %%
# More data from learning curve to show the process of building the model
train_sizes, train_scores, valid_scores = learning_curve(
     model, X, Y, train_sizes=[50, 80, 110], cv=cv, n_jobs=4)

print 'train_sizes = ', train_sizes

print ' training scores'
print ' 50 training sizees'
print train_scores[0].mean(),'±',train_scores[0].std()
print ' 80 training sizees'
print train_scores[1].mean(),'±',train_scores[1].std()
print ' 110 training sizees'
print train_scores[2].mean(),'±',train_scores[2].std()

print '\n validation scores'
print ' 50 validation scores'
print valid_scores[0].mean(),'±',valid_scores[0].std()
print ' 80 validation scores'
print valid_scores[1].mean(),'±',valid_scores[1].std()
print ' 110 validation scores'
print valid_scores[2].mean(),'±',valid_scores[2].std()
# Out:
# train_sizes =  [ 50  80 110]
#  training scores
#  50 training sizees
# 0.983882261083 ± 0.0192316003708
#  80 training sizees
# 0.981755882126 ± 0.0147166070998
#  110 training sizees
# 0.96933955957 ± 0.0335785454218
#
#  validation scores
#  50 validation scores
# -0.133042092531 ± 0.242660208131
#  80 validation scores
# 0.112831222967 ± 0.204220942531
#  110 validation scores
# 0.296368772386 ± 0.172015915511

# %% [markdown]
# ## Cross validation

# %%
scoring = 'mean_squared_error'
results = cross_validation.cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
print 'Scoring according to mean_squared_error'
print results
print '\n Mean      Standard deviation'
print("%.2f      %.2f" % (results.mean(), results.std()))
## Fit the model
model.fit(X,Y)
# Out:
# Scoring according to mean_squared_error
# [-3.25639002 -4.49121994 -3.48764311 -3.46561408 -3.98702597 -3.68512739
#  -4.0276861  -3.56169534 -4.89206088 -4.22298775]
#
#  Mean      Standard deviation
# -3.91      0.49
# DecisionTreeRegressor(criterion='mse', max_depth=7, max_features=None,
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=3,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %% [markdown]
# ## Coefficients Of Determination {Calculating R^2}
#
# R^2, Close to one is better

# %%
predicted = cross_val_predict(model, X, Y, cv=kfold)
r_squared = r2_score(Y, predicted, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# R-squared =  0.94101531054

# %% [markdown]
# ## Residual Plot

# %%
predicted = cross_val_predict(model, X, Y, cv=kfold)
fig, ax = plt.subplots()
ax.scatter(Y, predicted)
ax.plot([Y.min(), Y.max()], [Y.min(), Y.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()

# %%
# Plotining using bokeh
#TOOLS = [BoxSelectTool(), HoverTool()]
#TOOLS = 'hover,box_zoom,box_select,crosshair,resize,reset,DecisionTreeRegressor_select,pan,save,poly_select,tap,wheel_zoom,undo'
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,lasso_select,pan,save,poly_select,tap,wheel_zoom,undo'
p = figure(plot_width=500, plot_height=500, tools=TOOLS)
p.scatter(Y, predicted,x="jjj", marker="o", color="#80B1D3", line_width=3)
p.title.align = "center"
p.xaxis.axis_label = "Measured"
p.xaxis.axis_label_text_color = "#aa6666"
#p.xaxis.axis_label_standoff = 30
p.xaxis.major_tick_line_color = "firebrick"
p.xaxis.major_tick_line_width = 3
p.xaxis.minor_tick_line_color = "orange"
p.yaxis.axis_label = "Predicted"
p.yaxis.axis_label_text_font_style = "italic"
p.yaxis.axis_label_text_color = "#aa6666"
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
#p.line([Y.min(), Y.max()], [Y.min(), Y.max()], line_dash="4 4", line_width=2, color='red')

# create a new plot with the toolbar below
# line_dash="4 4", line_width=2, color='red'
p.line([Y.min(), Y.max()], [Y.min(), Y.max()], line_dash="4 4", line_width=2, line_color="black")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="5e5cf0e5-4ffd-4560-a3a6-62a47a93125b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#5e5cf0e5-4ffd-4560-a3a6-62a47a93125b").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5e5cf0e5-4ffd-4560-a3a6-62a47a93125b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5e5cf0e5-4ffd-4560-a3a6-62a47a93125b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f26e07d6-a598-4ad3-81e6-8c3aaa586022":{"roots":{"references":[{"attributes":{"axis_label":"Measured","axis_label_text_color":{"value":"#aa6666"},"formatter":{"id":"432667dd-b625-4fca-bc14-9dced4433723","type":"BasicTickFormatter"},"major_tick_line_color":{"value":"firebrick"},"major_tick_line_width":{"value":3},"minor_tick_line_color":{"value":"orange"},"plot":{"id":"7842eccb-34c6-4836-822d-0a65dea3b1c4","subtype":"Figure","type":"Plot"},"ticker":{"id":"ecb1cf29-4aae-4804-acfa-3ca12a97d1e4","type":"BasicTicker"}},"id":"99ae99b4-7455-4a0a-adc6-d47c02680bd5","type":"LinearAxis"},{"attributes":{"line_dash":[4,4],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"9b14e947-2cc1-417a-8d38-ba78f2cbfab1","type":"Line"},{"attributes":{"data_source":{"id":"2c448600-8a00-40db-bac0-123dca64f67d","type":"ColumnDataSource"},"glyph":{"id":"9b14e947-2cc1-417a-8d38-ba78f2cbfab1","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"375f51a2-4642-43af-bc60-7219039f470d","type":"Line"},"selection_glyph":null},"id":"109ac3ba-2841-484c-88c6-15f49c6a2c33","type":"GlyphRenderer"},{"attributes":{},"id":"432667dd-b625-4fca-bc14-9dced4433723","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"3d3c121d-5ad2-4b1e-aa1a-ff8cae0c76d4","type":"Circle"},{"attributes":{},"id":"ecb1cf29-4aae-4804-acfa-3ca12a97d1e4","type":"BasicTicker"},{"attributes":{"overlay":{"id":"de233cda-111f-4bd9-9047-cabadb5b0b50","type":"PolyAnnotation"},"plot":{"id":"7842eccb-34c6-4836-822d-0a65dea3b1c4","subtype":"Figure","type":"Plot"}},"id":"f4caa2dd-05d1-476e-9c46-55104f58ac31","type":"PolySelectTool"},{"attributes":{"plot":{"id":"7842eccb-34c6-4836-822d-0a65dea3b1c4","subtype":"Figure","type":"Plot"}},"id":"887d0cc9-22cc-4c3e-b486-64437034b5e7","type":"PanTool"},{"attributes":{"callback":null,"overlay":{"id":"fe180c2c-6a4b-407a-9eb4-8dfb570f289d","type":"BoxAnnotation"},"plot":{"id":"7842eccb-34c6-4836-822d-0a65dea3b1c4","subtype":"Figure","type":"Plot"},"renderers":[{"id":"9742f81d-7a47-43cd-bf36-53b9feafeb84","type":"GlyphRenderer"},{"id":"109ac3ba-2841-484c-88c6-15f49c6a2c33","type":"GlyphRenderer"}]},"id":"36665114-d314-43ca-b390-3f75cdb0a9cb","type":"BoxSelectTool"},{"attributes":{"callback":null,"plot":{"id":"7842eccb-34c6-4836-822d-0a65dea3b1c4","subtype":"Figure","type":"Plot"}},"id":"d55250d3-9b63-4dd7-b52f-915b83713b49","type":"TapTool"},{"attributes":{"plot":{"id":"7842eccb-34c6-4836-822d-0a65dea3b1c4","subtype":"Figure","type":"Plot"}},"id":"127deba6-53f3-4280-bf0a-a5cded65b1fc","type":"SaveTool"},{"attributes":{"callback":null},"id":"82c56191-157d-49cf-bb8f-f75133da6240","type":"DataRange1d"},{"attributes":{},"id":"45a8a45d-835f-4bb1-9935-c82b7e9b9ed1","type":"ToolEvents"},{"attributes":{"axis_label":"Predicted","axis_label_text_color":{"value":"#aa6666"},"formatter":{"id":"c0532cb2-dc52-4d57-a4db-921e3af129fa","type":"BasicTickFormatter"},"plot":{"id":"7842eccb-34c6-4836-822d-0a65dea3b1c4","subtype":"Figure","type":"Plot"},"ticker":{"id":"49058754-7b95-44f4-9a83-80680acee72a","type":"BasicTicker"}},"id":"dcb933f5-8a90-42c0-aa9d-d6b98cdb8afb","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"767bf3f3-1d58-457f-a043-9e3c3d81569d","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"7842eccb-34c6-4836-822d-0a65dea3b1c4","subtype":"Figure","type":"Plot"}},"id":"b5d6fc45-7b71-4cb6-946b-3a03f42fadc3","type":"WheelZoomTool"},{"attributes":{"fill_color":{"value":"#80B1D3"},"line_color":{"value":"#80B1D3"},"line_width":{"value":3},"x":{"field":"x"},"y": ...

# %%
plt.scatter(predicted, (predicted - Y), c='r', s=30)
plt.title("Residual plot on the training data")
plt.xlabel("Predicted")
plt.ylabel("Residuals")

# %%
# Plotining using bokeh
#TOOLS = 'hover,box_zoom,box_select,crosshair,resize,reset,DecisionTreeRegressor_select,pan,save,poly_select,tap,wheel_zoom,undo'
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,lasso_select,pan,save,poly_select,tap,wheel_zoom,undo'
p = figure(plot_width=500, plot_height=500, title="Residual plot on the training data", tools=TOOLS)
p.scatter(predicted, (predicted - Y),x="jjj", marker="o", color="#80B1D3", line_width=3)
p.title.align = "center"
p.xaxis.axis_label = "Predicted"
p.xaxis.axis_label_text_color = "#aa6666"
#p.xaxis.axis_label_standoff = 30
p.xaxis.major_tick_line_color = "firebrick"
p.xaxis.major_tick_line_width = 3
p.xaxis.minor_tick_line_color = "orange"
p.yaxis.axis_label = "Residuals"
p.yaxis.axis_label_text_font_style = "italic"
p.yaxis.axis_label_text_color = "#aa6666"
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
#p.line([2,38], [0, 0], line_dash="4 4", line_width=2, color='red')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="f5a85bb3-2f10-4b57-b79f-9c194566a01a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#f5a85bb3-2f10-4b57-b79f-9c194566a01a").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f5a85bb3-2f10-4b57-b79f-9c194566a01a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f5a85bb3-2f10-4b57-b79f-9c194566a01a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f120cc1f-ab0f-4383-9142-b0de4dd6f2ed":{"roots":{"references":[{"attributes":{"callback":null},"id":"2620ebc6-5992-42bc-b4f1-e59fec6fa9ca","type":"DataRange1d"},{"attributes":{"axis_label":"Residuals","axis_label_text_color":{"value":"#aa6666"},"formatter":{"id":"2a7e90fb-c602-4756-ae2f-43b8a1823079","type":"BasicTickFormatter"},"plot":{"id":"2864a9d3-b6a6-4e0e-acf9-40961e54c015","subtype":"Figure","type":"Plot"},"ticker":{"id":"d4bacd14-bf33-44a6-a39a-6335f65a48e2","type":"BasicTicker"}},"id":"aa7e2380-91d8-482f-a38e-f19f48ce8b80","type":"LinearAxis"},{"attributes":{"overlay":{"id":"4e1d2100-e5cd-4a20-ad89-8bbff8a6a720","type":"BoxAnnotation"},"plot":{"id":"2864a9d3-b6a6-4e0e-acf9-40961e54c015","subtype":"Figure","type":"Plot"}},"id":"63da1ef1-775d-4e6d-9819-18d7d3a6d26e","type":"BoxZoomTool"},{"attributes":{},"id":"d4bacd14-bf33-44a6-a39a-6335f65a48e2","type":"BasicTicker"},{"attributes":{"overlay":{"id":"cd815f10-5c00-4bcb-8faa-e469c5050b35","type":"PolyAnnotation"},"plot":{"id":"2864a9d3-b6a6-4e0e-acf9-40961e54c015","subtype":"Figure","type":"Plot"}},"id":"090e4726-a8ff-43c2-93bb-2e44845d8b47","type":"PolySelectTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"63da1ef1-775d-4e6d-9819-18d7d3a6d26e","type":"BoxZoomTool"},{"id":"47936606-0598-425d-8464-1e7437df4c6e","type":"BoxSelectTool"},{"id":"8c75a7ab-50f9-4de7-afd0-2721b3dd732f","type":"CrosshairTool"},{"id":"accf679e-7fc1-4ecf-ac95-577803823ecb","type":"ResizeTool"},{"id":"b175f9eb-e6ed-4e35-b930-d0366d5f51f1","type":"ResetTool"},{"id":"302a2998-013e-4396-9ad2-599636cc439e","type":"LassoSelectTool"},{"id":"441e38d2-84c5-4596-a5d6-271db3718c38","type":"PanTool"},{"id":"c2bcbefa-c651-4a73-8d2b-cc0750c3441b","type":"SaveTool"},{"id":"090e4726-a8ff-43c2-93bb-2e44845d8b47","type":"PolySelectTool"},{"id":"3402b194-5b8f-40b2-b274-0004b6fb5c4d","type":"TapTool"},{"id":"cf95e18f-2209-499d-b4f7-b7be0cab9847","type":"WheelZoomTool"},{"id":"22571115-c3f3-4d47-ab29-94d519d36313","type":"UndoTool"}]},"id":"dfa45d63-0d82-466a-b1df-323bd42cd851","type":"Toolbar"},{"attributes":{},"id":"1e9a1bdb-28d3-4941-9eb4-f6ec690418a5","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"2864a9d3-b6a6-4e0e-acf9-40961e54c015","subtype":"Figure","type":"Plot"}},"id":"8c75a7ab-50f9-4de7-afd0-2721b3dd732f","type":"CrosshairTool"},{"attributes":{"plot":{"id":"2864a9d3-b6a6-4e0e-acf9-40961e54c015","subtype":"Figure","type":"Plot"}},"id":"cf95e18f-2209-499d-b4f7-b7be0cab9847","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"2864a9d3-b6a6-4e0e-acf9-40961e54c015","subtype":"Figure","type":"Plot"}},"id":"c2bcbefa-c651-4a73-8d2b-cc0750c3441b","type":"SaveTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"cd815f10-5c00-4bcb-8faa-e469c5050b35","type":"PolyAnnotation"},{"attributes":{"callback":null,"overlay":{"id":"7c6448ea-f08f-48af-a2b7-bd5cf73baa83","type":"PolyAnnotation"},"plot":{"id":"2864a9d3-b6a6-4e0e-acf9-40961e54c015","subtype":"Figure","type":"Plot"}},"id":"302a2998-013e-4396-9ad2-599636cc439e","type":"LassoSelectTool"},{"attributes":{"callback":null,"overlay":{"id":"336495c5-8035-4ffb-9047-760fa096ace7","type":"BoxAnnotation"},"plot":{"id":"2864a9d3-b6a6-4e0e-acf9-40961e54c015","subtype":"Figure","type":"Plot"},"renderers":[{"id":"9477fb8d-6111-45e7-a720-188f94758708","type":"GlyphRenderer"}]},"id":"47936606-0598-425d-8464-1e7437df4c6e","type":"BoxSelectTool"},{"attributes":{},"id":"0315a95c-d20b-42e6-8419-b9a2d97a8cfa","type":"BasicTicker"},{"attributes":{"align":"center","plot":null,"text":"Residual plot on the training data"},"id":"03efbcf6-3daa-4df1-b35c-07aa0c0b2603","type":"Title"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[31.03395121951219,28.15675980392153,28.1567598039 ...

# %% [markdown]
# ## Pipeline

# %% [markdown]
# The best to deliver the model by pipeline the operation then at deployment can be done in one model.

# %% [markdown]
#   I used two ways to check the pipeline so any one can be fine

# %%
# Use Pipeline
# ANOVA 
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, f_regression
anova_filter = SelectKBest(f_regression, k=13)
LR =  DecisionTreeRegressor(min_samples_split = 3, max_depth = 7, min_samples_leaf =1 )

anova_LinReg = Pipeline([('scaler_Input',scaler), ('anova', anova_filter), ('LinReg', LR)])
# You can set the parameters using the names issued
# For instance, fit using a k of 10 in the SelectKBest
anova_LinReg.set_params(anova__k=13).fit(new_data, Y)
prediction = anova_LinReg.predict(new_data)
print anova_LinReg.score(new_data, Y)                        
# getting the selected features chosen by anova_filter
results = cross_validation.cross_val_score(anova_LinReg, new_data, Y, cv=kfold, scoring=scoring)
print 'Scoring according to mean_squared_error'
print results
print '\n Mean      Standard deviation'
print("%.2f      %.2f" % (results.mean(), results.std()))
print anova_LinReg.named_steps['anova'].get_support()
r_squared = r2_score(Y, prediction, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# 0.923736691411
# Scoring according to mean_squared_error
# [-6.54352885 -6.54050598 -5.6341785  -5.85558021 -6.33286256 -6.00686221
#  -6.29010249 -5.93816837 -4.77162558 -6.43260482]
#
#  Mean      Standard deviation
# -6.03      0.51
# [ True  True False False  True False False False False  True  True  True
#   True  True  True False  True  True  True  True]
# R-squared =  0.923736691411

# %%
# Using make_pipeline
from sklearn.pipeline import make_pipeline

# ANOVA SVM-C
# 1) anova filter, take 3 best ranked features
anova_filter = SelectKBest(f_regression, k=13)
anova_DTRegressor = make_pipeline(scaler, anova_filter, LR)
anova_DTRegressor.fit(new_data, Y)
prediction = anova_DTRegressor.predict(new_data)
r_squared = r2_score(Y, prediction, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# R-squared =  0.923736691411

# %% [markdown]
# ### Save the Pipeline model for developement

# %%
# save the model scaler to the desk
from sklearn.externals import joblib
joblib.dump(anova_DTRegressor, 'anova_DTRegressor.pkl')
# Out:
# ['anova_DTRegressor.pkl',
#  'anova_DTRegressor.pkl_01.npy',
#  'anova_DTRegressor.pkl_02.npy',
#  'anova_DTRegressor.pkl_03.npy',
#  'anova_DTRegressor.pkl_04.npy',
#  'anova_DTRegressor.pkl_05.npy',
#  'anova_DTRegressor.pkl_06.npy',
#  'anova_DTRegressor.pkl_07.npy',
#  'anova_DTRegressor.pkl_08.npy']

# %%
# Test the model if it is work
anova_DecisionTreeRegressorTest = joblib.load('anova_DTRegressor.pkl')
NewPred = anova_DecisionTreeRegressorTest.predict(new_data)
print " =================================================================>>>>> done"
r_squared = r2_score(Y, NewPred, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
#  =================================================================>>>>> done
# R-squared =  0.923736691411

# %%
# test on single data point, randomly choose point number 55
print 'Point of training data before normalization\n',new_data[55]
print '\nThe read target of the data = ', Y[55]
NewPred = anova_DecisionTreeRegressorTest.predict([new_data[55]])
print '\nThe Predicted target of the data = ', NewPred
# Out:
# Point of training data before normalization
# [  2.60000000e+01   4.90000000e+01   0.00000000e+00   3.17820000e+01
#    1.18000000e-02   1.27000000e-04   7.05000000e-03   6.00000000e-03
#    2.11500000e-02   5.81300000e-02   5.27000000e-01   3.21500000e-02
#    3.45600000e-02   4.39900000e-02   9.64400000e-02   3.43700000e-02
#    1.74210000e+01   6.30040000e-01   7.72870000e-01   4.15090000e-01]
#
# The read target of the data =  25.706
#
# The Predicted target of the data =  [ 25.28646316]

# %% [markdown]
# ## Conclusion
