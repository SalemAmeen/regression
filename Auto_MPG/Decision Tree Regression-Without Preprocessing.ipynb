# %% [markdown]
# Salem Ameen, PhD student at Salford University
#
# ### Auto MPG price
#
# Decision trees Regression

# %% [markdown]
# # Import the Libraries

# %%
import numpy as np
import pandas
from numpy import *
import time
import sys
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import feature_selection
from sklearn.tree import DecisionTreeRegressor
from sklearn.learning_curve import learning_curve, validation_curve
from sklearn.cross_validation import cross_val_predict
from sklearn import metrics, grid_search, cross_validation
from IPython.display import set_matplotlib_formats
from bokeh.plotting import figure, show, output_notebook
from sklearn.grid_search import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import r2_score
from bokeh.layouts import gridplot
output_notebook()
set_matplotlib_formats('png', 'pdf')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (6, 6)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="33458f6e-adf2-4718-9124-767c91331411">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Load data

# %% [markdown]
# In the previous file we have not change the data as there is no missing value or add any new parameters so it can be downloaded from the web directly.

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'
names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year','origin','name']
feature_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year','origin']
feature_cols = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year','origin']
data = pd.read_csv(url, sep='\s+', names = names)
data = data.drop('name',1)
from sklearn import preprocessing

def number_encode_features(df):
    result = df.copy()
    encoders = {}
    for column in result.columns:
        if result.dtypes[column] == np.object:
            encoders[column] = preprocessing.LabelEncoder()
            result[column] = encoders[column].fit_transform(result[column])
    return result, encoders

data, _ = number_encode_features(data)

dataset = data.values
X = dataset[:,1:8]
Y = dataset[:,0]
print 'Number of examples',len(X)
# Out:
# Number of examples 398

# %%
# Make developement dataset for genrilization and final testing
from sklearn.cross_validation import train_test_split
# Extracting 20% testing data
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.20, random_state=0)
X = X_train
Y = y_train
new_data      = X_train
new_test_data = X_test
print 'Number of training examples',len(X_train)
print 'Number of validation examples',len(X_test)
# Out:
# Number of training examples 318
# Number of validation examples 80

# %% [markdown]
# Number of training data is very small so we need to use cross validation instead of spareate another validation data.

# %% [markdown]
# From the previous visulization the data has no missing value but has many outlier and some sparisty

# %% [markdown]
# # Ranking of the feature's importance to the target

# %%
# Using just correlation coefficient even in prevoius file we show them using data frame
for col in feature_cols:
    lm = DecisionTreeRegressor()
    lm.fit(data[[col]], data['mpg'])
    print col,'\t', lm.score(data[[col]], data['mpg'])
# Out:
# mpg 	1.0
# cylinders 	0.637242089916
# displacement 	0.815077207897
# horsepower 	0.793267880581
# weight 	0.9630669809
# acceleration 	0.516023027818
# year 	0.428893949289
# origin 	0.332864469155

# %%
# Randing the important features to the target
model = feature_selection.SelectKBest(score_func=feature_selection.f_regression,k=4)
results = model.fit(data[feature_cols], data['mpg'])
k=0
print 'Feature Name      Score         Pvalue'
for feat in feature_cols:
    print feat,'\t\t',results.scores_[k],'\t',results.pvalues_[k]
    k=k+1
# Out:
# Feature Name      Score         Pvalue
# mpg 		8.91712726219e+17 	0.0
# cylinders 		597.077047852 	4.50399224618e-81
# displacement 		724.994303368 	1.65588891019e-91
# horsepower 		101.546001862 	2.06258705842e-21
# weight 		888.850682648 	2.97279956405e-103
# acceleration 		84.9577002497 	1.82309153508e-18
# year 		199.98200802 	4.84493581337e-37
# origin 		184.199639369 	1.01148221023e-34

# %% [markdown]
# # Set the parameters for cross validation

# %%
num_folds = 10
num_instances = len(X)
seed = 7
kfold = cross_validation.KFold(n=num_instances, n_folds=num_folds, random_state=seed)

# %% [markdown]
#  # Set the parameters for bias-variance dilemma

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %% [markdown]
# # 1. DecisionTreeRegressor  with   Regression

# %% [markdown]
# Decision trees or the Classification and Regression Trees (CART as they are know) use the training data to select the best points to split the data in order to minimize a cost metric. The default cost metric for regression decision trees is the mean squared error, specified in the criterion parameter.

# %% [markdown]
# ## Validation curve

# %% [markdown]
# choosing multiple hyperparameters of an estimator

# %%
from sklearn.tree import DecisionTreeRegressor
estimator = DecisionTreeRegressor()
estimator.get_params().keys()
# Out:
# ['presort',
#  'splitter',
#  'max_leaf_nodes',
#  'min_samples_leaf',
#  'min_samples_split',
#  'min_weight_fraction_leaf',
#  'criterion',
#  'random_state',
#  'max_features',
#  'max_depth']

# %%
# For parametr alpha
#param_range = np.logspace(-10.0, 10.0)
#param_range = np.linspace(1,50,100)
param_range = np.arange(1,50) # generate integer numbers

train_scores, test_scores = validation_curve(
    DecisionTreeRegressor(), X, Y, param_name="max_depth", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with DecisionTreeRegressor")
plt.xlabel("max_depth")
plt.ylabel("Score")
plt.ylim(0.4, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# more that 5 is the best of number of K

# %%
# For parametr alpha
#param_range = np.logspace(-10.0, 10.0)
#param_range = np.linspace(1,50,100)
param_range = np.arange(1,10) # generate integer numbers

train_scores, test_scores = validation_curve(
    DecisionTreeRegressor(), X, Y, param_name="min_samples_split", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with DecisionTreeRegressor")
plt.xlabel("min_samples_split")
plt.ylabel("Score")
plt.ylim(0.4, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# min_samples_split =2 (The defualt) is the best

# %%
# For parametr alpha
#param_range = np.logspace(-10.0, 10.0)
#param_range = np.linspace(1,50,100)
param_range = np.arange(1,10) # generate integer numbers

train_scores, test_scores = validation_curve(
    DecisionTreeRegressor(), X, Y, param_name="min_samples_leaf", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with DecisionTreeRegressor")
plt.xlabel("min_samples_leaf")
plt.ylabel("Score")
plt.ylim(0.4, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# min_samples_leaf = 2 is the best

# %% [markdown]
# ## Grid search and/or Random search to determine best compination of parameters

# %%
# Utility function to report optimal parameters
from operator import itemgetter
def report(grid_scores, n_top=5):
    params = None
    top_scores = sorted(grid_scores, key=itemgetter(1), reverse=True)[:n_top]
    for i, score in enumerate(top_scores):
        print("Parameters with rank: {0}".format(i + 1))
        print("Mean validation score: {0:.4f} (std: {1:.4f})".format(
              score.mean_validation_score, np.std(score.cv_validation_scores)))
        print("Parameters: {0}".format(score.parameters))
        print("")
        
        if params == None:
            params = score.parameters
    
    return params

# The most common value for the max number of features to look at in each split is sqrt(# of features)
sqrtfeat = np.sqrt(X.shape[1]) 
grid_test1 = { "max_depth"      : np.arange(1,15),
             "min_samples_split"      : np.arange(1,4),
             "min_samples_leaf"    : np.arange(1,3)}

# Large randomized test using max_depth to control tree size (5000 possible combinations)
random_test1 = { "max_depth"      : [1,10],
                "min_samples_split"      : [ 1,2],
               "min_samples_leaf"   : [1,2]}


forest =  DecisionTreeRegressor()

print "Hyperparameter optimization using GridSearchCV..."
grid_search = GridSearchCV(forest, grid_test1, n_jobs=-1, cv=num_folds)
grid_search.fit(X, Y)
best_params_from_grid_search = report(grid_search.grid_scores_)
print '+++++++++++++++++++++++++++++++++++++++++++++++'
print "Hyperparameter optimization using RandomizedSearchCV"
grid_search = RandomizedSearchCV(forest, random_test1, n_jobs=-1, cv=num_folds, n_iter=5)
grid_search.fit(X, Y)
best_params_from_rand_search1 = report(grid_search.grid_scores_)
# Out:
# Hyperparameter optimization using GridSearchCV...
# Parameters with rank: 1
# Mean validation score: 0.8212 (std: 0.0754)
# Parameters: {'min_samples_split': 3, 'max_depth': 5, 'min_samples_leaf': 1}
#
# Parameters with rank: 2
# Mean validation score: 0.8181 (std: 0.0678)
# Parameters: {'min_samples_split': 1, 'max_depth': 5, 'min_samples_leaf': 2}
#
# Parameters with rank: 3
# Mean validation score: 0.8158 (std: 0.0674)
# Parameters: {'min_samples_split': 2, 'max_depth': 5, 'min_samples_leaf': 2}
#
# Parameters with rank: 4
# Mean validation score: 0.8134 (std: 0.0758)
# Parameters: {'min_samples_split': 3, 'max_depth': 5, 'min_samples_leaf': 2}
#
# Parameters with rank: 5
# Mean validation score: 0.8126 (std: 0.0804)
# Parameters: {'min_samples_split': 2, 'max_depth': 5, 'min_samples_leaf': 1}
#
# +++++++++++++++++++++++++++++++++++++++++++++++
# Hyperparameter optimization using RandomizedSearchCV
# Parameters with rank: 1
# Mean validation score: 0.7897 (std: 0.0813)
# Parameters: {'min_samples_split': 1, 'max_depth': 10, 'min_samples_leaf': 1}
#
# Parameters with rank: 2
# Mean validation score: 0.7714 (std: 0.0787)
# Parameters: {'min_samples_split': 1, 'max_depth': 10, 'min_samples_leaf': 2}
#
# Parameters with rank: 3
# Mean validation score: 0.7656 (std: 0.0783)
# Parameters: {'min_samples_split': 2, 'max_depth': 10, 'min_samples_leaf': 2}
#
# Parameters with rank: 4
# Mean validation score: 0.4954 (std: 0.0741)
# Parameters: {'min_samples_split': 2, 'max_depth': 1, 'min_samples_leaf': 2}
#
# Parameters with rank: 5
# Mean validation score: 0.4954 (std: 0.0741)
# Parameters: {'min_samples_split': 1, 'max_depth': 1, 'min_samples_leaf': 1}

# %% [markdown]
# Best 'min_samples_split': 3, 'max_depth': 7, 'min_samples_leaf': 1

# %% [markdown]
# ## Learning Curve

# %% [markdown]
# In essence, what we’re doing it training the exact same model with increasingly large fractions of our total training data, and plotting the error of the training and test sets at each step.

# %%
from sklearn.tree import DecisionTreeRegressor

model =  DecisionTreeRegressor(min_samples_split = 3, max_depth = 7, min_samples_leaf =1 )
title = "Learning Curves (  DecisionTreeRegressor Refression)"
cv = cross_validation.ShuffleSplit(X.shape[0], n_iter=100,
                                   test_size=0.2, random_state=0)
plot_learning_curve(model, title, X, Y, ylim=(0.2, 1.01), cv=cv, n_jobs=-1)
plt.show()

# %%
# More data from learning curve to show the process of building the model
train_sizes, train_scores, valid_scores = learning_curve(
     model, X, Y, train_sizes=[50, 80, 110], cv=cv, n_jobs=4)

print 'train_sizes = ', train_sizes

print ' training scores'
print ' 50 training sizees'
print train_scores[0].mean(),'±',train_scores[0].std()
print ' 80 training sizees'
print train_scores[1].mean(),'±',train_scores[1].std()
print ' 110 training sizees'
print train_scores[2].mean(),'±',train_scores[2].std()

print '\n validation scores'
print ' 50 validation scores'
print valid_scores[0].mean(),'±',valid_scores[0].std()
print ' 80 validation scores'
print valid_scores[1].mean(),'±',valid_scores[1].std()
print ' 110 validation scores'
print valid_scores[2].mean(),'±',valid_scores[2].std()
# Out:
# train_sizes =  [ 50  80 110]
#  training scores
#  50 training sizees
# 0.994668151707 ± 0.00360817530423
#  80 training sizees
# 0.991587224404 ± 0.0054928618466
#  110 training sizees
# 0.988636157905 ± 0.00634133265756
#
#  validation scores
#  50 validation scores
# 0.604569891347 ± 0.187121103965
#  80 validation scores
# 0.670626231554 ± 0.111096428166
#  110 validation scores
# 0.714488157203 ± 0.100982543507

# %% [markdown]
# ## Cross validation

# %%
scoring = 'mean_squared_error'
results = cross_validation.cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
print 'Scoring according to mean_squared_error'
print results
print '\n Mean      Standard deviation'
print("%.2f      %.2f" % (results.mean(), results.std()))
## Fit the model
model.fit(X,Y)
# Out:
# Scoring according to mean_squared_error
# [-12.40512911 -15.25028668  -9.2067169  -26.79431686 -13.20288889
#   -6.45970014 -13.57931535  -7.9436916   -6.74909642 -12.32265188]
#
#  Mean      Standard deviation
# -12.39      5.61
# DecisionTreeRegressor(criterion='mse', max_depth=7, max_features=None,
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=3,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %% [markdown]
# ## Coefficients Of Determination {Calculating R^2}
#
# R^2, Close to one is better

# %%
predicted = cross_val_predict(model, X, Y, cv=kfold)
r_squared = r2_score(Y, predicted, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# R-squared =  0.802928225016

# %% [markdown]
# ## Residual Plot

# %%
predicted = cross_val_predict(model, X, Y, cv=kfold)
fig, ax = plt.subplots()
ax.scatter(Y, predicted)
ax.plot([Y.min(), Y.max()], [Y.min(), Y.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()

# %%
# Plotining using bokeh
#TOOLS = [BoxSelectTool(), HoverTool()]
#TOOLS = 'hover,box_zoom,box_select,crosshair,resize,reset,DecisionTreeRegressor_select,pan,save,poly_select,tap,wheel_zoom,undo'
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,lasso_select,pan,save,poly_select,tap,wheel_zoom,undo'
p = figure(plot_width=500, plot_height=500, tools=TOOLS)
p.scatter(Y, predicted,x="jjj", marker="o", color="#80B1D3", line_width=3)
p.title.align = "center"
p.xaxis.axis_label = "Measured"
p.xaxis.axis_label_text_color = "#aa6666"
#p.xaxis.axis_label_standoff = 30
p.xaxis.major_tick_line_color = "firebrick"
p.xaxis.major_tick_line_width = 3
p.xaxis.minor_tick_line_color = "orange"
p.yaxis.axis_label = "Predicted"
p.yaxis.axis_label_text_font_style = "italic"
p.yaxis.axis_label_text_color = "#aa6666"
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
#p.line([Y.min(), Y.max()], [Y.min(), Y.max()], line_dash="4 4", line_width=2, color='red')

# create a new plot with the toolbar below
# line_dash="4 4", line_width=2, color='red'
p.line([Y.min(), Y.max()], [Y.min(), Y.max()], line_dash="4 4", line_width=2, line_color="black")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="579f992d-7831-43fe-9990-ea3e1b7a2054"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#579f992d-7831-43fe-9990-ea3e1b7a2054").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("579f992d-7831-43fe-9990-ea3e1b7a2054");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '579f992d-7831-43fe-9990-ea3e1b7a2054' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"68557d6b-fb9b-4edf-8830-35179c10ad26":{"roots":{"references":[{"attributes":{},"id":"c622d423-bcb6-45b0-9662-bf590306a9fb","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[9.0,46.6],"y":[9.0,46.6]}},"id":"7c7826ec-71ba-4b12-8ea1-7703c6fb8363","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"733f1f19-06a7-478a-98a3-e8062e1ea6d4","type":"Circle"},{"attributes":{},"id":"2752290b-8c0b-4fa0-b07b-b57d24d8378c","type":"BasicTickFormatter"},{"attributes":{"align":"center","plot":null,"text":null},"id":"46404bf1-5031-4380-842d-c19f8669dbf0","type":"Title"},{"attributes":{"callback":null,"plot":{"id":"b7ce2914-be91-4363-b478-1c77b84f123a","subtype":"Figure","type":"Plot"}},"id":"0ba9577d-5d2b-45ea-ae30-d9c51091b8b4","type":"TapTool"},{"attributes":{"plot":{"id":"b7ce2914-be91-4363-b478-1c77b84f123a","subtype":"Figure","type":"Plot"}},"id":"81122184-85b6-4510-af16-e5de8801e7b8","type":"ResetTool"},{"attributes":{"plot":{"id":"b7ce2914-be91-4363-b478-1c77b84f123a","subtype":"Figure","type":"Plot"}},"id":"672481d9-3078-4569-abe0-2cb037d7e1a7","type":"SaveTool"},{"attributes":{},"id":"4779c239-57ae-4c14-8773-fdaae037f87f","type":"BasicTicker"},{"attributes":{},"id":"f2cdf92a-3bc1-4b59-a9a2-d0be7de2c699","type":"BasicTicker"},{"attributes":{},"id":"0e2f887e-a5c6-4c48-9656-df6e0e591205","type":"ToolEvents"},{"attributes":{"plot":{"id":"b7ce2914-be91-4363-b478-1c77b84f123a","subtype":"Figure","type":"Plot"}},"id":"99a547e3-fcbf-4a0c-9b82-12fe43562b4d","type":"CrosshairTool"},{"attributes":{"data_source":{"id":"a2338e50-482c-49a5-b9a3-232bc4ab8aaf","type":"ColumnDataSource"},"glyph":{"id":"9561afb4-95e4-4a5c-b4ed-97a32d7fc72b","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"733f1f19-06a7-478a-98a3-e8062e1ea6d4","type":"Circle"},"selection_glyph":null},"id":"6991b4c3-0a8b-413a-bf53-eb3af4789ba1","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"b7ce2914-be91-4363-b478-1c77b84f123a","subtype":"Figure","type":"Plot"},"ticker":{"id":"f2cdf92a-3bc1-4b59-a9a2-d0be7de2c699","type":"BasicTicker"}},"id":"c6561166-e073-4ae9-b366-0b402318b13c","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"bd73c741-6e65-45f9-9e0a-3c12047b71ba","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"8f44da5d-4334-4abc-b892-7e530459d2af","type":"DataRange1d"},{"attributes":{"callback":null},"id":"92386cd0-379d-4de1-a753-7f4d1aa2e3b1","type":"DataRange1d"},{"attributes":{"overlay":{"id":"34784109-a027-4c27-8ec5-2145439ac63a","type":"BoxAnnotation"},"plot":{"id":"b7ce2914-be91-4363-b478-1c77b84f123a","subtype":"Figure","type":"Plot"}},"id":"0ac7252a-79b7-4867-aecf-3293edff1d92","type":"BoxZoomTool"},{"attributes":{"line_dash":[4,4],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"b3a7b926-525f-450b-9da0-c0f5507e9373","type":"Line"},{"attributes":{"plot":{"id":"b7ce2914-be91-4363-b478-1c77b84f123a","subtype":"Figure","type":"Plot"}},"id":"3403c89b-e828-42e7-896f-7218dede50a3","type":"UndoTool"},{"attributes":{"overlay":{"id":"f12ec437-ba4a-4ef9-9318-0bfa1582f413","type":"PolyAnnotation"},"plot":{"id":"b7ce2914-be91-4363-b478-1c77b84f123a","subtype":"Figure","type":"Plot"}},"id":"e56c8ee8-b3c3-4e61-b6ca-7b2c55b25500","type":"PolySelectTool"},{"attributes":{"background_fill_alpha":{"value":0.5},"background_fill_color":{"value":"beige"},"below":[{"id":"da04dfee-dffe-483f-a6f5-5d7b3e7aeec0","type":"LinearAxis"}],"left":[{"id":"e8b512bf-c8fe-499e-98c3-1550610e0584","type":"LinearAxi ...

# %%
plt.scatter(predicted, (predicted - Y), c='r', s=30)
plt.title("Residual plot on the training data")
plt.xlabel("Predicted")
plt.ylabel("Residuals")

# %%
# Plotining using bokeh
#TOOLS = 'hover,box_zoom,box_select,crosshair,resize,reset,DecisionTreeRegressor_select,pan,save,poly_select,tap,wheel_zoom,undo'
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,lasso_select,pan,save,poly_select,tap,wheel_zoom,undo'
p = figure(plot_width=500, plot_height=500, title="Residual plot on the training data", tools=TOOLS)
p.scatter(predicted, (predicted - Y),x="jjj", marker="o", color="#80B1D3", line_width=3)
p.title.align = "center"
p.xaxis.axis_label = "Predicted"
p.xaxis.axis_label_text_color = "#aa6666"
#p.xaxis.axis_label_standoff = 30
p.xaxis.major_tick_line_color = "firebrick"
p.xaxis.major_tick_line_width = 3
p.xaxis.minor_tick_line_color = "orange"
p.yaxis.axis_label = "Residuals"
p.yaxis.axis_label_text_font_style = "italic"
p.yaxis.axis_label_text_color = "#aa6666"
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
#p.line([2,38], [0, 0], line_dash="4 4", line_width=2, color='red')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="5b697794-8067-4cb5-9661-57d982de59ad"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#5b697794-8067-4cb5-9661-57d982de59ad").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5b697794-8067-4cb5-9661-57d982de59ad");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5b697794-8067-4cb5-9661-57d982de59ad' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"7e147b0f-0988-4909-b47b-3ab126a8992c":{"roots":{"references":[{"attributes":{},"id":"dcadd8b5-5b6c-4efa-ad60-45fa837dd038","type":"BasicTicker"},{"attributes":{"plot":{"id":"40ef69f8-de07-4c58-9999-7877b53c4bd1","subtype":"Figure","type":"Plot"}},"id":"93573007-5fab-4d46-89a4-de437515a4ee","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"2b7d8611-e44b-4c69-970a-341364e3eb79","type":"PolyAnnotation"},{"attributes":{"align":"center","plot":null,"text":"Residual plot on the training data"},"id":"3a56fb5d-820b-45a5-b929-659522ea38b0","type":"Title"},{"attributes":{"callback":null,"plot":{"id":"40ef69f8-de07-4c58-9999-7877b53c4bd1","subtype":"Figure","type":"Plot"}},"id":"d78303d2-e0a0-4bc0-b870-d0a0001963de","type":"TapTool"},{"attributes":{},"id":"06918ff2-c8da-42e1-aa81-a0d41434d4e9","type":"BasicTicker"},{"attributes":{"callback":null,"overlay":{"id":"0651c0bc-8f9e-4241-b0b0-7b70c37cb80e","type":"PolyAnnotation"},"plot":{"id":"40ef69f8-de07-4c58-9999-7877b53c4bd1","subtype":"Figure","type":"Plot"}},"id":"cf6f6d3b-3a47-406e-9941-04c5a1cae7aa","type":"LassoSelectTool"},{"attributes":{"axis_label":"Predicted","axis_label_text_color":{"value":"#aa6666"},"formatter":{"id":"4059eeb9-ee88-4ed9-a603-aeffe1503b74","type":"BasicTickFormatter"},"major_tick_line_color":{"value":"firebrick"},"major_tick_line_width":{"value":3},"minor_tick_line_color":{"value":"orange"},"plot":{"id":"40ef69f8-de07-4c58-9999-7877b53c4bd1","subtype":"Figure","type":"Plot"},"ticker":{"id":"06918ff2-c8da-42e1-aa81-a0d41434d4e9","type":"BasicTicker"}},"id":"b3a2bec7-36b5-4009-843a-230dce54672a","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8b6a4632-5eaf-4511-9576-3b537ac4a5e1","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"b4eec2bd-9211-49f6-bcca-474752c1e0d5","type":"ColumnDataSource"},"glyph":{"id":"60418b4d-44bb-4841-b56c-c19db0da552f","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"62c2954b-2cbb-46ba-86ef-838f87c2bb64","type":"Circle"},"selection_glyph":null},"id":"410b031d-a820-4cc9-b2b4-e86ac5d3b391","type":"GlyphRenderer"},{"attributes":{},"id":"e529bca0-2208-474e-8018-4fb4c10685c0","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Residuals","axis_label_text_color":{"value":"#aa6666"},"formatter":{"id":"e529bca0-2208-474e-8018-4fb4c10685c0","type":"BasicTickFormatter"},"plot":{"id":"40ef69f8-de07-4c58-9999-7877b53c4bd1","subtype":"Figure","type":"Plot"},"ticker":{"id":"dcadd8b5-5b6c-4efa-ad60-45fa837dd038","type":"BasicTicker"}},"id":"2ed10aa3-fda2-47b6-b791-915aed7bd51e","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"0651c0bc-8f9e-4241-b0b0-7b70c37cb80e","type":"PolyAnnotation"},{"attributes":{"overlay":{"id":"2b7d8611-e44b-4c69-970a-341364e3eb79","type":"PolyAnnotation"},"plot":{"id":"40ef69f8-de07-4c58-9999-7877b53c4bd1","subtype":"Figure","type":"Plot"}},"id":"a1f5dd3c-aa4d-4fdf-8c58-7ae44f781c24","type":"PolySelectTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[13.727272727272727,25.5,34.56666666666667,25.5,32.9,46.6,29.85,19.6875,29.9,33.92,25.5,10.5,20.333333333333332,34.0,31.700000000000003,19.15,19.6875,24.0,20.333333333333332,12.8,20.333333333333332,41.25,26.4,26.0,31.8,23.725,19.5,15.0,16.0,24.2310344827586 ...

# %% [markdown]
# ## Pipeline

# %% [markdown]
# The best to deliver the model by pipeline the operation then at deployment can be done in one model.

# %% [markdown]
#   I used two ways to check the pipeline so any one can be fine

# %%
# Use Pipeline
# ANOVA 
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, f_regression
anova_filter = SelectKBest(f_regression, k=7)
LR =  DecisionTreeRegressor(min_samples_split = 3, max_depth = 7, min_samples_leaf =1 )

anova_LinReg = Pipeline([ ('anova', anova_filter), ('LinReg', LR)])
# You can set the parameters using the names issued
# For instance, fit using a k of 10 in the SelectKBest
anova_LinReg.set_params(anova__k=7).fit(new_data, Y)
prediction = anova_LinReg.predict(new_data)
print anova_LinReg.score(new_data, Y)                        
# getting the selected features chosen by anova_filter
results = cross_validation.cross_val_score(anova_LinReg, new_data, Y, cv=kfold, scoring=scoring)
print 'Scoring according to mean_squared_error'
print results
print '\n Mean      Standard deviation'
print("%.2f      %.2f" % (results.mean(), results.std()))
print anova_LinReg.named_steps['anova'].get_support()
r_squared = r2_score(Y, prediction, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# 0.969419678252
# Scoring according to mean_squared_error
# [-13.24817598 -19.01761041 -11.62476378 -26.74761764 -12.22163889
#   -6.22680951 -13.58681535  -8.77865688  -6.00716094 -11.99818112]
#
#  Mean      Standard deviation
# -12.95      5.85
# [ True  True  True  True  True  True  True]
# R-squared =  0.969419678252

# %%
# Using make_pipeline
from sklearn.pipeline import make_pipeline

# ANOVA SVM-C
# 1) anova filter, take 3 best ranked features
anova_filter = SelectKBest(f_regression, k=7)
anova_DTRegressorNoPreprocessing = make_pipeline( anova_filter, LR)
anova_DTRegressorNoPreprocessing.fit(new_data, Y)
prediction = anova_DTRegressorNoPreprocessing.predict(new_data)
r_squared = r2_score(Y, prediction, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# R-squared =  0.969419678252

# %% [markdown]
# ### Save the Pipeline model for developement

# %%
# save the model scaler to the desk
from sklearn.externals import joblib
joblib.dump(anova_DTRegressorNoPreprocessing, 'anova_DTRegressorNoPreprocessing.pkl')
# Out:
# ['anova_DTRegressorNoPreprocessing.pkl',
#  'anova_DTRegressorNoPreprocessing.pkl_01.npy',
#  'anova_DTRegressorNoPreprocessing.pkl_02.npy',
#  'anova_DTRegressorNoPreprocessing.pkl_03.npy',
#  'anova_DTRegressorNoPreprocessing.pkl_04.npy',
#  'anova_DTRegressorNoPreprocessing.pkl_05.npy']

# %%
# Test the model if it is work
anova_DecisionTreeRegressorTest = joblib.load('anova_DTRegressorNoPreprocessing.pkl')
NewPred = anova_DecisionTreeRegressorTest.predict(new_data)
print " =================================================================>>>>> done"
r_squared = r2_score(Y, NewPred, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
#  =================================================================>>>>> done
# R-squared =  0.969419678252

# %%
# test on single data point, randomly choose point number 55
print 'Point of training data before normalization\n',new_data[55]
print '\nThe read target of the data = ', Y[55]
NewPred = anova_DecisionTreeRegressorTest.predict([new_data[55]])
print '\nThe Predicted target of the data = ', NewPred
# Out:
# Point of training data before normalization
# [  4.00000000e+00   9.70000000e+01   5.10000000e+01   2.13000000e+03
#    2.46000000e+01   8.20000000e+01   2.00000000e+00]
#
# The read target of the data =  44.0
#
# The Predicted target of the data =  [ 44.15]

# %% [markdown]
# ## Conclusion
