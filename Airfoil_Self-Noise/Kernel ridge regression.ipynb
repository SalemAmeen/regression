# %% [markdown]
# Salem Ameen, PhD student at Salford University
#
# ### Airfoil Self-Noise price
#
# Kernel KernelRidge regression

# %% [markdown]
# # Import the Libraries

# %%
import numpy as np
import pandas
from numpy import *
import time
import sys
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import feature_selection
from sklearn.kernel_ridge import KernelRidge
from sklearn.learning_curve import learning_curve, validation_curve
from sklearn.cross_validation import cross_val_predict
from sklearn import metrics, grid_search, cross_validation
from IPython.display import set_matplotlib_formats
from bokeh.plotting import figure, show, output_notebook
from sklearn.grid_search import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import r2_score
from bokeh.layouts import gridplot
output_notebook()
set_matplotlib_formats('png', 'pdf')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (6, 6)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b3eebf77-90f1-4cd1-845a-c911d05607de">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Load data

# %% [markdown]
# In the previous file we have not change the data as there is no missing value or add any new parameters so it can be downloaded from the web directly.

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00291/airfoil_self_noise.dat'
names = ['Frequency', 'Angle', 'Chord', 'Free_stream', 'Suction', 'pressure']
feature_names = names
feature_cols = names
data = pd.read_csv(url, sep='\s+', names = names)

from sklearn import preprocessing
dataset = data.values
X = dataset[:,0:5].astype(float)
Y = dataset[:,5]
print 'Number of examples',len(X)
# Out:
# Number of examples 1503

# %%
# Make developement dataset for genrilization and final testing
from sklearn.cross_validation import train_test_split
# Extracting 20% testing data
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.20, random_state=0)
X = X_train
Y = y_train
new_data      = X_train
new_test_data = X_test
print 'Number of training examples',len(X_train)
print 'Number of validation examples',len(X_test)
# Out:
# Number of training examples 1202
# Number of validation examples 301

# %% [markdown]
# Number of training data is very small so we need to use cross validation instead of spareate another validation data.

# %% [markdown]
# From the previous visulization the data has no missing value but has many outlier and some sparisty

# %% [markdown]
# # Ranking of the feature's importance to the target

# %%
# Using just correlation coefficient even in prevoius file we show them using data frame
for col in feature_cols:
    lm = KernelRidge()
    lm.fit(data[[col]], data['pressure'])
    print col,'\t', lm.score(data[[col]], data['pressure'])
# Out:
# Frequency 	-185.159693172
# Angle 	-144.378577643
# Chord 	-108.700019994
# Free_stream 	-26.7999517929
# Suction 	-259.078454334
# pressure 	0.999999999999

# %%
# Randing the important features to the target
model = feature_selection.SelectKBest(score_func=feature_selection.f_regression,k=4)
results = model.fit(data[feature_cols], data['pressure'])
k=0
print 'Feature Name      Score         Pvalue'
for feat in feature_cols:
    print feat,'\t\t',results.scores_[k],'\t',results.pvalues_[k]
    k=k+1
# Out:
# Feature Name      Score         Pvalue
# Frequency 		270.416272463 	5.36177705642e-56
# Angle 		37.4923835551 	1.16954827306e-09
# Chord 		88.6588675485 	1.70142015337e-20
# Free_stream 		23.8652245755 	1.1437427443e-06
# Suction 		162.641263457 	1.92478295603e-35
# pressure 		inf 	0.0

# %% [markdown]
# # Set the parameters for cross validation

# %%
num_folds = 10
num_instances = len(X)
seed = 7
kfold = cross_validation.KFold(n=num_instances, n_folds=num_folds, random_state=seed)

# %% [markdown]
#  # Set the parameters for bias-variance dilemma

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %% [markdown]
# # Preprocessing the data and save both the model and preprocessed data

# %%
# According to the nature of the data spasity and there is outliter RobustScaler class is recomandit 
# but when I tried both of them the result seems is same
from sklearn.preprocessing import StandardScaler
scaler = preprocessing.StandardScaler().fit(X_train)

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test) # use same transform for testing data
X = X_train

# %%
# save transformed data
np.save('./data/X_train', X_train)
np.save('./data/y_train', y_train)
np.save('./data/X_test', X_test)
np.save('./data/y_test', y_test)

# %%
# save the model scaler to the desk
from sklearn.externals import joblib
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl', 'scaler.pkl_01.npy', 'scaler.pkl_02.npy', 'scaler.pkl_03.npy']

# %%
# Test the model if it is work
scalerTest = joblib.load('scaler.pkl')
new_data_scaled = scalerTest.transform(new_test_data)
print " =================================================================>>>>> done"
print new_data_scaled
# Out:
#  =================================================================>>>>> done
# [[ 2.29083349 -1.15043085 -1.17128043  1.28444798 -0.82148429]
#  [ 1.09730905 -1.15043085  1.81266366  1.28444798 -0.65012723]
#  [-0.12847281  0.9056672  -0.35747749 -1.24501741  2.31947901]
#  ...,
#  [-0.41878957 -1.15043085  0.18505779 -0.74040184 -0.70544919]
#  [-0.61233407 -0.2644699   0.99886072 -0.74040184 -0.3865872 ]
#  [ 2.29083349 -0.69909225  0.18505779 -0.74040184 -0.62856871]]

# %% [markdown]
# # 1. KernelRidge Regression

# %% [markdown]
# Kernel KernelRidge regression (KRR) combines KernelRidge regression (linear least squares with l2-norm regularization) with the kernel trick. It thus learns a linear function in the space induced by the respective kernel and the data. For non-linear kernels, this corresponds to a non-linear function in the original space.

# %% [markdown]
# ## Validation curve

# %% [markdown]
# choosing multiple hyperparameters of an estimator

# %%
from sklearn.kernel_ridge import KernelRidge
estimator = KernelRidge()
estimator.get_params().keys()
# Out:
# ['kernel', 'degree', 'kernel_params', 'alpha', 'coef0', 'gamma']

# %%
# For parametr gamma
#param_range = np.logspace(-10.0, 10.0)
#param_range = np.logspace(-20, 2, 50)
param_range = np.linspace(0.00000000001,0.5,10)

train_scores, test_scores = validation_curve(
    KernelRidge(kernel='rbf'), X, Y, param_name="gamma", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with KernelRidge")
plt.xlabel("gamma")
plt.ylabel("Score")
plt.ylim(0, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# It looks gamma between 0 and 0.1 works well

# %%
# For parametr alpha
#param_range = np.logspace(-10.0, 10.0)
#param_range = np.logspace(-20, 2, 50)
param_range = np.linspace(0,0.2,100)

train_scores, test_scores = validation_curve(
    KernelRidge(kernel='rbf'), X, Y, param_name="alpha", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with KernelRidge")
plt.xlabel("alpha")
plt.ylabel("Score")
plt.ylim(0.2, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()
# Out:
# /home/salm/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /home/salm/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /home/salm/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /home/salm/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "

# %% [markdown]
# It looks very small alpha works fine

# %% [markdown]
# ## Grid search and/or Random search to determine best compination of parameters

# %%
# Utility function to report optimal parameters
from operator import itemgetter
def report(grid_scores, n_top=5):
    params = None
    top_scores = sorted(grid_scores, key=itemgetter(1), reverse=True)[:n_top]
    for i, score in enumerate(top_scores):
        print("Parameters with rank: {0}".format(i + 1))
        print("Mean validation score: {0:.4f} (std: {1:.4f})".format(
              score.mean_validation_score, np.std(score.cv_validation_scores)))
        print("Parameters: {0}".format(score.parameters))
        print("")
        
        if params == None:
            params = score.parameters
    
    return params

# The most common value for the max number of features to look at in each split is sqrt(# of features)
sqrtfeat = np.sqrt(X.shape[1]) 
# Simple grid test (162 combinations)
grid_test1 = { "gamma"      : np.linspace(0.00000000001,0.2,20),
               "alpha"         :  np.linspace(0.00000000000001,0.2,20) }

# Large randomized test using max_depth to control tree size (5000 possible combinations)
random_test1 = { "gamma"          : [0.0000000001, 0.0000002, 0.00003],
                 "alpha"         : [0.000001, 0.1] }


forest = KernelRidge(kernel='rbf')

print "Hyperparameter optimization using GridSearchCV..."
grid_search = GridSearchCV(forest, grid_test1, n_jobs=-1, cv=num_folds)
grid_search.fit(X, Y)
best_params_from_grid_search = report(grid_search.grid_scores_)
print '+++++++++++++++++++++++++++++++++++++++++++++++'
print "Hyperparameter optimization using RandomizedSearchCV"
grid_search = RandomizedSearchCV(forest, random_test1, n_jobs=-1, cv=num_folds, n_iter=5)
grid_search.fit(X, Y)
best_params_from_rand_search1 = report(grid_search.grid_scores_)
# Out:
# Hyperparameter optimization using GridSearchCV...
# /home/salm/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /home/salm/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /home/salm/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /home/salm/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /home/salm/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /home/salm/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /home/salm/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /home/salm/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /home/salm/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /home/salm/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /home/salm/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# /home/salm/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.py:154: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# Parameters with rank: 1
# Mean validation score: 0.8308 (std: 0.0559)
# Parameters: {'alpha': 0.010526315789483159, 'gamma': 0.18947368421105265}
#
# Parameters with rank: 2
# Mean validation score: 0.8307 (std: 0.0538)
# Parameters: {'alpha': 0.010526315789483159, 'gamma': 0.17894736842210526}
#
# Parameters with rank: 3
# Mean validation score: 0.8305 (std: 0.0580)
# Parameters: {'alpha': 0.010526315789483159, 'gamma': 0.20000000000000001}
#
# Parameters with rank: 4
# Mean validation score: 0.8302 (std: 0.0517)
# Parameters: {'alpha': 0.010526315789483159, 'gamma': 0.1684210526331579}
#
# Parameters with rank: 5
# Mean validation score: 0.8293 (std: 0.0497)
# Parameters: {'alpha': 0.010526315789483159, 'gamma': 0.15789473684421054}
#
# +++++++++++++++++++++++++++++++++++++++++++++++
# Hyperparameter optimization using RandomizedSearchCV
# Parameters with rank: 1
# Mean validation score: 0.6119 (std: 0.0653)
# Parameters: {'alpha': 1e-06, 'gamma': 3e-05}
#
# Parameters with rank: 2
# Mean validation score: 0.4930 (std: 0.0744)
# Parameters: {'alpha': 1e-06, 'gamma': 2e-07}
#
# Parameters with rank: 3
# Mean validation score: 0.2515 (std: 0.0231)
# Parameters: {'alpha': 0.1, 'gamma': 3e-05}
#
# Parameters with rank: 4
# Mean validation score: -0.0003 (std: 0.0041)
# Parameters: {'alpha': 0.1, 'gamma': 2e-07}
#
# Parameters with rank: 5
# Mean validation score: -0.0031 (std: 0.0040)
# Parameters: {'alpha': 0.1, 'gamma': 1e-10}

# %% [markdown]
# ## Learning Curve

# %% [markdown]
# In essence, what we’re doing it training the exact same model with increasingly large fractions of our total training data, and plotting the error of the training and test sets at each step.

# %%
from sklearn.kernel_ridge import KernelRidge
# 'alpha': 10.0, 'solver': 'lsqr'
model = KernelRidge(kernel='rbf', gamma=0.052, alpha =  0.0216)
title = "Learning Curves (KernelRidge Refression)"
cv = cross_validation.ShuffleSplit(X.shape[0], n_iter=100,
                                   test_size=0.2, random_state=0)
plot_learning_curve(model, title, X, Y, ylim=(0.2, 1.01), cv=cv, n_jobs=-1)
plt.show()

# %%
# More data from learning curve to show the process of building the model
train_sizes, train_scores, valid_scores = learning_curve(
     model, X, Y, train_sizes=[50, 80, 110], cv=cv, n_jobs=4)

print 'train_sizes = ', train_sizes

print ' training scores'
print ' 50 training sizees'
print train_scores[0].mean(),'±',train_scores[0].std()
print ' 80 training sizees'
print train_scores[1].mean(),'±',train_scores[1].std()
print ' 110 training sizees'
print train_scores[2].mean(),'±',train_scores[2].std()

print '\n validation scores'
print ' 50 validation scores'
print valid_scores[0].mean(),'±',valid_scores[0].std()
print ' 80 validation scores'
print valid_scores[1].mean(),'±',valid_scores[1].std()
print ' 110 validation scores'
print valid_scores[2].mean(),'±',valid_scores[2].std()
# Out:
# train_sizes =  [ 50  80 110]
#  training scores
#  50 training sizees
# 0.793043269204 ± 0.0543095612555
#  80 training sizees
# 0.791400635434 ± 0.0419635733068
#  110 training sizees
# 0.786043927682 ± 0.0376978228821
#
#  validation scores
#  50 validation scores
# 0.0482904283725 ± 0.359426582713
#  80 validation scores
# 0.389903777853 ± 0.20183580179
#  110 validation scores
# 0.522138623899 ± 0.0978608055482

# %% [markdown]
# ## Cross validation

# %%
scoring = 'mean_squared_error'
results = cross_validation.cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
print 'Scoring according to mean_squared_error'
print results
print '\n Mean      Standard deviation'
print("%.2f      %.2f" % (results.mean(), results.std()))
## Fit the model
model.fit(X,Y)
# Out:
# Scoring according to mean_squared_error
# [ -9.68221027 -13.87657232 -12.79464179  -9.82363133 -10.41002302
#  -13.07107827  -7.15749841 -11.2243733   -9.76349116 -13.08755793]
#
#  Mean      Standard deviation
# -11.09      2.00
# KernelRidge(alpha=0.0216, coef0=1, degree=3, gamma=0.052, kernel='rbf',
#       kernel_params=None)

# %% [markdown]
# To be more precise these valrible is not the input feature as descripe on the dataset, those varibles in scaled virsion on the orginal onces. So, to be more correct I should assign to them another varibles but for easy to unserstand I kept them as they were.

# %% [markdown]
# ## Coefficients Of Determination {Calculating R^2}
#
# R^2, Close to one is better

# %%
predicted = cross_val_predict(model, X, Y, cv=kfold)
r_squared = r2_score(Y, predicted, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# R-squared =  0.767450418421

# %% [markdown]
# ## Residual Plot

# %%
predicted = cross_val_predict(model, X, Y, cv=kfold)
fig, ax = plt.subplots()
ax.scatter(Y, predicted)
ax.plot([Y.min(), Y.max()], [Y.min(), Y.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()

# %%
# Plotining using bokeh
#TOOLS = [BoxSelectTool(), HoverTool()]
#TOOLS = 'hover,box_zoom,box_select,crosshair,resize,reset,lasso_select,pan,save,poly_select,tap,wheel_zoom,undo'
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,lasso_select,pan,save,poly_select,tap,wheel_zoom,undo'
p = figure(plot_width=500, plot_height=500, tools=TOOLS)
p.scatter(Y, predicted,x="jjj", marker="o", color="#80B1D3", line_width=3)
p.title.align = "center"
p.xaxis.axis_label = "Measured"
p.xaxis.axis_label_text_color = "#aa6666"
#p.xaxis.axis_label_standoff = 30
p.xaxis.major_tick_line_color = "firebrick"
p.xaxis.major_tick_line_width = 3
p.xaxis.minor_tick_line_color = "orange"
p.yaxis.axis_label = "Predicted"
p.yaxis.axis_label_text_font_style = "italic"
p.yaxis.axis_label_text_color = "#aa6666"
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
#p.line([Y.min(), Y.max()], [Y.min(), Y.max()], line_dash="4 4", line_width=2, color='red')

# create a new plot with the toolbar below
# line_dash="4 4", line_width=2, color='red'
p.line([Y.min(), Y.max()], [Y.min(), Y.max()], line_dash="4 4", line_width=2, line_color="black")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="536cb85d-50a9-491a-8601-a06ec3290c2b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#536cb85d-50a9-491a-8601-a06ec3290c2b").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("536cb85d-50a9-491a-8601-a06ec3290c2b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '536cb85d-50a9-491a-8601-a06ec3290c2b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"df1e9254-3b02-4edb-9e96-5c90d7e568ca":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"f0b80ee5-a2ad-4bef-9826-afa623173b30","type":"PolyAnnotation"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"d71e3506-0a7b-4eb8-bf3a-ce8f65aa50cb","type":"BoxZoomTool"},{"id":"b69fda7b-6a5f-493e-9468-065dd7937e93","type":"BoxSelectTool"},{"id":"c9e0af57-b900-4670-978c-7079051cd98b","type":"CrosshairTool"},{"id":"4ad2954d-8b4a-4c6e-9c4f-34ecccbe6279","type":"ResizeTool"},{"id":"d8bf237b-458c-4c06-ac08-6c542bf8d675","type":"ResetTool"},{"id":"f98c8295-8d82-4073-b1b2-e4f64219e111","type":"LassoSelectTool"},{"id":"2775fa7b-043a-453f-9d5c-189e8306fb1e","type":"PanTool"},{"id":"9c52d05f-2cd8-421a-aa91-69046320f1fc","type":"SaveTool"},{"id":"0e119e36-3243-4fca-ad63-6583f4f6135b","type":"PolySelectTool"},{"id":"46bfaee4-0877-4ded-9715-d509c546f982","type":"TapTool"},{"id":"bc13d4a5-1a69-4a2b-993d-5b07ba0d872a","type":"WheelZoomTool"},{"id":"38b56d79-f5cc-4915-bad6-a9b32e262926","type":"UndoTool"}]},"id":"424578fb-b300-4ba2-9be6-3c2132a5cc7e","type":"Toolbar"},{"attributes":{"plot":{"id":"7b4fcf1a-84cb-4e27-9cb1-215380c5fc2f","subtype":"Figure","type":"Plot"}},"id":"bc13d4a5-1a69-4a2b-993d-5b07ba0d872a","type":"WheelZoomTool"},{"attributes":{},"id":"62679af5-6bb1-4b3c-878f-c842fb398b1c","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[4,4],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"e7add4f7-8d99-4bde-b88d-1668261b0dea","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7889d415-846d-4985-ad6e-6d882490a955","type":"BoxAnnotation"},{"attributes":{"axis_label":"Predicted","axis_label_text_color":{"value":"#aa6666"},"formatter":{"id":"62679af5-6bb1-4b3c-878f-c842fb398b1c","type":"BasicTickFormatter"},"plot":{"id":"7b4fcf1a-84cb-4e27-9cb1-215380c5fc2f","subtype":"Figure","type":"Plot"},"ticker":{"id":"ac40378f-3ee2-4f84-bbfd-8975fac9cc44","type":"BasicTicker"}},"id":"a524577c-64d6-4b82-98d7-04543be44752","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[104.13,140.987],"y":[104.13,140.987]}},"id":"bfc7a3fb-7871-41df-8c44-bdaf56ef76d8","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"bfc7a3fb-7871-41df-8c44-bdaf56ef76d8","type":"ColumnDataSource"},"glyph":{"id":"04c56c53-65eb-4383-871c-6c093e296438","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"e7add4f7-8d99-4bde-b88d-1668261b0dea","type":"Line"},"selection_glyph":null},"id":"bce78631-972d-4822-b0a1-651cc6f5d26c","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"f0b80ee5-a2ad-4bef-9826-afa623173b30","type":"PolyAnnotation"},"plot":{"id":"7b4fcf1a-84cb-4e27-9cb1-215380c5fc2f","subtype":"Figure","type":"Plot"}},"id":"0e119e36-3243-4fca-ad63-6583f4f6135b","type":"PolySelectTool"},{"attributes":{"callback":null,"plot":{"id":"7b4fcf1a-84cb-4e27-9cb1-215380c5fc2f","subtype":"Figure","type":"Plot"}},"id":"46bfaee4-0877-4ded-9715-d509c546f982","type":"TapTool"},{"attributes":{"background_fill_alpha":{"value":0.5},"background_fill_color":{"value":"beige"},"below":[{"id":"897e50e5-2e19-4f8c-bd00-0882176799f2","type":"LinearAxis"}],"left":[{"id":"a524577c-64d6-4b82-98d7-04543be44752","type":"LinearAxis"}],"plot_height":500,"plot_width":500,"renderers":[{"id":"897e50e5-2e19-4f8c-bd00-0882176799f2","type":"LinearAxis"},{"id":"5a036a3d-6b99-4324-bcee-2694ebcb5a35","ty ...

# %%
plt.scatter(predicted, (predicted - Y), c='r', s=30)
plt.title("Residual plot on the training data")
plt.xlabel("Predicted")
plt.ylabel("Residuals")

# %%
# Plotining using bokeh
#TOOLS = 'hover,box_zoom,box_select,crosshair,resize,reset,lasso_select,pan,save,poly_select,tap,wheel_zoom,undo'
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,lasso_select,pan,save,poly_select,tap,wheel_zoom,undo'
p = figure(plot_width=500, plot_height=500, title="Residual plot on the training data", tools=TOOLS)
p.scatter(predicted, (predicted - Y),x="jjj", marker="o", color="#80B1D3", line_width=3)
p.title.align = "center"
p.xaxis.axis_label = "Predicted"
p.xaxis.axis_label_text_color = "#aa6666"
#p.xaxis.axis_label_standoff = 30
p.xaxis.major_tick_line_color = "firebrick"
p.xaxis.major_tick_line_width = 3
p.xaxis.minor_tick_line_color = "orange"
p.yaxis.axis_label = "Residuals"
p.yaxis.axis_label_text_font_style = "italic"
p.yaxis.axis_label_text_color = "#aa6666"
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
#p.line([2,38], [0, 0], line_dash="4 4", line_width=2, color='red')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="130d785e-c966-4a51-ba27-b5627fa892e9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#130d785e-c966-4a51-ba27-b5627fa892e9").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("130d785e-c966-4a51-ba27-b5627fa892e9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '130d785e-c966-4a51-ba27-b5627fa892e9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"dd916592-8daa-41fd-99b9-13d3ec92f4b4":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"5f769517-1672-4ad0-b856-53a4a1c0d53d","type":"Circle"},{"attributes":{"callback":null,"overlay":{"id":"e6f665e2-9ace-458f-b380-6df1a5d0e881","type":"BoxAnnotation"},"plot":{"id":"35948735-76fe-4d3a-a37d-c4dbd9f40377","subtype":"Figure","type":"Plot"},"renderers":[{"id":"42fc6cf1-8a28-4b12-8e53-20ea6ae1a0a9","type":"GlyphRenderer"}]},"id":"5c7b0c2a-a576-421c-a55e-a82f86cfaade","type":"BoxSelectTool"},{"attributes":{"align":"center","plot":null,"text":"Residual plot on the training data"},"id":"109da51d-8c95-4153-84f7-b7073a1c1e47","type":"Title"},{"attributes":{"overlay":{"id":"5debe7fb-bd7b-4618-9611-3105f148859d","type":"PolyAnnotation"},"plot":{"id":"35948735-76fe-4d3a-a37d-c4dbd9f40377","subtype":"Figure","type":"Plot"}},"id":"06415775-fef2-45bd-90d8-ad2971f141ba","type":"PolySelectTool"},{"attributes":{"plot":{"id":"35948735-76fe-4d3a-a37d-c4dbd9f40377","subtype":"Figure","type":"Plot"}},"id":"963611be-c46e-4c4c-9da6-9fe8424755e7","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[128.8099920515715,130.8711660649767,118.21481567809201,123.94544168934692,112.90010841034382,132.53294766869135,126.7779210147994,122.93480830419458,125.47825871602663,135.61993306825025,126.85771363561253,130.75606331926792,109.65026242319004,125.76875469085576,123.30581409834576,128.36860593950814,120.62675228465218,126.77806749330603,124.30484616992476,121.47277496671654,118.48196575136774,124.33864507482758,109.26145835365128,122.93547177769142,116.82897581527618,122.51736705681446,116.22731969083156,132.00983150744787,126.13738858892975,130.05353778692051,132.91185689326062,116.38739360027421,128.08568725281793,118.5442544005557,124.8581981991814,117.24023968519373,132.70732937185653,110.51011668132992,128.56664211798352,128.20098363439365,126.60686987426607,127.08357426005091,115.67863200279817,114.5049366856245,125.7357207900859,121.62399778619698,122.78121612430971,121.67176222716125,111.96406470147122,131.4579650368587,130.96620901357892,122.74359800700313,128.23655011537835,123.92838446534142,130.02954410584152,130.46686996508083,125.53213002663415,123.40375738293187,115.79302481783816,119.66101749768904,127.42681534998269,129.58980265554328,117.89804623275836,129.67516940770042,128.32259052677614,116.88857091195712,127.18516828187376,122.50855171219132,128.43905257968527,122.17095432584995,126.24911208005028,118.07898289650677,131.03223891801895,131.28420720352324,127.8529516118158,124.81475992104015,128.88702615559896,127.35398296972721,127.3343242725839,128.36234066060365,116.88369448525941,129.9389112051383,130.60341217768064,111.06097799326756,120.92121227825749,109.79500424552157,128.0738312952053,124.6774651700598,117.89303283445793,128.5782262399216,129.65343339368883,126.64402827641015,119.38720898923995,128.4112979155882,129.03399538640224,131.592324606072,125.28982888090536,128.42317172928324,120.63997559996915,134.2967579674539,125.72305273527172,133.2230718628332,120.55489261019545,127.4000836025557,123.87126212067437,125.73119667392257,132.73941393696532,125.03569509119643,127.63023511392339,117.48318708409579,130.5886867002614,123.91618544201492,128.40899494233668,128.3331142283905,129.641632882061,131.22011451595858,123.86912313896391,128.39429396243895,128.01238666371046,118.84665966539251,130.1097714611842,117.8045774390495,129.64317673344465,127.64452226006233,127.06873609662613,124.23470997648894,123.90282955939358,129.57724958294511,121.29790836650642,128.93347787089152,119.51771948600174,131.90898248553708,127.91203567055157,126.24314872940033,124.98586249208688,126.7530001284851,129.95434478325564,121.36902561602881,128.28256225268552,131.52761427072733,131.1499698737934,132.67249302093876 ...

# %% [markdown]
# ## Pipeline

# %% [markdown]
# The best to deliver the model by pipeline the operation then at deployment can be done in one model.

# %% [markdown]
#   I used two ways to check the pipeline so any one can be fine

# %%
# Use Pipeline
# ANOVA 
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, f_regression
anova_filter = SelectKBest(f_regression, k=5)
LRR = KernelRidge(kernel='rbf', gamma=0.052, alpha =  0.0216)
anova_LinReg = Pipeline([('scaler_Input',scaler), ('anova', anova_filter), ('LinReg', LRR)])
# You can set the parameters using the names issued
# For instance, fit using a k of 10 in the SelectKBest
anova_LinReg.set_params(anova__k=5).fit(new_data, Y)
prediction = anova_LinReg.predict(new_data)
print anova_LinReg.score(new_data, Y)                        
# getting the selected features chosen by anova_filter
results = cross_validation.cross_val_score(anova_LinReg, new_data, Y, cv=kfold, scoring=scoring)
print 'Scoring according to mean_squared_error'
print results
print '\n Mean      Standard deviation'
print("%.2f      %.2f" % (results.mean(), results.std()))
print anova_LinReg.named_steps['anova'].get_support()
r_squared = r2_score(Y, prediction, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# 0.792548393714
# Scoring according to mean_squared_error
# [ -9.71112527 -13.94659676 -12.7985312   -9.65161805 -10.44095022
#  -13.00363012  -7.20217413 -11.1686541   -9.74808842 -13.10827691]
#
#  Mean      Standard deviation
# -11.08      2.00
# [ True  True  True  True  True]
# R-squared =  0.792548393714

# %%
# Using make_pipeline
from sklearn.pipeline import make_pipeline

# ANOVA SVM-C
# 1) anova filter, take 3 best ranked features
anova_filter = SelectKBest(f_regression, k=5)
anova_KernelRidge = make_pipeline(scaler, anova_filter, LRR)
anova_KernelRidge.fit(new_data, Y)
prediction = anova_KernelRidge.predict(new_data)
r_squared = r2_score(Y, prediction, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# R-squared =  0.792548393714

# %% [markdown]
# ### Save the Pipeline model for developement

# %%
# save the model scaler to the desk
from sklearn.externals import joblib
joblib.dump(anova_KernelRidge, 'anova_KernelRidge.pkl')
# Out:
# ['anova_KernelRidge.pkl',
#  'anova_KernelRidge.pkl_01.npy',
#  'anova_KernelRidge.pkl_02.npy',
#  'anova_KernelRidge.pkl_03.npy',
#  'anova_KernelRidge.pkl_04.npy',
#  'anova_KernelRidge.pkl_05.npy',
#  'anova_KernelRidge.pkl_06.npy',
#  'anova_KernelRidge.pkl_07.npy']

# %%
# Test the model if it is work
anova_KernelRidgeTest = joblib.load('anova_KernelRidge.pkl')
NewPred = anova_KernelRidgeTest.predict(new_data)
print " =================================================================>>>>> done"
r_squared = r2_score(Y, NewPred, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
#  =================================================================>>>>> done
# R-squared =  0.792548393714

# %%
# test on single data point, randomly choose point number 55
print 'Point of training data before normalization\n',new_data[55]
print '\nThe read target of the data = ', Y[55]
NewPred = anova_KernelRidgeTest.predict([new_data[55]])
print '\nThe Predicted target of the data = ', NewPred
# Out:
# Point of training data before normalization
# [  1.00000000e+03   2.70000000e+00   1.52400000e-01   7.13000000e+01
#    2.43851000e-03]
#
# The read target of the data =  128.774
#
# The Predicted target of the data =  [ 130.67923004]

# %% [markdown]
# ## Conclusion
