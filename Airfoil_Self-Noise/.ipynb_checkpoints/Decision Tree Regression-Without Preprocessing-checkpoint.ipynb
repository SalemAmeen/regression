# %% [markdown]
# Salem Ameen, PhD student at Salford University
#
# ### Airfoil Self-Noise price
#
# Decision trees Regression

# %% [markdown]
# # Import the Libraries

# %%
import numpy as np
import pandas
from numpy import *
import time
import sys
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import feature_selection
from sklearn.tree import DecisionTreeRegressor
from sklearn.learning_curve import learning_curve, validation_curve
from sklearn.cross_validation import cross_val_predict
from sklearn import metrics, grid_search, cross_validation
from IPython.display import set_matplotlib_formats
from bokeh.plotting import figure, show, output_notebook
from sklearn.grid_search import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import r2_score
from bokeh.layouts import gridplot
output_notebook()
set_matplotlib_formats('png', 'pdf')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (6, 6)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="be5067fc-a9a9-487c-adc6-e77ff61f231d">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Load data

# %% [markdown]
# In the previous file we have not change the data as there is no missing value or add any new parameters so it can be downloaded from the web directly.

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00291/airfoil_self_noise.dat'
names = ['Frequency', 'Angle', 'Chord', 'Free_stream', 'Suction', 'pressure']
feature_names = names
feature_cols = names
data = pd.read_csv(url, sep='\s+', names = names)

from sklearn import preprocessing
dataset = data.values
X = dataset[:,0:5].astype(float)
Y = dataset[:,5]
print 'Number of examples',len(X)
# Out:
# Number of examples 1503

# %%
# Make developement dataset for genrilization and final testing
from sklearn.cross_validation import train_test_split
# Extracting 20% testing data
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.20, random_state=0)
X = X_train
Y = y_train
new_data      = X_train
new_test_data = X_test
print 'Number of training examples',len(X_train)
print 'Number of validation examples',len(X_test)
# Out:
# Number of training examples 1202
# Number of validation examples 301

# %% [markdown]
# Number of training data is very small so we need to use cross validation instead of spareate another validation data.

# %% [markdown]
# From the previous visulization the data has no missing value but has many outlier and some sparisty

# %% [markdown]
# # Ranking of the feature's importance to the target

# %%
# Using just correlation coefficient even in prevoius file we show them using data frame
for col in feature_cols:
    lm = DecisionTreeRegressor()
    lm.fit(data[[col]], data['pressure'])
    print col,'\t', lm.score(data[[col]], data['pressure'])
# Out:
# Frequency 	0.208538014689
# Angle 	0.170777839353
# Chord 	0.0690445352687
# Free_stream 	0.0200966819657
# Suction 	0.293078622679
# pressure 	1.0

# %%
# Randing the important features to the target
model = feature_selection.SelectKBest(score_func=feature_selection.f_regression,k=4)
results = model.fit(data[feature_cols], data['pressure'])
k=0
print 'Feature Name      Score         Pvalue'
for feat in feature_cols:
    print feat,'\t\t',results.scores_[k],'\t',results.pvalues_[k]
    k=k+1
# Out:
# Feature Name      Score         Pvalue
# Frequency 		270.416272463 	5.36177705642e-56
# Angle 		37.4923835551 	1.16954827306e-09
# Chord 		88.6588675485 	1.70142015337e-20
# Free_stream 		23.8652245755 	1.1437427443e-06
# Suction 		162.641263457 	1.92478295603e-35
# pressure 		inf 	0.0

# %% [markdown]
# # Set the parameters for cross validation

# %%
num_folds = 10
num_instances = len(X)
seed = 7
kfold = cross_validation.KFold(n=num_instances, n_folds=num_folds, random_state=seed)

# %% [markdown]
#  # Set the parameters for bias-variance dilemma

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %% [markdown]
# # 1. DecisionTreeRegressor  with   Regression

# %% [markdown]
# Decision trees or the Classification and Regression Trees (CART as they are know) use the training data to select the best points to split the data in order to minimize a cost metric. The default cost metric for regression decision trees is the mean squared error, specified in the criterion parameter.

# %% [markdown]
# ## Validation curve

# %% [markdown]
# choosing multiple hyperparameters of an estimator

# %%
from sklearn.tree import DecisionTreeRegressor
estimator = DecisionTreeRegressor()
estimator.get_params().keys()
# Out:
# ['presort',
#  'splitter',
#  'max_leaf_nodes',
#  'min_samples_leaf',
#  'min_samples_split',
#  'min_weight_fraction_leaf',
#  'criterion',
#  'random_state',
#  'max_features',
#  'max_depth']

# %%
# For parametr alpha
#param_range = np.logspace(-10.0, 10.0)
#param_range = np.linspace(1,50,100)
param_range = np.arange(1,50) # generate integer numbers

train_scores, test_scores = validation_curve(
    DecisionTreeRegressor(), X, Y, param_name="max_depth", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with DecisionTreeRegressor")
plt.xlabel("max_depth")
plt.ylabel("Score")
plt.ylim(0.4, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# more that 5 is the best of number of K

# %%
# For parametr alpha
#param_range = np.logspace(-10.0, 10.0)
#param_range = np.linspace(1,50,100)
param_range = np.arange(1,10) # generate integer numbers

train_scores, test_scores = validation_curve(
    DecisionTreeRegressor(), X, Y, param_name="min_samples_split", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with DecisionTreeRegressor")
plt.xlabel("min_samples_split")
plt.ylabel("Score")
plt.ylim(0.4, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# min_samples_split =2 (The defualt) is the best

# %%
# For parametr alpha
#param_range = np.logspace(-10.0, 10.0)
#param_range = np.linspace(1,50,100)
param_range = np.arange(1,10) # generate integer numbers

train_scores, test_scores = validation_curve(
    DecisionTreeRegressor(), X, Y, param_name="min_samples_leaf", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with DecisionTreeRegressor")
plt.xlabel("min_samples_leaf")
plt.ylabel("Score")
plt.ylim(0.4, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# min_samples_leaf = 2 is the best

# %% [markdown]
# ## Grid search and/or Random search to determine best compination of parameters

# %%
# Utility function to report optimal parameters
from operator import itemgetter
def report(grid_scores, n_top=5):
    params = None
    top_scores = sorted(grid_scores, key=itemgetter(1), reverse=True)[:n_top]
    for i, score in enumerate(top_scores):
        print("Parameters with rank: {0}".format(i + 1))
        print("Mean validation score: {0:.4f} (std: {1:.4f})".format(
              score.mean_validation_score, np.std(score.cv_validation_scores)))
        print("Parameters: {0}".format(score.parameters))
        print("")
        
        if params == None:
            params = score.parameters
    
    return params

# The most common value for the max number of features to look at in each split is sqrt(# of features)
sqrtfeat = np.sqrt(X.shape[1]) 
grid_test1 = { "max_depth"      : np.arange(1,15),
             "min_samples_split"      : np.arange(1,4),
             "min_samples_leaf"    : np.arange(1,3)}

# Large randomized test using max_depth to control tree size (5000 possible combinations)
random_test1 = { "max_depth"      : [1,10],
                "min_samples_split"      : [ 1,2],
               "min_samples_leaf"   : [1,2]}


forest =  DecisionTreeRegressor()

print "Hyperparameter optimization using GridSearchCV..."
grid_search = GridSearchCV(forest, grid_test1, n_jobs=-1, cv=num_folds)
grid_search.fit(X, Y)
best_params_from_grid_search = report(grid_search.grid_scores_)
print '+++++++++++++++++++++++++++++++++++++++++++++++'
print "Hyperparameter optimization using RandomizedSearchCV"
grid_search = RandomizedSearchCV(forest, random_test1, n_jobs=-1, cv=num_folds, n_iter=5)
grid_search.fit(X, Y)
best_params_from_rand_search1 = report(grid_search.grid_scores_)
# Out:
# Hyperparameter optimization using GridSearchCV...
# Parameters with rank: 1
# Mean validation score: 0.8503 (std: 0.0444)
# Parameters: {'min_samples_split': 3, 'max_depth': 14, 'min_samples_leaf': 1}
#
# Parameters with rank: 2
# Mean validation score: 0.8476 (std: 0.0441)
# Parameters: {'min_samples_split': 2, 'max_depth': 13, 'min_samples_leaf': 1}
#
# Parameters with rank: 3
# Mean validation score: 0.8458 (std: 0.0451)
# Parameters: {'min_samples_split': 3, 'max_depth': 13, 'min_samples_leaf': 1}
#
# Parameters with rank: 4
# Mean validation score: 0.8451 (std: 0.0503)
# Parameters: {'min_samples_split': 1, 'max_depth': 14, 'min_samples_leaf': 1}
#
# Parameters with rank: 5
# Mean validation score: 0.8451 (std: 0.0528)
# Parameters: {'min_samples_split': 2, 'max_depth': 14, 'min_samples_leaf': 1}
#
# +++++++++++++++++++++++++++++++++++++++++++++++
# Hyperparameter optimization using RandomizedSearchCV
# Parameters with rank: 1
# Mean validation score: 0.8076 (std: 0.0406)
# Parameters: {'min_samples_split': 1, 'max_depth': 10, 'min_samples_leaf': 2}
#
# Parameters with rank: 2
# Mean validation score: 0.8054 (std: 0.0511)
# Parameters: {'min_samples_split': 1, 'max_depth': 10, 'min_samples_leaf': 1}
#
# Parameters with rank: 3
# Mean validation score: 0.8051 (std: 0.0427)
# Parameters: {'min_samples_split': 2, 'max_depth': 10, 'min_samples_leaf': 2}
#
# Parameters with rank: 4
# Mean validation score: 0.1497 (std: 0.0632)
# Parameters: {'min_samples_split': 2, 'max_depth': 1, 'min_samples_leaf': 1}
#
# Parameters with rank: 5
# Mean validation score: 0.1497 (std: 0.0632)
# Parameters: {'min_samples_split': 1, 'max_depth': 1, 'min_samples_leaf': 1}

# %% [markdown]
# Best 'min_samples_split': 3, 'max_depth': 7, 'min_samples_leaf': 1

# %% [markdown]
# ## Learning Curve

# %% [markdown]
# In essence, what we’re doing it training the exact same model with increasingly large fractions of our total training data, and plotting the error of the training and test sets at each step.

# %%
from sklearn.tree import DecisionTreeRegressor

model =  DecisionTreeRegressor(min_samples_split = 3, max_depth = 7, min_samples_leaf =1 )
title = "Learning Curves (  DecisionTreeRegressor Refression)"
cv = cross_validation.ShuffleSplit(X.shape[0], n_iter=100,
                                   test_size=0.2, random_state=0)
plot_learning_curve(model, title, X, Y, ylim=(0.2, 1.01), cv=cv, n_jobs=-1)
plt.show()

# %%
# More data from learning curve to show the process of building the model
train_sizes, train_scores, valid_scores = learning_curve(
     model, X, Y, train_sizes=[50, 80, 110], cv=cv, n_jobs=4)

print 'train_sizes = ', train_sizes

print ' training scores'
print ' 50 training sizees'
print train_scores[0].mean(),'±',train_scores[0].std()
print ' 80 training sizees'
print train_scores[1].mean(),'±',train_scores[1].std()
print ' 110 training sizees'
print train_scores[2].mean(),'±',train_scores[2].std()

print '\n validation scores'
print ' 50 validation scores'
print valid_scores[0].mean(),'±',valid_scores[0].std()
print ' 80 validation scores'
print valid_scores[1].mean(),'±',valid_scores[1].std()
print ' 110 validation scores'
print valid_scores[2].mean(),'±',valid_scores[2].std()
# Out:
# train_sizes =  [ 50  80 110]
#  training scores
#  50 training sizees
# 0.956857380027 ± 0.0390480189522
#  80 training sizees
# 0.944827854652 ± 0.0365772042287
#  110 training sizees
# 0.93475951265 ± 0.0302147962972
#
#  validation scores
#  50 validation scores
# 0.157978950791 ± 0.18469006282
#  80 validation scores
# 0.293209006708 ± 0.150087978267
#  110 validation scores
# 0.377509543074 ± 0.109416492149

# %% [markdown]
# ## Cross validation

# %%
scoring = 'mean_squared_error'
results = cross_validation.cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
print 'Scoring according to mean_squared_error'
print results
print '\n Mean      Standard deviation'
print("%.2f      %.2f" % (results.mean(), results.std()))
## Fit the model
model.fit(X,Y)
# Out:
# Scoring according to mean_squared_error
# [-13.36776248 -12.00150206 -11.96503107 -14.14560586 -11.4692446
#  -12.29479266  -9.84423143 -15.68441843  -9.76310179 -14.10225247]
#
#  Mean      Standard deviation
# -12.46      1.80
# DecisionTreeRegressor(criterion='mse', max_depth=7, max_features=None,
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=3,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %% [markdown]
# ## Coefficients Of Determination {Calculating R^2}
#
# R^2, Close to one is better

# %%
predicted = cross_val_predict(model, X, Y, cv=kfold)
r_squared = r2_score(Y, predicted, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# R-squared =  0.739016545947

# %% [markdown]
# ## Residual Plot

# %%
predicted = cross_val_predict(model, X, Y, cv=kfold)
fig, ax = plt.subplots()
ax.scatter(Y, predicted)
ax.plot([Y.min(), Y.max()], [Y.min(), Y.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()

# %%
# Plotining using bokeh
#TOOLS = [BoxSelectTool(), HoverTool()]
#TOOLS = 'hover,box_zoom,box_select,crosshair,resize,reset,DecisionTreeRegressor_select,pan,save,poly_select,tap,wheel_zoom,undo'
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,lasso_select,pan,save,poly_select,tap,wheel_zoom,undo'
p = figure(plot_width=500, plot_height=500, tools=TOOLS)
p.scatter(Y, predicted,x="jjj", marker="o", color="#80B1D3", line_width=3)
p.title.align = "center"
p.xaxis.axis_label = "Measured"
p.xaxis.axis_label_text_color = "#aa6666"
#p.xaxis.axis_label_standoff = 30
p.xaxis.major_tick_line_color = "firebrick"
p.xaxis.major_tick_line_width = 3
p.xaxis.minor_tick_line_color = "orange"
p.yaxis.axis_label = "Predicted"
p.yaxis.axis_label_text_font_style = "italic"
p.yaxis.axis_label_text_color = "#aa6666"
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
#p.line([Y.min(), Y.max()], [Y.min(), Y.max()], line_dash="4 4", line_width=2, color='red')

# create a new plot with the toolbar below
# line_dash="4 4", line_width=2, color='red'
p.line([Y.min(), Y.max()], [Y.min(), Y.max()], line_dash="4 4", line_width=2, line_color="black")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="a2ad5fa5-13e6-4a5c-867c-a60b321c8f73"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#a2ad5fa5-13e6-4a5c-867c-a60b321c8f73").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a2ad5fa5-13e6-4a5c-867c-a60b321c8f73");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a2ad5fa5-13e6-4a5c-867c-a60b321c8f73' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"305696b1-3936-41c4-ab47-8d1928c32669":{"roots":{"references":[{"attributes":{"plot":{"id":"be149d40-504f-46ee-9c61-ca0867b0d854","subtype":"Figure","type":"Plot"}},"id":"573fe530-793a-4760-8be7-d8d6a6f71944","type":"UndoTool"},{"attributes":{"plot":{"id":"be149d40-504f-46ee-9c61-ca0867b0d854","subtype":"Figure","type":"Plot"}},"id":"d072a223-163d-4366-9245-63e746c21e42","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"e1d8626d-92bc-4ae6-8b64-6207daf4bd7e","type":"PolyAnnotation"},{"attributes":{"plot":{"id":"be149d40-504f-46ee-9c61-ca0867b0d854","subtype":"Figure","type":"Plot"},"ticker":{"id":"0367ecc4-5b57-4ffd-a826-78a9298278b5","type":"BasicTicker"}},"id":"13be2de3-020c-40ea-b341-2abec40250e6","type":"Grid"},{"attributes":{"data_source":{"id":"b056ed75-2553-4448-80e8-2233d03ce5fe","type":"ColumnDataSource"},"glyph":{"id":"5baf851f-d874-4b6e-a35f-01ff2dd8685f","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"fccfdb63-4856-48ac-b007-12950e62c4b7","type":"Line"},"selection_glyph":null},"id":"d09df46e-b2cf-470f-bd79-39c16b96f3b3","type":"GlyphRenderer"},{"attributes":{"callback":null,"plot":{"id":"be149d40-504f-46ee-9c61-ca0867b0d854","subtype":"Figure","type":"Plot"}},"id":"02b6f044-f0b9-4dd2-a7fd-0588e65827cf","type":"TapTool"},{"attributes":{"callback":null},"id":"bd063738-1694-4953-acfc-adaa749fc94e","type":"DataRange1d"},{"attributes":{"overlay":{"id":"e1d8626d-92bc-4ae6-8b64-6207daf4bd7e","type":"PolyAnnotation"},"plot":{"id":"be149d40-504f-46ee-9c61-ca0867b0d854","subtype":"Figure","type":"Plot"}},"id":"302e2ef3-3b65-4aed-9c82-c696ac674907","type":"PolySelectTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"034f2950-bbfb-4972-8e51-9c3df9faf162","type":"PolyAnnotation"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cd745a31-d94a-46fb-89f0-d8832a98f704","type":"BoxAnnotation"},{"attributes":{},"id":"7208209a-30ea-4cb4-b297-599a7ce071c8","type":"BasicTicker"},{"attributes":{"axis_label":"Measured","axis_label_text_color":{"value":"#aa6666"},"formatter":{"id":"d7897dc3-5e36-4286-b9fa-a109376a7ac1","type":"BasicTickFormatter"},"major_tick_line_color":{"value":"firebrick"},"major_tick_line_width":{"value":3},"minor_tick_line_color":{"value":"orange"},"plot":{"id":"be149d40-504f-46ee-9c61-ca0867b0d854","subtype":"Figure","type":"Plot"},"ticker":{"id":"0367ecc4-5b57-4ffd-a826-78a9298278b5","type":"BasicTicker"}},"id":"f3ced7bd-4551-4927-a6ce-9671c7515f52","type":"LinearAxis"},{"attributes":{"plot":{"id":"be149d40-504f-46ee-9c61-ca0867b0d854","subtype":"Figure","type":"Plot"}},"id":"ad03ff02-07ed-4c57-ae63-493f57449b94","type":"CrosshairTool"},{"attributes":{},"id":"d7897dc3-5e36-4286-b9fa-a109376a7ac1","type":"BasicTickFormatter"},{"attributes":{},"id":"0367ecc4-5b57-4ffd-a826-78a9298278b5","type":"BasicTicker"},{"attributes":{"plot":{"id":"be149d40-504f-46ee-9c61-ca0867b0d854","subtype":"Figure","type":"Plot"}},"id":"e91d91e5-0796-42a0-9836-ee73472c820a","type":"SaveTool"},{"attributes":{"plot":{"id":"be149d40-504f-46ee-9c61-ca0867b0d854","subtype":"Figure","type":"Plot"}},"id":"c921b0f7-b8b5-4cc2-88d8-29ef420d0456","type":"PanTool"},{"attributes":{"overlay":{"id":"842a0098-f7d4-4e35-93bf-2a0ccdb55372","type":"BoxAnnotation"},"plot":{"id":"be149d40-504f-46ee-9c61-ca0867b0d854","sub ...

# %%
plt.scatter(predicted, (predicted - Y), c='r', s=30)
plt.title("Residual plot on the training data")
plt.xlabel("Predicted")
plt.ylabel("Residuals")

# %%
# Plotining using bokeh
#TOOLS = 'hover,box_zoom,box_select,crosshair,resize,reset,DecisionTreeRegressor_select,pan,save,poly_select,tap,wheel_zoom,undo'
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,lasso_select,pan,save,poly_select,tap,wheel_zoom,undo'
p = figure(plot_width=500, plot_height=500, title="Residual plot on the training data", tools=TOOLS)
p.scatter(predicted, (predicted - Y),x="jjj", marker="o", color="#80B1D3", line_width=3)
p.title.align = "center"
p.xaxis.axis_label = "Predicted"
p.xaxis.axis_label_text_color = "#aa6666"
#p.xaxis.axis_label_standoff = 30
p.xaxis.major_tick_line_color = "firebrick"
p.xaxis.major_tick_line_width = 3
p.xaxis.minor_tick_line_color = "orange"
p.yaxis.axis_label = "Residuals"
p.yaxis.axis_label_text_font_style = "italic"
p.yaxis.axis_label_text_color = "#aa6666"
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
#p.line([2,38], [0, 0], line_dash="4 4", line_width=2, color='red')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="36960e43-5118-4dc6-a4d1-0de41bcff75a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#36960e43-5118-4dc6-a4d1-0de41bcff75a").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("36960e43-5118-4dc6-a4d1-0de41bcff75a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '36960e43-5118-4dc6-a4d1-0de41bcff75a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3a3514e3-89bb-4dc2-8a4d-c3f9dc037fe2":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#80B1D3"},"line_color":{"value":"#80B1D3"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"c98ae53f-0af3-45bc-9854-bda75b11b8c8","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cdb6193b-5f6f-423e-80e8-586be1025044","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"bd51497b-0189-459f-9a27-66c104381d2c","type":"BoxZoomTool"},{"id":"c194ec13-14d1-471f-a620-de22b3c554ca","type":"BoxSelectTool"},{"id":"f412b1f4-ed53-482e-b1d9-e0170e2cd609","type":"CrosshairTool"},{"id":"53ebc395-931c-4c6f-8ba3-689c977ed5e3","type":"ResizeTool"},{"id":"af8b2e58-287b-4809-b620-b8458203d44d","type":"ResetTool"},{"id":"cd99e7ff-3db1-474d-b257-25ef662c8cc8","type":"LassoSelectTool"},{"id":"b39d8b4e-268b-4e25-a267-2d215933a978","type":"PanTool"},{"id":"5a3a110e-5d19-4e69-b8b0-225cf9be2b44","type":"SaveTool"},{"id":"630411b1-1398-4b61-8fd8-66650ff0ee43","type":"PolySelectTool"},{"id":"26a2bee9-6566-413e-a3f3-fa0b618b2d42","type":"TapTool"},{"id":"a2e7d8d3-b371-403d-8073-c880154ae445","type":"WheelZoomTool"},{"id":"ffd95b7f-a04d-4046-a8de-9b954a6cd09e","type":"UndoTool"}]},"id":"759971a4-acd7-4569-a461-f5c44e30e3cc","type":"Toolbar"},{"attributes":{"callback":null,"overlay":{"id":"b880fef5-8c30-4598-af56-caf4a9a4a9a8","type":"PolyAnnotation"},"plot":{"id":"75c1964e-555d-4972-9f71-85558eec166e","subtype":"Figure","type":"Plot"}},"id":"cd99e7ff-3db1-474d-b257-25ef662c8cc8","type":"LassoSelectTool"},{"attributes":{"callback":null},"id":"1b2ea8d3-0089-4d6a-a96d-cad4f3747dfd","type":"DataRange1d"},{"attributes":{},"id":"e18bed6a-5d65-44eb-8b36-5115de2adf1b","type":"BasicTicker"},{"attributes":{"callback":null},"id":"a1b4d4b3-67e3-4801-b3c0-c72eaf9a374e","type":"DataRange1d"},{"attributes":{"plot":{"id":"75c1964e-555d-4972-9f71-85558eec166e","subtype":"Figure","type":"Plot"}},"id":"5a3a110e-5d19-4e69-b8b0-225cf9be2b44","type":"SaveTool"},{"attributes":{"plot":{"id":"75c1964e-555d-4972-9f71-85558eec166e","subtype":"Figure","type":"Plot"}},"id":"53ebc395-931c-4c6f-8ba3-689c977ed5e3","type":"ResizeTool"},{"attributes":{"background_fill_alpha":{"value":0.5},"background_fill_color":{"value":"beige"},"below":[{"id":"a2fcb760-73c7-47b8-a5f4-a5c0ef7e0993","type":"LinearAxis"}],"left":[{"id":"76c9d6f7-7904-40dd-8fc7-c9e425f9ac83","type":"LinearAxis"}],"plot_height":500,"plot_width":500,"renderers":[{"id":"a2fcb760-73c7-47b8-a5f4-a5c0ef7e0993","type":"LinearAxis"},{"id":"9c5b8291-0c81-4b3e-a5ca-8b7d0ff33d79","type":"Grid"},{"id":"76c9d6f7-7904-40dd-8fc7-c9e425f9ac83","type":"LinearAxis"},{"id":"759cd3fa-f4f8-4092-a342-c6e8df695388","type":"Grid"},{"id":"cdb6193b-5f6f-423e-80e8-586be1025044","type":"BoxAnnotation"},{"id":"29ef3718-c08a-4b23-a3e2-b628087f1e7c","type":"BoxAnnotation"},{"id":"b880fef5-8c30-4598-af56-caf4a9a4a9a8","type":"PolyAnnotation"},{"id":"d8728abf-1ff8-4661-87ac-b2b1d8b0d355","type":"PolyAnnotation"},{"id":"49d28b7b-32a8-4fd7-88fb-7cf096955ed0","type":"GlyphRenderer"}],"title":{"id":"681b3f17-c3ea-4b61-83d0-51d3db718639","type":"Title"},"tool_events":{"id":"651ba84a-b48b-4649-9ca2-ad65f890aca7","type":"ToolEvents"},"toolbar":{"id":"759971a4-acd7-4569-a461-f5c44e30e3cc","type":"Toolbar"},"x_range":{"id":"1b2ea8d3-0089-4d6a-a96d-cad4f3747dfd","type":"DataRange1d"},"y_range":{"id":"a1b4d4b3-67e3-4801-b3c0-c72eaf9a374e","type":"DataRange1d"}},"id":"75c1964e-555d-4972-9f71-85558eec166e","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"75c1964e-555d-4972-9f71-85558eec166e","subtype":"Figure","type":"Plot"}},"id":"f412b1f4-ed53-482e-b1d9-e0170 ...

# %% [markdown]
# ## Pipeline

# %% [markdown]
# The best to deliver the model by pipeline the operation then at deployment can be done in one model.

# %% [markdown]
#   I used two ways to check the pipeline so any one can be fine

# %%
# Use Pipeline
# ANOVA 
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, f_regression
anova_filter = SelectKBest(f_regression, k=5)
LR =  DecisionTreeRegressor(min_samples_split = 3, max_depth = 7, min_samples_leaf =1 )

anova_LinReg = Pipeline([ ('anova', anova_filter), ('LinReg', LR)])
# You can set the parameters using the names issued
# For instance, fit using a k of 10 in the SelectKBest
anova_LinReg.set_params(anova__k=5).fit(new_data, Y)
prediction = anova_LinReg.predict(new_data)
print anova_LinReg.score(new_data, Y)                        
# getting the selected features chosen by anova_filter
results = cross_validation.cross_val_score(anova_LinReg, new_data, Y, cv=kfold, scoring=scoring)
print 'Scoring according to mean_squared_error'
print results
print '\n Mean      Standard deviation'
print("%.2f      %.2f" % (results.mean(), results.std()))
print anova_LinReg.named_steps['anova'].get_support()
r_squared = r2_score(Y, prediction, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# 0.837289552482
# Scoring according to mean_squared_error
# [-13.32266344 -12.00150206 -11.96503107 -14.14560586 -11.4692446
#  -12.29479266  -9.84423143 -15.68441843  -9.76310179 -14.10225247]
#
#  Mean      Standard deviation
# -12.46      1.80
# [ True  True  True  True  True]
# R-squared =  0.837289552482

# %%
# Using make_pipeline
from sklearn.pipeline import make_pipeline

# ANOVA SVM-C
# 1) anova filter, take 3 best ranked features
anova_filter = SelectKBest(f_regression, k=5)
anova_DTRegressorNoPreprocessing = make_pipeline( anova_filter, LR)
anova_DTRegressorNoPreprocessing.fit(new_data, Y)
prediction = anova_DTRegressorNoPreprocessing.predict(new_data)
r_squared = r2_score(Y, prediction, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# R-squared =  0.837289552482

# %% [markdown]
# ### Save the Pipeline model for developement

# %%
# save the model scaler to the desk
from sklearn.externals import joblib
joblib.dump(anova_DTRegressorNoPreprocessing, 'anova_DTRegressorNoPreprocessing.pkl')
# Out:
# ['anova_DTRegressorNoPreprocessing.pkl',
#  'anova_DTRegressorNoPreprocessing.pkl_01.npy',
#  'anova_DTRegressorNoPreprocessing.pkl_02.npy',
#  'anova_DTRegressorNoPreprocessing.pkl_03.npy',
#  'anova_DTRegressorNoPreprocessing.pkl_04.npy',
#  'anova_DTRegressorNoPreprocessing.pkl_05.npy']

# %%
# Test the model if it is work
anova_DecisionTreeRegressorTest = joblib.load('anova_DTRegressorNoPreprocessing.pkl')
NewPred = anova_DecisionTreeRegressorTest.predict(new_data)
print " =================================================================>>>>> done"
r_squared = r2_score(Y, NewPred, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
#  =================================================================>>>>> done
# R-squared =  0.837289552482

# %%
# test on single data point, randomly choose point number 55
print 'Point of training data before normalization\n',new_data[55]
print '\nThe read target of the data = ', Y[55]
NewPred = anova_DecisionTreeRegressorTest.predict([new_data[55]])
print '\nThe Predicted target of the data = ', NewPred
# Out:
# Point of training data before normalization
# [  1.00000000e+03   2.70000000e+00   1.52400000e-01   7.13000000e+01
#    2.43851000e-03]
#
# The read target of the data =  128.774
#
# The Predicted target of the data =  [ 132.51132836]

# %% [markdown]
# ## Conclusion
