# %% [markdown]
# Salem Ameen, PhD student at Salford University
#
# ### Airfoil Self-Noise price
#
# Support Vector Machines Regression

# %% [markdown]
# # Import the Libraries

# %%
import numpy as np
import pandas
from numpy import *
import time
import sys
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import feature_selection
from sklearn.svm import SVR
from sklearn.learning_curve import learning_curve, validation_curve
from sklearn.cross_validation import cross_val_predict
from sklearn import metrics, grid_search, cross_validation
from IPython.display import set_matplotlib_formats
from bokeh.plotting import figure, show, output_notebook
from sklearn.grid_search import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import r2_score
from bokeh.layouts import gridplot
output_notebook()
set_matplotlib_formats('png', 'pdf')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (6, 6)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8363bd08-c267-478f-a2ea-ca1ce5e76aaa">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Load data

# %% [markdown]
# In the previous file we have not change the data as there is no missing value or add any new parameters so it can be downloaded from the web directly.

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00291/airfoil_self_noise.dat'
names = ['Frequency', 'Angle', 'Chord', 'Free_stream', 'Suction', 'pressure']
feature_names = names
feature_cols = names
data = pd.read_csv(url, sep='\s+', names = names)

from sklearn import preprocessing
dataset = data.values
X = dataset[:,0:5].astype(float)
Y = dataset[:,5]
print 'Number of examples',len(X)
# Out:
# Number of examples 1503

# %%
# Make developement dataset for genrilization and final testing
from sklearn.cross_validation import train_test_split
# Extracting 20% testing data
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.20, random_state=0)
X = X_train
Y = y_train
new_data      = X_train
new_test_data = X_test
print 'Number of training examples',len(X_train)
print 'Number of validation examples',len(X_test)
# Out:
# Number of training examples 1202
# Number of validation examples 301

# %% [markdown]
# Number of training data is very small so we need to use cross validation instead of spareate another validation data.

# %% [markdown]
# From the previous visulization the data has no missing value but has many outlier and some sparisty

# %% [markdown]
# # Ranking of the feature's importance to the target

# %%
# Using just correlation coefficient even in prevoius file we show them using data frame
for col in feature_cols:
    lm = SVR()
    lm.fit(data[[col]], data['pressure'])
    print col,'\t', lm.score(data[[col]], data['pressure'])
# Out:
# Frequency 	0.196770757664
# Angle 	0.0843749916499
# Chord 	0.0354947131873
# Free_stream 	0.00541008199643
# Suction 	-0.00414369501448
# pressure 	0.965776296395

# %%
# Randing the important features to the target
model = feature_selection.SelectKBest(score_func=feature_selection.f_regression,k=4)
results = model.fit(data[feature_cols], data['pressure'])
k=0
print 'Feature Name      Score         Pvalue'
for feat in feature_cols:
    print feat,'\t\t',results.scores_[k],'\t',results.pvalues_[k]
    k=k+1
# Out:
# Feature Name      Score         Pvalue
# Frequency 		270.416272463 	5.36177705642e-56
# Angle 		37.4923835551 	1.16954827306e-09
# Chord 		88.6588675485 	1.70142015337e-20
# Free_stream 		23.8652245755 	1.1437427443e-06
# Suction 		162.641263457 	1.92478295603e-35
# pressure 		inf 	0.0

# %% [markdown]
# # Set the parameters for cross validation

# %%
num_folds = 10
num_instances = len(X)
seed = 7
kfold = cross_validation.KFold(n=num_instances, n_folds=num_folds, random_state=seed)

# %% [markdown]
#  # Set the parameters for bias-variance dilemma

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %% [markdown]
# # Preprocessing the data and save both the model and preprocessed data

# %%
# According to the nature of the data spasity and there is outliter RobustScaler class is recomandit 
# but when I tried both of them the result seems is same
from sklearn.preprocessing import StandardScaler
scaler = preprocessing.StandardScaler().fit(X_train)

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test) # use same transform for testing data
X = X_train

# %%
# save transformed data
np.save('./data/X_train', X_train)
np.save('./data/y_train', y_train)
np.save('./data/X_test', X_test)
np.save('./data/y_test', y_test)

# %%
# save the model scaler to the desk
from sklearn.externals import joblib
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl', 'scaler.pkl_01.npy', 'scaler.pkl_02.npy', 'scaler.pkl_03.npy']

# %%
# Test the model if it is work
scalerTest = joblib.load('scaler.pkl')
new_data_scaled = scalerTest.transform(new_test_data)
print " =================================================================>>>>> done"
print new_data_scaled
# Out:
#  =================================================================>>>>> done
# [[ 2.29083349 -1.15043085 -1.17128043  1.28444798 -0.82148429]
#  [ 1.09730905 -1.15043085  1.81266366  1.28444798 -0.65012723]
#  [-0.12847281  0.9056672  -0.35747749 -1.24501741  2.31947901]
#  ...,
#  [-0.41878957 -1.15043085  0.18505779 -0.74040184 -0.70544919]
#  [-0.61233407 -0.2644699   0.99886072 -0.74040184 -0.3865872 ]
#  [ 2.29083349 -0.69909225  0.18505779 -0.74040184 -0.62856871]]

# %% [markdown]
# # 1. SVR Regression

# %% [markdown]
# Support Vector Machines (SVM) were developed for binary classification. The technique has been extended for the prediction real-valued problems called Support Vector Regression (SVR). Like the classification example, SVR is built upon the LIBSVM library.

# %% [markdown]
# ## Validation curve

# %% [markdown]
# choosing multiple hyperparameters of an estimator

# %%
from sklearn.svm import SVR
estimator = SVR()
estimator.get_params().keys()
# Out:
# ['kernel',
#  'C',
#  'verbose',
#  'degree',
#  'epsilon',
#  'shrinking',
#  'max_iter',
#  'tol',
#  'cache_size',
#  'coef0',
#  'gamma']

# %%
# For parametr alpha
#param_range = np.logspace(-10.0, 10.0)
#param_range = np.linspace(1,50,100)
param_range = np.arange(1,50) # generate integer numbers

train_scores, test_scores = validation_curve(
    SVR(), X, Y, param_name="C", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with SVR")
plt.xlabel("C")
plt.ylabel("Score")
plt.ylim(0.4, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# more that 5 is the best of C

# %%
# For parametr alpha
#param_range = np.logspace(-10.0, 10.0)
#param_range = np.linspace(1,50,100)
param_range = np.arange(0,10) # generate integer numbers

train_scores, test_scores = validation_curve(
    SVR(), X, Y, param_name="epsilon", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with SVR")
plt.xlabel("epsilon")
plt.ylabel("Score")
plt.ylim(0.4, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# epsilon less than  1 is the best (default=0.1)

# %% [markdown]
# ## Grid search and/or Random search to determine best compination of parameters

# %%
# Utility function to report optimal parameters
from operator import itemgetter
def report(grid_scores, n_top=5):
    params = None
    top_scores = sorted(grid_scores, key=itemgetter(1), reverse=True)[:n_top]
    for i, score in enumerate(top_scores):
        print("Parameters with rank: {0}".format(i + 1))
        print("Mean validation score: {0:.4f} (std: {1:.4f})".format(
              score.mean_validation_score, np.std(score.cv_validation_scores)))
        print("Parameters: {0}".format(score.parameters))
        print("")
        
        if params == None:
            params = score.parameters
    
    return params

# The most common value for the max number of features to look at in each split is sqrt(# of features)
sqrtfeat = np.sqrt(X.shape[1]) 
grid_test1 = { "C"      : np.linspace(1,50,100) ,
                "kernel"      : [ "linear", "rbf", "poly", "sigmoid"]}

# Large randomized test using max_depth to control tree size (5000 possible combinations)
random_test1 = { "C"      : [1,5,10],
                "kernel"      : [ "linear", "rbf", "poly", "sigmoid"]}


forest = SVR()

print "Hyperparameter optimization using GridSearchCV..."
grid_search = GridSearchCV(forest, grid_test1, n_jobs=-1, cv=num_folds)
grid_search.fit(X, Y)
best_params_from_grid_search = report(grid_search.grid_scores_)
print '+++++++++++++++++++++++++++++++++++++++++++++++'
print "Hyperparameter optimization using RandomizedSearchCV"
grid_search = RandomizedSearchCV(forest, random_test1, n_jobs=-1, cv=num_folds, n_iter=5)
grid_search.fit(X, Y)
best_params_from_rand_search1 = report(grid_search.grid_scores_)
# Out:
# Hyperparameter optimization using GridSearchCV...
# Parameters with rank: 1
# Mean validation score: 0.8124 (std: 0.0378)
# Parameters: {'kernel': 'rbf', 'C': 50.0}
#
# Parameters with rank: 2
# Mean validation score: 0.8121 (std: 0.0378)
# Parameters: {'kernel': 'rbf', 'C': 49.505050505050505}
#
# Parameters with rank: 3
# Mean validation score: 0.8119 (std: 0.0378)
# Parameters: {'kernel': 'rbf', 'C': 49.01010101010101}
#
# Parameters with rank: 4
# Mean validation score: 0.8117 (std: 0.0378)
# Parameters: {'kernel': 'rbf', 'C': 48.515151515151516}
#
# Parameters with rank: 5
# Mean validation score: 0.8115 (std: 0.0378)
# Parameters: {'kernel': 'rbf', 'C': 48.020202020202021}
#
# +++++++++++++++++++++++++++++++++++++++++++++++
# Hyperparameter optimization using RandomizedSearchCV
# Parameters with rank: 1
# Mean validation score: 0.6842 (std: 0.0538)
# Parameters: {'kernel': 'rbf', 'C': 1}
#
# Parameters with rank: 2
# Mean validation score: 0.5586 (std: 0.0706)
# Parameters: {'kernel': 'poly', 'C': 10}
#
# Parameters with rank: 3
# Mean validation score: 0.5251 (std: 0.0740)
# Parameters: {'kernel': 'poly', 'C': 1}
#
# Parameters with rank: 4
# Mean validation score: 0.4751 (std: 0.1018)
# Parameters: {'kernel': 'linear', 'C': 5}
#
# Parameters with rank: 5
# Mean validation score: 0.4749 (std: 0.1019)
# Parameters: {'kernel': 'linear', 'C': 10}

# %% [markdown]
# Parameters: {'kernel': 'rbf', 'C': 50.0}

# %%
# Value of gamma on rbf
#param_range = np.logspace(-10.0, 10.0)
param_range = np.linspace(0,10,100)
#param_range = np.arange(0,10) # generate integer numbers

train_scores, test_scores = validation_curve(
    SVR(kernel="rbf", C=50), X, Y, param_name="gamma", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with SVR")
plt.xlabel("gamma")
plt.ylabel("Score")
plt.ylim(0.4, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %%
# Utility function to report optimal parameters
from operator import itemgetter
def report(grid_scores, n_top=5):
    params = None
    top_scores = sorted(grid_scores, key=itemgetter(1), reverse=True)[:n_top]
    for i, score in enumerate(top_scores):
        print("Parameters with rank: {0}".format(i + 1))
        print("Mean validation score: {0:.4f} (std: {1:.4f})".format(
              score.mean_validation_score, np.std(score.cv_validation_scores)))
        print("Parameters: {0}".format(score.parameters))
        print("")
        
        if params == None:
            params = score.parameters
    
    return params

# The most common value for the max number of features to look at in each split is sqrt(# of features)
sqrtfeat = np.sqrt(X.shape[1]) 
grid_test1 = { "C"        : np.linspace(1,20,10),
             "gamma"      : np.linspace(0,20,10)}

# Large randomized test using max_depth to control tree size (5000 possible combinations)
random_test1 = { "C"         : [1,5,10,50],
                "gamma"      : [0,1,2]}


forest = SVR()

print "Hyperparameter optimization using GridSearchCV..."
grid_search = GridSearchCV(forest, grid_test1, n_jobs=-1, cv=num_folds)
grid_search.fit(X, Y)
best_params_from_grid_search = report(grid_search.grid_scores_)
print '+++++++++++++++++++++++++++++++++++++++++++++++'
print "Hyperparameter optimization using RandomizedSearchCV"
grid_search = RandomizedSearchCV(forest, random_test1, n_jobs=-1, cv=num_folds, n_iter=5)
grid_search.fit(X, Y)
best_params_from_rand_search1 = report(grid_search.grid_scores_)
# Out:
# Hyperparameter optimization using GridSearchCV...
# Parameters with rank: 1
# Mean validation score: 0.8641 (std: 0.0178)
# Parameters: {'C': 20.0, 'gamma': 2.2222222222222223}
#
# Parameters with rank: 2
# Mean validation score: 0.8615 (std: 0.0179)
# Parameters: {'C': 17.888888888888889, 'gamma': 2.2222222222222223}
#
# Parameters with rank: 3
# Mean validation score: 0.8592 (std: 0.0186)
# Parameters: {'C': 15.777777777777779, 'gamma': 2.2222222222222223}
#
# Parameters with rank: 4
# Mean validation score: 0.8557 (std: 0.0190)
# Parameters: {'C': 13.666666666666668, 'gamma': 2.2222222222222223}
#
# Parameters with rank: 5
# Mean validation score: 0.8518 (std: 0.0187)
# Parameters: {'C': 11.555555555555555, 'gamma': 2.2222222222222223}
#
# +++++++++++++++++++++++++++++++++++++++++++++++
# Hyperparameter optimization using RandomizedSearchCV
# Parameters with rank: 1
# Mean validation score: 0.8811 (std: 0.0160)
# Parameters: {'C': 50, 'gamma': 2}
#
# Parameters with rank: 2
# Mean validation score: 0.8732 (std: 0.0216)
# Parameters: {'C': 50, 'gamma': 1}
#
# Parameters with rank: 3
# Mean validation score: 0.8471 (std: 0.0204)
# Parameters: {'C': 10, 'gamma': 2}
#
# Parameters with rank: 4
# Mean validation score: 0.7792 (std: 0.0387)
# Parameters: {'C': 10, 'gamma': 0}
#
# Parameters with rank: 5
# Mean validation score: 0.7556 (std: 0.0439)
# Parameters: {'C': 5, 'gamma': 0}

# %% [markdown]
# ## Learning Curve

# %% [markdown]
# In essence, what we’re doing it training the exact same model with increasingly large fractions of our total training data, and plotting the error of the training and test sets at each step.

# %%
from sklearn.svm import SVR
model = SVR(kernel = "linear", C = 5.0 )
title = "Learning Curves (SVR Refression)"
cv = cross_validation.ShuffleSplit(X.shape[0], n_iter=100,
                                   test_size=0.2, random_state=0)
plot_learning_curve(model, title, X, Y, ylim=(0.2, 1.01), cv=cv, n_jobs=-1)
plt.show()

# %%
# More data from learning curve to show the process of building the model
train_sizes, train_scores, valid_scores = learning_curve(
     model, X, Y, train_sizes=[50, 80, 110], cv=cv, n_jobs=4)

print 'train_sizes = ', train_sizes

print ' training scores'
print ' 50 training sizees'
print train_scores[0].mean(),'±',train_scores[0].std()
print ' 80 training sizees'
print train_scores[1].mean(),'±',train_scores[1].std()
print ' 110 training sizees'
print train_scores[2].mean(),'±',train_scores[2].std()

print '\n validation scores'
print ' 50 validation scores'
print valid_scores[0].mean(),'±',valid_scores[0].std()
print ' 80 validation scores'
print valid_scores[1].mean(),'±',valid_scores[1].std()
print ' 110 validation scores'
print valid_scores[2].mean(),'±',valid_scores[2].std()
# Out:
# train_sizes =  [ 50  80 110]
#  training scores
#  50 training sizees
# 0.521221729961 ± 0.123727090794
#  80 training sizees
# 0.500445410973 ± 0.0916279941196
#  110 training sizees
# 0.492091826938 ± 0.0847642674721
#
#  validation scores
#  50 validation scores
# 0.415232380472 ± 0.0937608214789
#  80 validation scores
# 0.432469471972 ± 0.0807651459933
#  110 validation scores
# 0.449082831367 ± 0.0700006285171

# %% [markdown]
# ## Cross validation

# %%
scoring = 'mean_squared_error'
results = cross_validation.cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
print 'Scoring according to mean_squared_error'
print results
print '\n Mean      Standard deviation'
print("%.2f      %.2f" % (results.mean(), results.std()))
## Fit the model
model.fit(X,Y)
# Out:
# Scoring according to mean_squared_error
# [-25.95935891 -30.01905669 -27.05146519 -31.85014119 -18.64505715
#  -30.08824164 -18.53133197 -22.44431225 -22.11702868 -20.75370717]
#
#  Mean      Standard deviation
# -24.75      4.66
# SVR(C=5.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# ## Coefficients Of Determination {Calculating R^2}
#
# R^2, Close to one is better

# %%
predicted = cross_val_predict(model, X, Y, cv=kfold)
r_squared = r2_score(Y, predicted, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# R-squared =  0.480993067823

# %% [markdown]
# ## Residual Plot

# %%
predicted = cross_val_predict(model, X, Y, cv=kfold)
fig, ax = plt.subplots()
ax.scatter(Y, predicted)
ax.plot([Y.min(), Y.max()], [Y.min(), Y.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()

# %%
# Plotining using bokeh
#TOOLS = [BoxSelectTool(), HoverTool()]
#TOOLS = 'hover,box_zoom,box_select,crosshair,resize,reset,SVR_select,pan,save,poly_select,tap,wheel_zoom,undo'
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,lasso_select,pan,save,poly_select,tap,wheel_zoom,undo'
p = figure(plot_width=500, plot_height=500, tools=TOOLS)
p.scatter(Y, predicted,x="jjj", marker="o", color="#80B1D3", line_width=3)
p.title.align = "center"
p.xaxis.axis_label = "Measured"
p.xaxis.axis_label_text_color = "#aa6666"
#p.xaxis.axis_label_standoff = 30
p.xaxis.major_tick_line_color = "firebrick"
p.xaxis.major_tick_line_width = 3
p.xaxis.minor_tick_line_color = "orange"
p.yaxis.axis_label = "Predicted"
p.yaxis.axis_label_text_font_style = "italic"
p.yaxis.axis_label_text_color = "#aa6666"
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
#p.line([Y.min(), Y.max()], [Y.min(), Y.max()], line_dash="4 4", line_width=2, color='red')

# create a new plot with the toolbar below
# line_dash="4 4", line_width=2, color='red'
p.line([Y.min(), Y.max()], [Y.min(), Y.max()], line_dash="4 4", line_width=2, line_color="black")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="6c2eef16-851c-4ff5-ad9e-f1b50ceb9f84"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#6c2eef16-851c-4ff5-ad9e-f1b50ceb9f84").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6c2eef16-851c-4ff5-ad9e-f1b50ceb9f84");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6c2eef16-851c-4ff5-ad9e-f1b50ceb9f84' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"abdeec50-9787-474f-b53f-a655c255a031":{"roots":{"references":[{"attributes":{"data_source":{"id":"76bd7095-036b-438a-b2ab-c984836a4625","type":"ColumnDataSource"},"glyph":{"id":"68ed3d38-7358-4a18-8d03-90f1eba160f7","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"2e738284-d8a5-4408-87f7-97c4a6cfe9f6","type":"Circle"},"selection_glyph":null},"id":"f6817c9d-9d49-4e10-ad9e-90dc625cb1f7","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"aec3a980-f476-468c-afc3-530560bb1f78","subtype":"Figure","type":"Plot"},"ticker":{"id":"feab99b9-b0bf-474d-85ae-184f24976686","type":"BasicTicker"}},"id":"fbe15b53-94d6-4995-8d17-cabab6142f01","type":"Grid"},{"attributes":{"data_source":{"id":"f6c44a92-f0f5-4c44-b30c-2316c8e34151","type":"ColumnDataSource"},"glyph":{"id":"8803d610-5492-4ca3-bcab-f52a7318c293","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"3edabe0b-260e-4e4f-8fd1-6f97c01bfc51","type":"Line"},"selection_glyph":null},"id":"fc10cf4e-1ede-4f0f-b69b-ad5f52610079","type":"GlyphRenderer"},{"attributes":{"callback":null,"overlay":{"id":"ec0f54a5-d21b-4dd8-a7f0-7d3f0d2c2c15","type":"BoxAnnotation"},"plot":{"id":"aec3a980-f476-468c-afc3-530560bb1f78","subtype":"Figure","type":"Plot"},"renderers":[{"id":"f6817c9d-9d49-4e10-ad9e-90dc625cb1f7","type":"GlyphRenderer"},{"id":"fc10cf4e-1ede-4f0f-b69b-ad5f52610079","type":"GlyphRenderer"}]},"id":"d7d6a553-b5c7-42c5-a641-ce5167401db0","type":"BoxSelectTool"},{"attributes":{"axis_label":"Predicted","axis_label_text_color":{"value":"#aa6666"},"formatter":{"id":"8402f731-6419-4dc1-b107-4d2498f1eecc","type":"BasicTickFormatter"},"plot":{"id":"aec3a980-f476-468c-afc3-530560bb1f78","subtype":"Figure","type":"Plot"},"ticker":{"id":"feab99b9-b0bf-474d-85ae-184f24976686","type":"BasicTicker"}},"id":"898e3a2f-28c8-43cf-bd8d-3cd1513e0753","type":"LinearAxis"},{"attributes":{},"id":"eed38523-3f52-4cae-9be6-10f225ddfb06","type":"ToolEvents"},{"attributes":{"line_dash":[4,4],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"8803d610-5492-4ca3-bcab-f52a7318c293","type":"Line"},{"attributes":{"plot":{"id":"aec3a980-f476-468c-afc3-530560bb1f78","subtype":"Figure","type":"Plot"}},"id":"8afd9ec8-1141-4e4f-b273-906e1e6b245e","type":"ResizeTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b1998ee9-ce94-413d-8da5-47d4a1d73a62","type":"BoxZoomTool"},{"id":"d7d6a553-b5c7-42c5-a641-ce5167401db0","type":"BoxSelectTool"},{"id":"2065da12-d859-47b9-9d97-077b00ed1b71","type":"CrosshairTool"},{"id":"8afd9ec8-1141-4e4f-b273-906e1e6b245e","type":"ResizeTool"},{"id":"4b95e8b6-e294-44b1-b8a9-c45d08c5755e","type":"ResetTool"},{"id":"ee21e863-92df-43c3-8c2c-429ddf74b040","type":"LassoSelectTool"},{"id":"873b90fe-bc33-4636-867b-481eae2aa4ec","type":"PanTool"},{"id":"5c558f3a-30da-4c0c-b190-79a39b01da55","type":"SaveTool"},{"id":"d6fd9499-279a-4346-9ea0-c28b4f86562f","type":"PolySelectTool"},{"id":"a1d41ac8-4a90-4ad3-bf50-50309d2470c5","type":"TapTool"},{"id":"692c105c-8eae-4384-8620-7cc2828f5463","type":"WheelZoomTool"},{"id":"642e1215-fc46-48ba-8193-0dad3c70cd7b","type":"UndoTool"}]},"id":"f6fb04c3-ea4b-4021-b597-372bc4479b5e","type":"Toolbar"},{"attributes":{"plot":{"id":"aec3a980-f476-468c-afc3-530560bb1f78","subtype":"Figure","type":"Plot"}},"id":"4b95e8b6-e294-44b1-b8a9-c45d08c5755e","type":"ResetTool"},{"attributes":{"overlay":{"id":"8b7a4da5-23a1-4c74-8fcd-c7229d975a07","type":"PolyAnnotation"},"plot":{"id":"aec3a980-f476-468c-afc3-530560bb1f78","subtype":"Figure","type":"Plot"}},"id":"d6fd9499-279a-4346-9ea0-c28b4f86562f","type":"PolySelectTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b4e6b29d-88a6-4d66- ...

# %%
plt.scatter(predicted, (predicted - Y), c='r', s=30)
plt.title("Residual plot on the training data")
plt.xlabel("Predicted")
plt.ylabel("Residuals")

# %%
# Plotining using bokeh
#TOOLS = 'hover,box_zoom,box_select,crosshair,resize,reset,SVR_select,pan,save,poly_select,tap,wheel_zoom,undo'
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,lasso_select,pan,save,poly_select,tap,wheel_zoom,undo'
p = figure(plot_width=500, plot_height=500, title="Residual plot on the training data", tools=TOOLS)
p.scatter(predicted, (predicted - Y),x="jjj", marker="o", color="#80B1D3", line_width=3)
p.title.align = "center"
p.xaxis.axis_label = "Predicted"
p.xaxis.axis_label_text_color = "#aa6666"
#p.xaxis.axis_label_standoff = 30
p.xaxis.major_tick_line_color = "firebrick"
p.xaxis.major_tick_line_width = 3
p.xaxis.minor_tick_line_color = "orange"
p.yaxis.axis_label = "Residuals"
p.yaxis.axis_label_text_font_style = "italic"
p.yaxis.axis_label_text_color = "#aa6666"
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
#p.line([2,38], [0, 0], line_dash="4 4", line_width=2, color='red')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="f34a102c-e05f-48fb-b8f6-7c48b1c25a44"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#f34a102c-e05f-48fb-b8f6-7c48b1c25a44").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f34a102c-e05f-48fb-b8f6-7c48b1c25a44");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f34a102c-e05f-48fb-b8f6-7c48b1c25a44' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"2c0923c9-5ebe-4c8c-89c5-edd5dd6ea99f":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9b1975a3-9c21-4044-ac53-2be2d0353d52","type":"BoxZoomTool"},{"id":"3422a094-e8ab-4778-817a-a010dff3b7ad","type":"BoxSelectTool"},{"id":"d659f346-19a5-4da8-a6f0-2b3689a8e1fe","type":"CrosshairTool"},{"id":"4a230943-2e1b-455c-91f2-407ae4f67e17","type":"ResizeTool"},{"id":"59501fe2-3648-4e1f-9a1e-8c2fadb807fa","type":"ResetTool"},{"id":"c9bafc39-babb-4f06-9100-6962de88747c","type":"LassoSelectTool"},{"id":"900e0a3d-ef87-4a17-b097-f8a4e61ed45d","type":"PanTool"},{"id":"d4176b2b-8e41-4b9a-9ffc-9e2a49bb10bf","type":"SaveTool"},{"id":"c762a3b1-06d0-4ffc-9ef0-aa334525d584","type":"PolySelectTool"},{"id":"4d881766-f748-4321-bace-8a5555107d8a","type":"TapTool"},{"id":"61e964b9-cb07-46de-950b-923672f2a873","type":"WheelZoomTool"},{"id":"34404c9e-4297-492a-8bb6-432a609e9fe3","type":"UndoTool"}]},"id":"32b98b11-a81b-4c00-8b0e-f8da408cdd26","type":"Toolbar"},{"attributes":{},"id":"2bf4d145-0284-4a01-8bfc-b4a5bf542371","type":"BasicTicker"},{"attributes":{"axis_label":"Residuals","axis_label_text_color":{"value":"#aa6666"},"formatter":{"id":"89ec0099-11e4-467a-aa3a-2769fea44a76","type":"BasicTickFormatter"},"plot":{"id":"56777dee-cdaa-49a8-9b43-2661303bfc32","subtype":"Figure","type":"Plot"},"ticker":{"id":"2bf4d145-0284-4a01-8bfc-b4a5bf542371","type":"BasicTicker"}},"id":"0d0707b2-e189-45c8-a80f-d4be7d3264f0","type":"LinearAxis"},{"attributes":{"data_source":{"id":"5f53003c-9f63-4cd0-b932-7e4de76048c9","type":"ColumnDataSource"},"glyph":{"id":"633e4452-f42f-425f-9d30-da4d805a5093","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"352fd7a2-0011-47cb-9ace-1c66c800b22c","type":"Circle"},"selection_glyph":null},"id":"e2024034-5d7d-408f-8af5-64d241246775","type":"GlyphRenderer"},{"attributes":{"background_fill_alpha":{"value":0.5},"background_fill_color":{"value":"beige"},"below":[{"id":"89f34c3c-fa0c-47e5-88ac-c715ffa11d90","type":"LinearAxis"}],"left":[{"id":"0d0707b2-e189-45c8-a80f-d4be7d3264f0","type":"LinearAxis"}],"plot_height":500,"plot_width":500,"renderers":[{"id":"89f34c3c-fa0c-47e5-88ac-c715ffa11d90","type":"LinearAxis"},{"id":"c0f23008-88f7-49d6-9e67-fe6f709f17df","type":"Grid"},{"id":"0d0707b2-e189-45c8-a80f-d4be7d3264f0","type":"LinearAxis"},{"id":"85499d04-52aa-47e1-837a-351e0812edbe","type":"Grid"},{"id":"375bfdcc-bcae-434b-8eb6-9246ed66898c","type":"BoxAnnotation"},{"id":"8684da2d-c299-41e2-ab9a-86c39ebfec24","type":"BoxAnnotation"},{"id":"fb9ec585-21dc-456e-a93b-a44364e15119","type":"PolyAnnotation"},{"id":"484d27c4-7a97-4c2f-8935-41a7f9fc5fc4","type":"PolyAnnotation"},{"id":"e2024034-5d7d-408f-8af5-64d241246775","type":"GlyphRenderer"}],"title":{"id":"16658fe0-f12c-42af-b6bf-350b5964428b","type":"Title"},"tool_events":{"id":"8825aa93-acf4-4436-b00c-c365a0333e02","type":"ToolEvents"},"toolbar":{"id":"32b98b11-a81b-4c00-8b0e-f8da408cdd26","type":"Toolbar"},"x_range":{"id":"e9c67fde-e15e-4e0a-a7cb-a822d1d31bf8","type":"DataRange1d"},"y_range":{"id":"e8ab1bff-34f8-44e8-890c-d9c1eac7ead9","type":"DataRange1d"}},"id":"56777dee-cdaa-49a8-9b43-2661303bfc32","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"e9c67fde-e15e-4e0a-a7cb-a822d1d31bf8","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8684da2d-c299-41e2-ab9a-86c39ebfec24","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"56777dee-cdaa-49a8-9b43-2661303bfc32","subtype":"Figure","type":"Plot"}},"id":"4a230943-2e1b-455c-91f2-407ae4f67e17","type":"ResizeTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{ ...

# %% [markdown]
# ## Pipeline

# %% [markdown]
# The best to deliver the model by pipeline the operation then at deployment can be done in one model.

# %% [markdown]
#   I used two ways to check the pipeline so any one can be fine

# %%
# Use Pipeline
# ANOVA 
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, f_regression
anova_filter = SelectKBest(f_regression, k=5)
LR = SVR(kernel = "linear", C = 5.0 )
anova_LinReg = Pipeline([('scaler_Input',scaler), ('anova', anova_filter), ('LinReg', LR)])
# You can set the parameters using the names issued
# For instance, fit using a k of 10 in the SelectKBest
anova_LinReg.set_params(anova__k=5).fit(new_data, Y)
prediction = anova_LinReg.predict(new_data)
print anova_LinReg.score(new_data, Y)                        
# getting the selected features chosen by anova_filter
results = cross_validation.cross_val_score(anova_LinReg, new_data, Y, cv=kfold, scoring=scoring)
print 'Scoring according to mean_squared_error'
print results
print '\n Mean      Standard deviation'
print("%.2f      %.2f" % (results.mean(), results.std()))
print anova_LinReg.named_steps['anova'].get_support()
r_squared = r2_score(Y, prediction, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# 0.487101123291
# Scoring according to mean_squared_error
# [-25.95603843 -30.01798944 -27.05272588 -31.84900867 -18.64499531
#  -30.0873593  -18.5313461  -22.44390273 -22.11749751 -20.75361377]
#
#  Mean      Standard deviation
# -24.75      4.66
# [ True  True  True  True  True]
# R-squared =  0.487101123291

# %%
# Using make_pipeline
from sklearn.pipeline import make_pipeline

# ANOVA SVM-C
# 1) anova filter, take 3 best ranked features
anova_filter = SelectKBest(f_regression, k=5)
anova_SVR = make_pipeline(scaler, anova_filter, LR)
anova_SVR.fit(new_data, Y)
prediction = anova_SVR.predict(new_data)
r_squared = r2_score(Y, prediction, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# R-squared =  0.487101123291

# %% [markdown]
# ### Save the Pipeline model for developement

# %%
# save the model scaler to the desk
from sklearn.externals import joblib
joblib.dump(anova_SVR, 'anova_SVR.pkl')
# Out:
# ['anova_SVR.pkl',
#  'anova_SVR.pkl_01.npy',
#  'anova_SVR.pkl_02.npy',
#  'anova_SVR.pkl_03.npy',
#  'anova_SVR.pkl_04.npy',
#  'anova_SVR.pkl_05.npy',
#  'anova_SVR.pkl_06.npy',
#  'anova_SVR.pkl_07.npy',
#  'anova_SVR.pkl_08.npy',
#  'anova_SVR.pkl_09.npy',
#  'anova_SVR.pkl_10.npy',
#  'anova_SVR.pkl_11.npy',
#  'anova_SVR.pkl_12.npy',
#  'anova_SVR.pkl_13.npy',
#  'anova_SVR.pkl_14.npy',
#  'anova_SVR.pkl_15.npy']

# %%
# Test the model if it is work
anova_SVRTest = joblib.load('anova_SVR.pkl')
NewPred = anova_SVRTest.predict(new_data)
print " =================================================================>>>>> done"
r_squared = r2_score(Y, NewPred, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
#  =================================================================>>>>> done
# R-squared =  0.487101123291

# %%
# test on single data point, randomly choose point number 55
print 'Point of training data before normalization\n',new_data[55]
print '\nThe read target of the data = ', Y[55]
NewPred = anova_SVRTest.predict([new_data[55]])
print '\nThe Predicted target of the data = ', NewPred
# Out:
# Point of training data before normalization
# [  1.00000000e+03   2.70000000e+00   1.52400000e-01   7.13000000e+01
#    2.43851000e-03]
#
# The read target of the data =  128.774
#
# The Predicted target of the data =  [ 132.2504171]

# %% [markdown]
# ## Conclusion
