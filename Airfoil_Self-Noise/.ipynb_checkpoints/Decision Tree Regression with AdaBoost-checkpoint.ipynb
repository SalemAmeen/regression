# %% [markdown]
# Salem Ameen, PhD student at Salford University
#
# ### Airfoil Self-Noise price
#
# Decision trees Regression

# %% [markdown]
# # Import the Libraries

# %%
import numpy as np
import pandas
from numpy import *
import time
import sys
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import feature_selection
from sklearn.tree import DecisionTreeRegressor
from sklearn.learning_curve import learning_curve, validation_curve
from sklearn.cross_validation import cross_val_predict
from sklearn import metrics, grid_search, cross_validation
from IPython.display import set_matplotlib_formats
from bokeh.plotting import figure, show, output_notebook
from sklearn.grid_search import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import r2_score
from bokeh.layouts import gridplot
output_notebook()
set_matplotlib_formats('png', 'pdf')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (6, 6)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="88c392db-2d65-41ad-b643-c597ab108fff">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Load data

# %% [markdown]
# In the previous file we have not change the data as there is no missing value or add any new parameters so it can be downloaded from the web directly.

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00291/airfoil_self_noise.dat'
names = ['Frequency', 'Angle', 'Chord', 'Free_stream', 'Suction', 'pressure']
feature_names = names
feature_cols = names
data = pd.read_csv(url, sep='\s+', names = names)

from sklearn import preprocessing
dataset = data.values
X = dataset[:,0:5].astype(float)
Y = dataset[:,5]
print 'Number of examples',len(X)
# Out:
# Number of examples 1503

# %%
# Make developement dataset for genrilization and final testing
from sklearn.cross_validation import train_test_split
# Extracting 20% testing data
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.20, random_state=0)
X = X_train
Y = y_train
new_data      = X_train
new_test_data = X_test
print 'Number of training examples',len(X_train)
print 'Number of validation examples',len(X_test)
# Out:
# Number of training examples 1202
# Number of validation examples 301

# %% [markdown]
# Number of training data is very small so we need to use cross validation instead of spareate another validation data.

# %% [markdown]
# From the previous visulization the data has no missing value but has many outlier and some sparisty

# %% [markdown]
# # Ranking of the feature's importance to the target

# %%
# Using just correlation coefficient even in prevoius file we show them using data frame
for col in feature_cols:
    lm = DecisionTreeRegressor()
    lm.fit(data[[col]], data['pressure'])
    print col,'\t', lm.score(data[[col]], data['pressure'])
# Out:
# Frequency 	0.208538014689
# Angle 	0.170777839353
# Chord 	0.0690445352687
# Free_stream 	0.0200966819657
# Suction 	0.293078622679
# pressure 	1.0

# %%
# Randing the important features to the target
model = feature_selection.SelectKBest(score_func=feature_selection.f_regression,k=4)
results = model.fit(data[feature_cols], data['pressure'])
k=0
print 'Feature Name      Score         Pvalue'
for feat in feature_cols:
    print feat,'\t\t',results.scores_[k],'\t',results.pvalues_[k]
    k=k+1
# Out:
# Feature Name      Score         Pvalue
# Frequency 		270.416272463 	5.36177705642e-56
# Angle 		37.4923835551 	1.16954827306e-09
# Chord 		88.6588675485 	1.70142015337e-20
# Free_stream 		23.8652245755 	1.1437427443e-06
# Suction 		162.641263457 	1.92478295603e-35
# pressure 		inf 	0.0

# %% [markdown]
# # Set the parameters for cross validation

# %%
num_folds = 10
num_instances = len(X)
seed = 7
kfold = cross_validation.KFold(n=num_instances, n_folds=num_folds, random_state=seed)

# %% [markdown]
#  # Set the parameters for bias-variance dilemma

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %% [markdown]
# # Preprocessing the data and save both the model and preprocessed data

# %%
# According to the nature of the data spasity and there is outliter RobustScaler class is recomandit 
# but when I tried both of them the result seems is same
from sklearn.preprocessing import StandardScaler
scaler = preprocessing.StandardScaler().fit(X_train)

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test) # use same transform for testing data
X = X_train

# %%
# save transformed data
np.save('./data/X_train', X_train)
np.save('./data/y_train', y_train)
np.save('./data/X_test', X_test)
np.save('./data/y_test', y_test)

# %%
# save the model scaler to the desk
from sklearn.externals import joblib
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl', 'scaler.pkl_01.npy', 'scaler.pkl_02.npy', 'scaler.pkl_03.npy']

# %%
# Test the model if it is work
scalerTest = joblib.load('scaler.pkl')
new_data_scaled = scalerTest.transform(new_test_data)
print " =================================================================>>>>> done"
print new_data_scaled
# Out:
#  =================================================================>>>>> done
# [[ 2.29083349 -1.15043085 -1.17128043  1.28444798 -0.82148429]
#  [ 1.09730905 -1.15043085  1.81266366  1.28444798 -0.65012723]
#  [-0.12847281  0.9056672  -0.35747749 -1.24501741  2.31947901]
#  ...,
#  [-0.41878957 -1.15043085  0.18505779 -0.74040184 -0.70544919]
#  [-0.61233407 -0.2644699   0.99886072 -0.74040184 -0.3865872 ]
#  [ 2.29083349 -0.69909225  0.18505779 -0.74040184 -0.62856871]]

# %% [markdown]
# # 1. DecisionTreeRegressor  with AdaBoost Regression

# %% [markdown]
# Decision trees or the Classification and Regression Trees (CART as they are know) use the training data to select the best points to split the data in order to minimize a cost metric. The default cost metric for regression decision trees is the mean squared error, specified in the criterion parameter.

# %% [markdown]
# ## Validation curve

# %% [markdown]
# choosing multiple hyperparameters of an estimator

# %%
from sklearn.tree import DecisionTreeRegressor
estimator = DecisionTreeRegressor()
estimator.get_params().keys()
# Out:
# ['presort',
#  'splitter',
#  'max_leaf_nodes',
#  'min_samples_leaf',
#  'min_samples_split',
#  'min_weight_fraction_leaf',
#  'criterion',
#  'random_state',
#  'max_features',
#  'max_depth']

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
estimator = AdaBoostRegressor(DecisionTreeRegressor())
estimator.get_params().keys()
# Out:
# ['loss',
#  'base_estimator__min_samples_split',
#  'base_estimator__max_depth',
#  'learning_rate',
#  'base_estimator',
#  'base_estimator__criterion',
#  'base_estimator__max_features',
#  'base_estimator__random_state',
#  'n_estimators',
#  'base_estimator__min_weight_fraction_leaf',
#  'random_state',
#  'base_estimator__splitter',
#  'base_estimator__max_leaf_nodes',
#  'base_estimator__min_samples_leaf',
#  'base_estimator__presort']

# %%
# For parametr alpha
#param_range = np.logspace(-10.0, 10.0)
#param_range = np.linspace(1,50,100)
param_range = np.arange(1,50) # generate integer numbers

train_scores, test_scores = validation_curve(
    DecisionTreeRegressor(), X, Y, param_name="max_depth", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with DecisionTreeRegressor")
plt.xlabel("max_depth")
plt.ylabel("Score")
plt.ylim(0.4, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# more that 5 is the best of number of K

# %%
# For parametr alpha
#param_range = np.logspace(-10.0, 10.0)
#param_range = np.linspace(1,50,100)
param_range = np.arange(1,10) # generate integer numbers

train_scores, test_scores = validation_curve(
    DecisionTreeRegressor(), X, Y, param_name="min_samples_split", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with DecisionTreeRegressor")
plt.xlabel("min_samples_split")
plt.ylabel("Score")
plt.ylim(0.4, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# min_samples_split =2 (The defualt) is the best

# %%
# For parametr alpha
#param_range = np.logspace(-10.0, 10.0)
#param_range = np.linspace(1,50,100)
param_range = np.arange(1,10) # generate integer numbers

train_scores, test_scores = validation_curve(
    DecisionTreeRegressor(), X, Y, param_name="min_samples_leaf", param_range=param_range,
    cv=num_folds,  n_jobs=-1)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title("Validation Curve with DecisionTreeRegressor")
plt.xlabel("min_samples_leaf")
plt.ylabel("Score")
plt.ylim(0.4, 1.0)
plt.plot(param_range, train_scores_mean, label="Training score", color="r")
plt.fill_between(param_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color="r")
plt.plot(param_range, test_scores_mean, label="Cross-validation score",
             color="g")
plt.fill_between(param_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2, color="g")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# min_samples_leaf = 2 is the best

# %% [markdown]
# ## Grid search and/or Random search to determine best compination of parameters

# %%
# Utility function to report optimal parameters
from operator import itemgetter
def report(grid_scores, n_top=5):
    params = None
    top_scores = sorted(grid_scores, key=itemgetter(1), reverse=True)[:n_top]
    for i, score in enumerate(top_scores):
        print("Parameters with rank: {0}".format(i + 1))
        print("Mean validation score: {0:.4f} (std: {1:.4f})".format(
              score.mean_validation_score, np.std(score.cv_validation_scores)))
        print("Parameters: {0}".format(score.parameters))
        print("")
        
        if params == None:
            params = score.parameters
    
    return params

# The most common value for the max number of features to look at in each split is sqrt(# of features)
sqrtfeat = np.sqrt(X.shape[1]) 
grid_test1 = { "n_estimators"      : np.arange(1,10),
             "loss"      : [ "linear", "square", "exponential"]}

# Large randomized test using max_depth to control tree size (5000 possible combinations)
random_test1 = { "n_estimators"      : [1,10,20,100,200, 300, 400, 500],
                "loss"      : [ "linear", "square", "exponential"]}


forest = AdaBoostRegressor()

print "Hyperparameter optimization using GridSearchCV..."
grid_search = GridSearchCV(forest, grid_test1, n_jobs=-1, cv=num_folds)
grid_search.fit(X, Y)
best_params_from_grid_search = report(grid_search.grid_scores_)
print '+++++++++++++++++++++++++++++++++++++++++++++++'
print "Hyperparameter optimization using RandomizedSearchCV"
grid_search = RandomizedSearchCV(forest, random_test1, n_jobs=-1, cv=num_folds, n_iter=5)
grid_search.fit(X, Y)
best_params_from_rand_search1 = report(grid_search.grid_scores_)
# Out:
# Hyperparameter optimization using GridSearchCV...
# Parameters with rank: 1
# Mean validation score: 0.6178 (std: 0.0418)
# Parameters: {'n_estimators': 8, 'loss': 'square'}
#
# Parameters with rank: 2
# Mean validation score: 0.6166 (std: 0.0494)
# Parameters: {'n_estimators': 9, 'loss': 'square'}
#
# Parameters with rank: 3
# Mean validation score: 0.5896 (std: 0.0500)
# Parameters: {'n_estimators': 9, 'loss': 'linear'}
#
# Parameters with rank: 4
# Mean validation score: 0.5890 (std: 0.0492)
# Parameters: {'n_estimators': 9, 'loss': 'exponential'}
#
# Parameters with rank: 5
# Mean validation score: 0.5887 (std: 0.0537)
# Parameters: {'n_estimators': 7, 'loss': 'square'}
#
# +++++++++++++++++++++++++++++++++++++++++++++++
# Hyperparameter optimization using RandomizedSearchCV
# Parameters with rank: 1
# Mean validation score: 0.7292 (std: 0.0420)
# Parameters: {'n_estimators': 400, 'loss': 'square'}
#
# Parameters with rank: 2
# Mean validation score: 0.6987 (std: 0.0391)
# Parameters: {'n_estimators': 100, 'loss': 'linear'}
#
# Parameters with rank: 3
# Mean validation score: 0.6931 (std: 0.0425)
# Parameters: {'n_estimators': 100, 'loss': 'exponential'}
#
# Parameters with rank: 4
# Mean validation score: 0.6708 (std: 0.0502)
# Parameters: {'n_estimators': 20, 'loss': 'square'}
#
# Parameters with rank: 5
# Mean validation score: 0.4390 (std: 0.0660)
# Parameters: {'n_estimators': 1, 'loss': 'exponential'}

# %% [markdown]
# Best parameters Parameters: Parameters: {'max_features': None, 'max_depth': 19, 'min_samples_leaf': 1}

# %% [markdown]
# ## Learning Curve

# %% [markdown]
# In essence, what we’re doing it training the exact same model with increasingly large fractions of our total training data, and plotting the error of the training and test sets at each step.

# %%
from sklearn.tree import DecisionTreeRegressor
model = AdaBoostRegressor(n_estimators = 5, loss = "exponential")
title = "Learning Curves (Ada DecisionTreeRegressor Refression)"
cv = cross_validation.ShuffleSplit(X.shape[0], n_iter=100,
                                   test_size=0.2, random_state=0)
plot_learning_curve(model, title, X, Y, ylim=(0.2, 1.01), cv=cv, n_jobs=-1)
plt.show()

# %%
# More data from learning curve to show the process of building the model
train_sizes, train_scores, valid_scores = learning_curve(
     model, X, Y, train_sizes=[50, 80, 110], cv=cv, n_jobs=4)

print 'train_sizes = ', train_sizes

print ' training scores'
print ' 50 training sizees'
print train_scores[0].mean(),'±',train_scores[0].std()
print ' 80 training sizees'
print train_scores[1].mean(),'±',train_scores[1].std()
print ' 110 training sizees'
print train_scores[2].mean(),'±',train_scores[2].std()

print '\n validation scores'
print ' 50 validation scores'
print valid_scores[0].mean(),'±',valid_scores[0].std()
print ' 80 validation scores'
print valid_scores[1].mean(),'±',valid_scores[1].std()
print ' 110 validation scores'
print valid_scores[2].mean(),'±',valid_scores[2].std()
# Out:
# train_sizes =  [ 50  80 110]
#  training scores
#  50 training sizees
# 0.758424789264 ± 0.0917219692504
#  80 training sizees
# 0.701233092003 ± 0.0742483579977
#  110 training sizees
# 0.678931781454 ± 0.0593349721892
#
#  validation scores
#  50 validation scores
# 0.320336015658 ± 0.134817186778
#  80 validation scores
# 0.403134006856 ± 0.100624088325
#  110 validation scores
# 0.436909363518 ± 0.0723366380333

# %% [markdown]
# ## Cross validation

# %%
scoring = 'mean_squared_error'
results = cross_validation.cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
print 'Scoring according to mean_squared_error'
print results
print '\n Mean      Standard deviation'
print("%.2f      %.2f" % (results.mean(), results.std()))
## Fit the model
model.fit(X,Y)
# Out:
# Scoring according to mean_squared_error
# [-20.19614688 -24.41037955 -23.23158651 -19.81822137 -17.80197295
#  -21.9514244  -19.72516737 -22.4969914  -18.54970676 -22.24169818]
#
#  Mean      Standard deviation
# -21.04      2.03
# AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss
plot":{"id":"54dc3660-f066-47c0-9575-345cf70b1bc0","subtype":"Figure","type":"Plot"}},"id":"abb54675-1cc5-4d4e-a597-7de9dea792ba","type":"ResizeTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[104.13,140.987],"y":[104.13,140.987]}},"id":"eef622a9-c2e6-4357-8c92-5fdf4cbc668e","type":"ColumnDataSource"},{"attributes":{"callback":null,"overlay":{"id":"d8129cd7-2d95-4e39-935b-45e00deb0f95","type":"PolyAnnotation"},"plot":{"id":"54dc3660-f066-47c0-9575-345cf70b1bc0","subtype":"Figure ...

# %%
plt.scatter(predicted, (predicted - Y), c='r', s=30)
plt.title("Residual plot on the training data")
plt.xlabel("Predicted")
plt.ylabel("Residuals")

# %%
# Plotining using bokeh
#TOOLS = 'hover,box_zoom,box_select,crosshair,resize,reset,DecisionTreeRegressor_select,pan,save,poly_select,tap,wheel_zoom,undo'
TOOLS = 'box_zoom,box_select,crosshair,resize,reset,lasso_select,pan,save,poly_select,tap,wheel_zoom,undo'
p = figure(plot_width=500, plot_height=500, title="Residual plot on the training data", tools=TOOLS)
p.scatter(predicted, (predicted - Y),x="jjj", marker="o", color="#80B1D3", line_width=3)
p.title.align = "center"
p.xaxis.axis_label = "Predicted"
p.xaxis.axis_label_text_color = "#aa6666"
#p.xaxis.axis_label_standoff = 30
p.xaxis.major_tick_line_color = "firebrick"
p.xaxis.major_tick_line_width = 3
p.xaxis.minor_tick_line_color = "orange"
p.yaxis.axis_label = "Residuals"
p.yaxis.axis_label_text_font_style = "italic"
p.yaxis.axis_label_text_color = "#aa6666"
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
#p.line([2,38], [0, 0], line_dash="4 4", line_width=2, color='red')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="9d40e1bc-b14c-4a92-b803-3a9c22687dfa"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#9d40e1bc-b14c-4a92-b803-3a9c22687dfa").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9d40e1bc-b14c-4a92-b803-3a9c22687dfa");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9d40e1bc-b14c-4a92-b803-3a9c22687dfa' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"41352c31-a386-4e46-b2ab-1f8ecdd7fb15":{"roots":{"references":[{"attributes":{"plot":{"id":"5e120fe8-410a-4fab-8f2c-97606352f152","subtype":"Figure","type":"Plot"},"ticker":{"id":"04201d13-a866-4e0f-ac4c-948fc7dd9fa9","type":"BasicTicker"}},"id":"80954ee0-0f26-4051-bd66-9116c0eee01a","type":"Grid"},{"attributes":{"callback":null,"overlay":{"id":"b1688674-cf80-4c38-b7e4-99571285064a","type":"PolyAnnotation"},"plot":{"id":"5e120fe8-410a-4fab-8f2c-97606352f152","subtype":"Figure","type":"Plot"}},"id":"85255e08-f356-4fb8-943b-210727412b2c","type":"LassoSelectTool"},{"attributes":{"background_fill_alpha":{"value":0.5},"background_fill_color":{"value":"beige"},"below":[{"id":"e41d19c7-6764-4641-98c2-05a4d829ec18","type":"LinearAxis"}],"left":[{"id":"d0aeb679-57db-4ed6-bb78-9b485a2e1d0b","type":"LinearAxis"}],"plot_height":500,"plot_width":500,"renderers":[{"id":"e41d19c7-6764-4641-98c2-05a4d829ec18","type":"LinearAxis"},{"id":"80954ee0-0f26-4051-bd66-9116c0eee01a","type":"Grid"},{"id":"d0aeb679-57db-4ed6-bb78-9b485a2e1d0b","type":"LinearAxis"},{"id":"3ad54f26-0be4-4c15-94a2-c0f71fc12e1a","type":"Grid"},{"id":"a5c2e879-e4ad-4681-83dd-ed1a41ed317a","type":"BoxAnnotation"},{"id":"636f72f5-7218-411a-95b7-f7cf469a9c7a","type":"BoxAnnotation"},{"id":"b1688674-cf80-4c38-b7e4-99571285064a","type":"PolyAnnotation"},{"id":"3b0dc2a2-632b-4394-a55d-c026ed4e163c","type":"PolyAnnotation"},{"id":"f21896eb-913d-4057-ace0-4dc66da50fb3","type":"GlyphRenderer"}],"title":{"id":"58bb3045-0ae6-4736-ada8-4b66e8927ffa","type":"Title"},"tool_events":{"id":"1eeb7efc-3dbe-4d4d-ad7f-bd1afc4ed4de","type":"ToolEvents"},"toolbar":{"id":"263226b9-f417-4a31-9b85-34cd40b5da36","type":"Toolbar"},"x_range":{"id":"f9846cd3-596f-4bb6-be0c-ee721cd0359a","type":"DataRange1d"},"y_range":{"id":"3ad4cec4-5ae7-4dd8-8293-227878f0d3bc","type":"DataRange1d"}},"id":"5e120fe8-410a-4fab-8f2c-97606352f152","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"5e120fe8-410a-4fab-8f2c-97606352f152","subtype":"Figure","type":"Plot"}},"id":"d55ff824-d37e-4d7c-8ee8-dcf32c3b4af6","type":"WheelZoomTool"},{"attributes":{"axis_label":"Residuals","axis_label_text_color":{"value":"#aa6666"},"formatter":{"id":"79bc4ad6-ba14-4ea4-a156-172c034b3e7e","type":"BasicTickFormatter"},"plot":{"id":"5e120fe8-410a-4fab-8f2c-97606352f152","subtype":"Figure","type":"Plot"},"ticker":{"id":"1f2a2233-bc31-4192-bc91-84c6aeea6746","type":"BasicTicker"}},"id":"d0aeb679-57db-4ed6-bb78-9b485a2e1d0b","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1835fe37-6aae-4118-8487-abf6414b06fd","type":"BoxZoomTool"},{"id":"fd8322f4-6c36-4e37-8389-569827f87465","type":"BoxSelectTool"},{"id":"f5892f83-64d1-4ba6-897c-96837566e717","type":"CrosshairTool"},{"id":"dddf7b0e-a886-411c-994a-671ebc614c66","type":"ResizeTool"},{"id":"9e3aec5f-3884-4cdd-b663-46807be9ac37","type":"ResetTool"},{"id":"85255e08-f356-4fb8-943b-210727412b2c","type":"LassoSelectTool"},{"id":"547dbf1d-8209-4b3b-aeb3-e228c8899093","type":"PanTool"},{"id":"7cf5b62a-aaad-4081-b40e-6912d2d56caf","type":"SaveTool"},{"id":"7f4446a7-ad29-4bc3-b29c-af1dd503aea2","type":"PolySelectTool"},{"id":"ae548151-3cb2-486b-8e2f-9a0ae4d80567","type":"TapTool"},{"id":"d55ff824-d37e-4d7c-8ee8-dcf32c3b4af6","type":"WheelZoomTool"},{"id":"58f1ad75-3003-4f12-9416-1a209a7ea312","type":"UndoTool"}]},"id":"263226b9-f417-4a31-9b85-34cd40b5da36","type":"Toolbar"},{"attributes":{"callback":null,"plot":{"id":"5e120fe8-410a-4fab-8f2c-97606352f152","subtype":"Figure","type":"Plot"}},"id":"ae548151-3cb2-486b-8e2f-9a0ae4d80567","type":"TapTool"},{"attributes":{"plot":{"id":"5e120fe8-410a-4fab-8f2c-97606352f152","subtype":"Figure","type":"Plot"}},"id":"f5892f83-64d1-4ba6-897c-96837566e717","type":"CrosshairTool"},{"attributes":{"data_source":{"id":"3321b3f4-7610-44be-973d-9393bbccf4c3","type":"ColumnDataSource"},"glyph":{"id":"663f4cd3-6263-411c-81ae-045ebaa8f964","type":"Circle"},"hover_glyph" ...

# %% [markdown]
# ## Pipeline

# %% [markdown]
# The best to deliver the model by pipeline the operation then at deployment can be done in one model.

# %% [markdown]
#   I used two ways to check the pipeline so any one can be fine

# %%
# Use Pipeline
# ANOVA 
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, f_regression
anova_filter = SelectKBest(f_regression, k=5)
LR = AdaBoostRegressor(n_estimators = 5, loss = "exponential")

anova_LinReg = Pipeline([('scaler_Input',scaler), ('anova', anova_filter), ('LinReg', LR)])
# You can set the parameters using the names issued
# For instance, fit using a k of 10 in the SelectKBest
anova_LinReg.set_params(anova__k=5).fit(new_data, Y)
prediction = anova_LinReg.predict(new_data)
print anova_LinReg.score(new_data, Y)                        
# getting the selected features chosen by anova_filter
results = cross_validation.cross_val_score(anova_LinReg, new_data, Y, cv=kfold, scoring=scoring)
print 'Scoring according to mean_squared_error'
print results
print '\n Mean      Standard deviation'
print("%.2f      %.2f" % (results.mean(), results.std()))
print anova_LinReg.named_steps['anova'].get_support()
r_squared = r2_score(Y, prediction, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# 0.588211243515
# Scoring according to mean_squared_error
# [-21.1341938  -25.23548834 -21.57823787 -22.0946418  -19.74000525
#  -20.72206874 -19.619073   -21.22442394 -19.11979176 -25.4361183 ]
#
#  Mean      Standard deviation
# -21.59      2.07
# [ True  True  True  True  True]
# R-squared =  0.588211243515

# %%
# Using make_pipeline
from sklearn.pipeline import make_pipeline

# ANOVA SVM-C
# 1) anova filter, take 3 best ranked features
anova_filter = SelectKBest(f_regression, k=5)
anova_AdaBoostDecisionTreeRegressor = make_pipeline(scaler, anova_filter, LR)
anova_AdaBoostDecisionTreeRegressor.fit(new_data, Y)
prediction = anova_AdaBoostDecisionTreeRegressor.predict(new_data)
r_squared = r2_score(Y, prediction, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
# R-squared =  0.601355530163

# %% [markdown]
# ### Save the Pipeline model for developement

# %%
# save the model scaler to the desk
from sklearn.externals import joblib
joblib.dump(anova_AdaBoostDecisionTreeRegressor, 'anova_AdaBoostDecisionTreeRegressor.pkl')
# Out:
# ['anova_AdaBoostDecisionTreeRegressor.pkl',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_01.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_02.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_03.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_04.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_05.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_06.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_07.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_08.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_09.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_10.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_11.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_12.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_13.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_14.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_15.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_16.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_17.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_18.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_19.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_20.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_21.npy',
#  'anova_AdaBoostDecisionTreeRegressor.pkl_22.npy']

# %%
# Test the model if it is work
anova_DecisionTreeRegressorTest = joblib.load('anova_AdaBoostDecisionTreeRegressor.pkl')
NewPred = anova_DecisionTreeRegressorTest.predict(new_data)
print " =================================================================>>>>> done"
r_squared = r2_score(Y, NewPred, multioutput='variance_weighted')
print 'R-squared = ',r_squared
# Out:
#  =================================================================>>>>> done
# R-squared =  0.601355530163

# %%
# test on single data point, randomly choose point number 55
print 'Point of training data before normalization\n',new_data[55]
print '\nThe read target of the data = ', Y[55]
NewPred = anova_DecisionTreeRegressorTest.predict([new_data[55]])
print '\nThe Predicted target of the data = ', NewPred
# Out:
# Point of training data before normalization
# [  1.00000000e+03   2.70000000e+00   1.52400000e-01   7.13000000e+01
#    2.43851000e-03]
#
# The read target of the data =  128.774
#
# The Predicted target of the data =  [ 129.8952485]

# %% [markdown]
# ## Conclusion
